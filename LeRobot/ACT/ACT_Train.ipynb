# %% [markdown]
# # LeRobot Policy : ACT (Action Chunking with Transformers)
#
# ---
#
# - Conda env : [lerobot](../README.md#setup-a-conda-environment)
#
# ----
#
# - Ref:
#     - ...

# %% [markdown]
# ## Device Setup

# %%
import torch

if torch.backends.mps.is_available():
    device = "mps"
elif torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

print(f"Available device : {device}")
# Out:
# Available device : cuda

# %%
if device == "cuda":
    # !nvidia-smi
# Out:
# Thu Sep 11 10:46:01 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.57.08              Driver Version: 575.57.08      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2080 Ti     On  |   00000000:01:00.0  On |                  N/A |
# | 25%   44C    P5             36W /  250W |    1389MiB /  11264MiB |     19%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2104      G   /usr/lib/xorg/Xorg                      703MiB |
# |    0   N/A  N/A            2280      G   /usr/bin/gnome-shell                    103MiB |
# |    0   N/A  N/A            4369      G   ...ersion=20250910-180038.780000        151MiB |
# |    0   N/A  N/A            9286      G   /usr/share/code/code                    350MiB |
# |    0   N/A  N/A           11047      G   /opt/unityhub/unityhub-bin               41MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## DataSet(aloha_sim_transfer_cube_human ) Visualization

# %%
# !python -m lerobot.scripts.visualize_dataset \
    --repo-id lerobot/aloha_sim_transfer_cube_human  \
    --episode-index 0
# Out:
# Resolving data files: 100%|██████████████████| 50/50 [00:00<00:00, 77758.69it/s]
# [2025-09-10T20:49:57Z INFO  winit::platform_impl::linux::x11::window] Guessed window scale factor: 1
# [2025-09-10T20:49:58Z WARN  wgpu_hal::gles::egl] No config found!
# [2025-09-10T20:49:58Z WARN  wgpu_hal::gles::egl] EGL says it can present to the window but not natively
#   0%|                                                    | 0/13 [00:00<?, ?it/s][2025-09-10T20:49:58Z WARN  wgpu_hal::gles::adapter] Max vertex attribute stride unknown. Assuming it is 2048
# [2025-09-10T20:49:58Z WARN  wgpu_hal::vulkan::conv] Unrecognized present mode 1000361000
# [2025-09-10T20:49:58Z WARN  wgpu_hal::gles::adapter] Max vertex attribute stride unknown. Assuming it is 2048
# [2025-09-10T20:49:58Z WARN  wgpu_hal::vulkan::conv] Unrecognized present mode 1000361000
# [2025-09-10T20:49:58Z WARN  wgpu_hal::vulkan::conv] Unrecognized present mode 1000361000
# [2025-09-10T20:49:58Z WARN  wgpu_hal::vulkan::conv] Unrecognized present mode 1000361000
#   8%|███▍                                        | 1/13 [00:01<00:13,  1.10s/it][2025-09-10T20:49:59Z WARN  wgpu_hal::vulkan::conv] Unrecognized present mode 1000361000
# [2025-09-10T20:49:59Z WARN  wgpu_hal::vulkan::conv] Unrecognized present mode 1000361000
# 100%|███████████████████████████████████████████| 13/13 [00:04<00:00,  2.98it/s]

# %% [markdown]
# ##  Training ACT Model from scratch

# %%
import os

output_dir = "./temp/outputs/aloha_sim_transfer_cube_human"
print(output_dir)
# Out:
# ./temp/outputs/aloha_sim_transfer_cube_human

# %%
# !python -m lerobot.scripts.train \
    --policy.type=act \
    --dataset.repo_id=lerobot/aloha_sim_transfer_cube_human \
    --env.type=aloha \
    --env.task=AlohaTransferCube-v0 \
    --batch_size=16  \
    --steps=20000 \
    --save_freq=500 \
    --eval_freq=500 \
    --policy.device=$device \
    --wandb.enable=false \
    --output_dir=$output_dir \
    --policy.push_to_hub=false
# Out:
# INFO 2025-09-10 12:33:55 ts/train.py:111 {'batch_size': 16,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'lerobot/aloha_sim_transfer_cube_human',
#              'revision': None,
#              'root': None,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': {'episode_length': 400,
#          'features': {'action': {'shape': [14],
#                                  'type': <FeatureType.ACTION: 'ACTION'>},
#                       'agent_pos': {'shape': [14],
#                                     'type': <FeatureType.STATE: 'STATE'>},
#                       'pixels/top': {'shape': [480, 640, 3],
#                                      'type': <FeatureType.VISUAL: 'VISUAL'>}},
#          'features_map': {'action': 'action',
#                           'agent_pos': 'observation.state',
#                           'pixels/top': 'observation.images.top',
#                           'top': 'observation.image.top'},
#          'fps': 50,
#          'obs_type': 'pixels_agent_pos',
#          'render_mode': 'rgb_array',
#          'task': 'AlohaTransferCube-v0',
#          'type': 'aloha'},
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 500,
#  'job_name': 'aloha_act',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'temp/outputs/aloha_sim_transfer_cube_human',
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'private': None,
#             'push_to_hub': False,
#             'replace_final_stride_with_dilation': False,
#             'repo_id': None,
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 500,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 20000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': False,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2025-09-10 12:33:55 ts/train.py:117 Logs will be saved locally.
# INFO 2025-09-10 12:33:55 ts/train.py:127 Creating dataset
# Resolving data files: 100%|█████████████████| 50/50 [00:00<00:00, 237772.34it/s]
# INFO 2025-09-10 12:33:56 ts/train.py:135 Creating env
# INFO 2025-09-10 12:33:56 /__init__.py:88 MUJOCO_GL is not set, so an OpenGL backend will be chosen automatically.
# INFO 2025-09-10 12:33:56 /__init__.py:96 Successfully imported OpenGL backend: glfw
# INFO 2025-09-10 12:33:56 /__init__.py:31 MuJoCo library version is: 2.3.7
# INFO 2025-09-10 12:33:59 ts/train.py:138 Creating policy
# INFO 2025-09-10 12:34:00 ts/train.py:144 Creating optimizer and scheduler
# INFO 2025-09-10 12:34:00 ts/train.py:156 Output dir: temp/outputs/aloha_sim_transfer_cube_human
# INFO 2025-09-10 12:34:00 ts/train.py:158 cfg.env.task='AlohaTransferCube-v0'
# INFO 2025-09-10 12:34:00 ts/train.py:159 cfg.steps=20000 (20K)
# INFO 2025-09-10 12:34:00 ts/train.py:160 dataset.num_frames=20000 (20K)
# INFO 2025-09-10 12:34:00 ts/train.py:161 dataset.num_episodes=50
# INFO 2025-09-10 12:34:00 ts/train.py:162 num_learnable_params=51613582 (52M)
# INFO 2025-09-10 12:34:00 ts/train.py:163 num_total_params=51613672 (52M)
# INFO 2025-09-10 12:34:00 ts/train.py:202 Start offline training on a fixed dataset
# INFO 2025-09-10 12:34:49 ts/train.py:232 step:200 smpl:3K ep:8 epch:0.16 loss:6.661 grdn:113.743 lr:1.0e-05 updt_s:0.244 data_s:0.002
# INFO 2025-09-10 12:35:34 ts/train.py:232 step:400 smpl:6K ep:16 epch:0.32 loss:2.704 grdn:59.753 lr:1.0e-05 updt_s:0.222 data_s:0.000
# INFO 2025-09-10 12:35:56 ts/train.py:241 Checkpoint policy after step 500
# INFO 2025-09-10 12:35:57 ts/train.py:250 Eval policy at step 500
# Stepping through eval batches:   0%|                      | 0/1 [00:00<?, ?it/s]
# Running rollout with at most 400 steps:   0%|           | 0/400 [00:00<?, ?it/s]/home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.task_description to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.task_description` for environment variables or `env.get_wrapper_attr('task_description')` that will search the reminding wrappers.
#   logger.warn(
# /home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/lerobot/scripts/eval.py:147: UserWarning: The environment does not have 'task_description' and 'task'. Some policies require these features.
#   check_env_attributes_and_types(env)
# /home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.task_description to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.task_description` for environment variables or `env.get_wrapper_attr('task_description')` that will search the reminding wrappers.
#   logger.warn(
# /home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.task to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.task` for environment variables or `env.get_wrapper_attr('task')` that will search the reminding wrappers.
#   logger.warn(
#
# Running rollout with at most 400 steps:   0%| | 0/400 [00:02<?, ?it/s, running_s
# Running rollout with at most 400 steps:   0%| | 1/400 [00:02<15:40,  2.36s/it, r
# Running rollout with at most 400 steps:   0%| | 1/400 [00:02<15:40,  2.36s/it, r
# Running rollout with at most 400 steps:   0%| | 2/400 [00:02<07:57,  1.20s/it, r
# Running rollout with at most 400 steps:   0%| | 2/400 [00:03<07:57,  1.20s/it, r
# Running rollout with at most 400 steps:   1%| | 3/400 [00:03<05:29,  1.21it/s, r
# Running rollout with at most 400 steps:   1%| | 3/400 [00:03<05:29,  1.21it/s, r
# Running rollout with at most 400 steps:   1%| | 4/400 [00:03<04:19,  1.53it/s, r
# Running rollout with at most 400 steps:   1%| | 4/400 [00:03<04:19,  1.53it/s, r
# Running rollout with at most 400 steps:   1%| | 5/400 [00:03<03:41,  1.78it/s, r
# Running rollout with at most 400 steps:   1%| | 5/400 [00:04<03:41,  1.78it/s, r
# Running rollout with at most 400 steps:   2%| | 6/400 [00:04<03:19,  1.98it/s, r
# Running rollout with at most 400 steps:   2%| | 6/400 [00:04<03:19,  1.98it/s, r
# Running rollout with at most 400 steps:   2%| | 7/400 [00:04<03:04,  2.13it/s, r
# Running rollout with at most 400 steps:   2%| | 7/400 [00:05<03:04,  2.13it/s, r
# Running rollout with at most 400 steps:   2%| | 8/400 [00:05<02:56,  2.22it/s, r
# Running rollout with at most 400 steps:   2%| | 8/400 [00:05<02:56,  2.22it/s, r
# Running rollout with at most 400 steps:   2%| | 9/400 [00:05<02:49,  2.31it/s, r
# Running rollout with at most 400 steps:   2%| | 9/400 [00:05<02:49,  2.31it/s, r
# Running rollout with at most 400 steps:   2%| | 10/400 [00:05<02:44,  2.38it/s,
# Running rollout with at most 400 steps:   2%| | 10/400 [00:06<02:44,  2.38it/s,
# Running rollout with at most 400 steps:   3%| | 11/400 [00:06<02:40,  2.42it/s,
# Running rollout with at most 400 steps:   3%| | 11/400 [00:06<02:40,  2.42it/s,
# Running rollout with at most 400 steps:   3%| | 12/400 [00:06<02:38,  2.44it/s,
# Running rollout with at most 400 steps:   3%| | 12/400 [00:07<02:38,  2.44it/s,
# Running rollout with at most 400 steps:   3%| | 13/400 [00:07<02:38,  2.44it/s,
# Running rollout with at most 400 steps:   3%| | 13/400 [00:07<02:38,  2.44it/s,
# Running rollout with at most 400 steps:   4%| | 14/400 [00:07<02:39,  2.42it/s,
# Running rollout with at most 400 steps:   4%| | 14/400 [00:07<02:39,  2.42it/s,
# Running rollout with at most 400 steps:   4%| | 15/400 [00:07<02:37,  2.44it/s,
# Running rollout with at most 400 steps:   4%| | 15/400 [00:08<02:37,  2.44it/s,
# Running rollout with at most 400 steps:   4%| | 16/400 [00:08<02:36,  2.45it/s,
# Running rollout with at most 400 steps:   4%| | 16/400 [00:08<02:36,  2.45it/s,
# Running rollout with at most 400 steps:   4%| | 17/400 [00:08<02:35,  2.46it/s,
# Running rollout with at most 400 steps:   4%| | 17/400 [00:09<02:35,  2.46it/s,
# Running rollout with at most 400 steps:   4%| | 18/400 [00:09<02:34,  2.47it/s,
# Running rollout with at most 400 steps:   4%| | 18/400 [00:09<02:34,  2.47it/s,
# Running rollout with at most 400 steps:   5%| | 19/400 [00:09<02:34,  2.47it/s,
# Running rollout with at most 400 steps:   5%| | 19/400 [00:10<02:34,  2.47it/s,
# Running rollout with at most 400 steps:   5%| | 20/400 [00:10<02:45,  2.29it/s,
# Running rollout with at most 400 steps:   5%| | 20/400 [00:10<02:45,  2.29it/s,
# Running rollout with at most 400 steps:   5%| | 21/400 [00:10<02:41,  2.35it/s,
# Running rollout with at most 400 steps:   5%| | 21/400 [00:10<02:41,  2.35it/s,
# Running rollout with at most 400 steps:   6%| | 22/400 [00:10<02:38,  2.38it/s,
# Running rollout with at most 400 steps:   6%| | 22/400 [00:11<02:38,  2.38it/s,
# Running rollout with at most 400 steps:   6%| | 23/400 [00:11<02:35,  2.42it/s,
# Running rollout with at most 400 steps:   6%| | 23/400 [00:11<02:35,  2.42it/s,
# Running rollout with at most 400 steps:   6%| | 24/400 [00:11<02:40,  2.34it/s,
# Running rollout with at most 400 steps:   6%| | 24/400 [00:12<02:40,  2.34it/s,
# Running rollout with at most 400 steps:   6%| | 25/400 [00:12<02:48,  2.23it/s,
# Running rollout with at most 400 steps:   6%| | 25/400 [00:12<02:48,  2.23it/s,
# Running rollout with at most 400 steps:   6%| | 26/400 [00:12<02:47,  2.24it/s,
# Running rollout with at most 400 steps:   6%| | 26/400 [00:13<02:47,  2.24it/s,
# Running rollout with at most 400 steps:   7%| | 27/400 [00:13<02:41,  2.31it/s,
# Running rollout with at most 400 steps:   7%| | 27/400 [00:13<02:41,  2.31it/s,
# Running rollout with at most 400 steps:   7%| | 28/400 [00:13<02:37,  2.36it/s,
# Running rollout with at most 400 steps:   7%| | 28/400 [00:13<02:37,  2.36it/s,
# Running rollout with at most 400 steps:   7%| | 29/400 [00:13<02:35,  2.39it/s,
# Running rollout with at most 400 steps:   7%| | 29/400 [00:14<02:35,  2.39it/s,
# Running rollout with at most 400 steps:   8%| | 30/400 [00:14<02:33,  2.41it/s,
# Running rollout with at most 400 steps:   8%| | 30/400 [00:14<02:33,  2.41it/s,
# Running rollout with at most 400 steps:   8%| | 31/400 [00:14<02:32,  2.43it/s,
# Running rollout with at most 400 steps:   8%| | 31/400 [00:15<02:32,  2.43it/s,
# Running rollout with at most 400 steps:   8%| | 32/400 [00:15<02:30,  2.44it/s,
# Running rollout with at most 400 steps:   8%| | 32/400 [00:15<02:30,  2.44it/s,
# Running rollout with at most 400 steps:   8%| | 33/400 [00:15<02:30,  2.44it/s,
# Running rollout with at most 400 steps:   8%| | 33/400 [00:15<02:30,  2.44it/s,
# Running rollout with at most 400 steps:   8%| | 34/400 [00:15<02:33,  2.38it/s,
# Running rollout with at most 400 steps:   8%| | 34/400 [00:16<02:33,  2.38it/s,
# Running rollout with at most 400 steps:   9%| | 35/400 [00:16<02:30,  2.42it/s,
# Running rollout with at most 400 steps:   9%| | 35/400 [00:16<02:30,  2.42it/s,
# Running rollout with at most 400 steps:   9%| | 36/400 [00:16<02:29,  2.44it/s,
# Running rollout with at most 400 steps:   9%| | 36/400 [00:17<02:29,  2.44it/s,
# Running rollout with at most 400 steps:   9%| | 37/400 [00:17<02:28,  2.44it/s,
# Running rollout with at most 400 steps:   9%| | 37/400 [00:17<02:28,  2.44it/s,
# Running rollout with at most 400 steps:  10%| | 38/400 [00:17<02:29,  2.42it/s,
# Running rollout with at most 400 steps:  10%| | 38/400 [00:17<02:29,  2.42it/s,
# Running rollout with at most 400 steps:  10%| | 39/400 [00:17<02:28,  2.42it/s,
# Running rollout with at most 400 steps:  10%| | 39/400 [00:18<02:28,  2.42it/s,
# Running rollout with at most 400 steps:  10%| | 40/400 [00:18<02:27,  2.44it/s,
# Running rollout with at most 400 steps:  10%| | 40/400 [00:18<02:27,  2.44it/s,
# Running rollout with at most 400 steps:  10%| | 41/400 [00:18<02:26,  2.45it/s,
# Running rollout with at most 400 steps:  10%| | 41/400 [00:19<02:26,  2.45it/s,
# Running rollout with at most 400 steps:  10%| | 42/400 [00:19<02:25,  2.46it/s,
# Running rollout with at most 400 steps:  10%| | 42/400 [00:19<02:25,  2.46it/s,
# Running rollout with at most 400 steps:  11%| | 43/400 [00:19<02:24,  2.46it/s,
# Running rollout with at most 400 steps:  11%| | 43/400 [00:20<02:24,  2.46it/s,
# Running rollout with at most 400 steps:  11%| | 44/400 [00:20<02:24,  2.47it/s,
# Running rollout with at most 400 steps:  11%| | 44/400 [00:20<02:24,  2.47it/s,
# Running rollout with at most 400 steps:  11%| | 45/400 [00:20<02:23,  2.47it/s,
# Running rollout with at most 400 steps:  11%| | 45/400 [00:20<02:23,  2.47it/s,
# Running rollout with at most 400 steps:  12%| | 46/400 [00:20<02:23,  2.47it/s,
# Running rollout with at most 400 steps:  12%| | 46/400 [00:21<02:23,  2.47it/s,
# Running rollout with at most 400 steps:  12%| | 47/400 [00:21<02:21,  2.49it/s,
# Running rollout with at most 400 steps:  12%| | 47/400 [00:21<02:21,  2.49it/s,
# Running rollout with at most 400 steps:  12%| | 48/400 [00:21<02:20,  2.50it/s,
# Running rollout with at most 400 steps:  12%| | 48/400 [00:22<02:20,  2.50it/s,
# Running rollout with at most 400 steps:  12%| | 49/400 [00:22<02:20,  2.50it/s,
# Running rollout with at most 400 steps:  12%| | 49/400 [00:22<02:20,  2.50it/s,
# Running rollout with at most 400 steps:  12%|▏| 50/400 [00:22<02:32,  2.30it/s,
# Running rollout with at most 400 steps:  12%|▏| 50/400 [00:22<02:32,  2.30it/s,
# Running rollout with at most 400 steps:  13%|▏| 51/400 [00:22<02:27,  2.37it/s,
# Running rollout with at most 400 steps:  13%|▏| 51/400 [00:23<02:27,  2.37it/s,
# Running rollout with at most 400 steps:  13%|▏| 52/400 [00:23<02:24,  2.41it/s,
# Running rollout with at most 400 steps:  13%|▏| 52/400 [00:23<02:24,  2.41it/s,
# Running rollout with at most 400 steps:  13%|▏| 53/400 [00:23<02:22,  2.43it/s,
# Running rollout with at most 400 steps:  13%|▏| 53/400 [00:24<02:22,  2.43it/s,
# Running rollout with at most 400 steps:  14%|▏| 54/400 [00:24<02:20,  2.46it/s,
# Running rollout with at most 400 steps:  14%|▏| 54/400 [00:24<02:20,  2.46it/s,
# Running rollout with at most 400 steps:  14%|▏| 55/400 [00:24<02:21,  2.44it/s,
# Running rollout with at most 400 steps:  14%|▏| 55/400 [00:24<02:21,  2.44it/s,
# Running rollout with at most 400 steps:  14%|▏| 56/400 [00:24<02:19,  2.47it/s,
# Running rollout with at most 400 steps:  14%|▏| 56/400 [00:25<02:19,  2.47it/s,
# Running rollout with at most 400 steps:  14%|▏| 57/400 [00:25<02:25,  2.36it/s,
# Running rollout with at most 400 steps:  14%|▏| 57/400 [00:25<02:25,  2.36it/s,
# Running rollout with at most 400 steps:  14%|▏| 58/400 [00:25<02:24,  2.37it/s,
# Running rollout with at most 400 steps:  14%|▏| 58/400 [00:26<02:24,  2.37it/s,
# Running rollout with at most 400 steps:  15%|▏| 59/400 [00:26<02:23,  2.38it/s,
# Running rollout with at most 400 steps:  15%|▏| 59/400 [00:26<02:23,  2.38it/s,
# Running rollout with at most 400 steps:  15%|▏| 60/400 [00:26<02:21,  2.40it/s,
# Running rollout with at most 400 steps:  15%|▏| 60/400 [00:27<02:21,  2.40it/s,
# Running rollout with at most 400 steps:  15%|▏| 61/400 [00:27<02:19,  2.43it/s,
# Running rollout with at most 400 steps:  15%|▏| 61/400 [00:27<02:19,  2.43it/s,
# Running rollout with at most 400 steps:  16%|▏| 62/400 [00:27<02:17,  2.46it/s,
# Running rollout with at most 400 steps:  16%|▏| 62/400 [00:27<02:17,  2.46it/s,
# Running rollout with at most 400 steps:  16%|▏| 63/400 [00:27<02:16,  2.47it/s,
# Running rollout with at most 400 steps:  16%|▏| 63/400 [00:28<02:16,  2.47it/s,
# Running rollout with at most 400 steps:  16%|▏| 64/400 [00:28<02:15,  2.47it/s,
# Running rollout with at most 400 steps:  16%|▏| 64/400 [00:28<02:15,  2.47it/s,
# Running rollout with at most 400 steps:  16%|▏| 65/400 [00:28<02:14,  2.48it/s,
# Running rollout with at most 400 steps:  16%|▏| 65/400 [00:29<02:14,  2.48it/s,
# Running rollout with at most 400 steps:  16%|▏| 66/400 [00:29<02:14,  2.49it/s,
# Running rollout with at most 400 steps:  16%|▏| 66/400 [00:29<02:14,  2.49it/s,
# Running rollout with at most 400 steps:  17%|▏| 67/400 [00:29<02:13,  2.50it/s,
# Running rollout with at most 400 steps:  17%|▏| 67/400 [00:29<02:13,  2.50it/s,
# Running rollout with at most 400 steps:  17%|▏| 68/400 [00:29<02:12,  2.50it/s,
# Running rollout with at most 400 steps:  17%|▏| 68/400 [00:30<02:12,  2.50it/s,
# Running rollout with at most 400 steps:  17%|▏| 69/400 [00:30<02:12,  2.50it/s,
# Running rollout with at most 400 steps:  17%|▏| 69/400 [00:30<02:12,  2.50it/s,
# Running rollout with at most 400 steps:  18%|▏| 70/400 [00:30<02:12,  2.49it/s,
# Running rollout with at most 400 steps:  18%|▏| 70/400 [00:31<02:12,  2.49it/s,
# Running rollout with at most 400 steps:  18%|▏| 71/400 [00:31<02:13,  2.47it/s,
# Running rollout with at most 400 steps:  18%|▏| 71/400 [00:31<02:13,  2.47it/s,
# Running rollout with at most 400 steps:  18%|▏| 72/400 [00:31<02:12,  2.48it/s,
# Running rollout with at most 400 steps:  18%|▏| 72/400 [00:31<02:12,  2.48it/s,
# Running rollout with at most 400 steps:  18%|▏| 73/400 [00:31<02:11,  2.48it/s,
# Running rollout with at most 400 steps:  18%|▏| 73/400 [00:32<02:11,  2.48it/s,
# Running rollout with at most 400 steps:  18%|▏| 74/400 [00:32<02:22,  2.28it/s,
# Running rollout with at most 400 steps:  18%|▏| 74/400 [00:32<02:22,  2.28it/s,
# Running rollout with at most 400 steps:  19%|▏| 75/400 [00:32<02:19,  2.32it/s,
# Running rollout with at most 400 steps:  19%|▏| 75/400 [00:33<02:19,  2.32it/s,
# Running rollout with at most 400 steps:  19%|▏| 76/400 [00:33<02:16,  2.37it/s,
# Running rollout with at most 400 steps:  19%|▏| 76/400 [00:33<02:16,  2.37it/s,
# Running rollout with at most 400 steps:  19%|▏| 77/400 [00:33<02:15,  2.39it/s,
# Running rollout with at most 400 steps:  19%|▏| 77/400 [00:33<02:15,  2.39it/s,
# Running rollout with at most 400 steps:  20%|▏| 78/400 [00:33<02:13,  2.40it/s,
# Running rollout with at most 400 steps:  20%|▏| 78/400 [00:34<02:13,  2.40it/s,
# Running rollout with at most 400 steps:  20%|▏| 79/400 [00:34<02:12,  2.41it/s,
# Running rollout with at most 400 steps:  20%|▏| 79/400 [00:34<02:12,  2.41it/s,
# Running rollout with at most 400 steps:  20%|▏| 80/400 [00:34<02:11,  2.43it/s,
# Running rollout with at most 400 steps:  20%|▏| 80/400 [00:35<02:11,  2.43it/s,
# Running rollout with at most 400 steps:  20%|▏| 81/400 [00:35<02:11,  2.43it/s,
# Running rollout with at most 400 steps:  20%|▏| 81/400 [00:35<02:11,  2.43it/s,
# Running rollout with at most 400 steps:  20%|▏| 82/400 [00:35<02:11,  2.42it/s,
# Running rollout with at most 400 steps:  20%|▏| 82/400 [00:36<02:11,  2.42it/s,
# Running rollout with at most 400 steps:  21%|▏| 83/400 [00:36<02:18,  2.28it/s,
# Running rollout with at most 400 steps:  21%|▏| 83/400 [00:36<02:18,  2.28it/s,
# Running rollout with at most 400 steps:  21%|▏| 84/400 [00:36<02:14,  2.34it/s,
# Running rollout with at most 400 steps:  21%|▏| 84/400 [00:36<02:14,  2.34it/s,
# Running rollout with at most 400 steps:  21%|▏| 85/400 [00:36<02:13,  2.37it/s,
# Running rollout with at most 400 steps:  21%|▏| 85/400 [00:37<02:13,  2.37it/s,
# Running rollout with at most 400 steps:  22%|▏| 86/400 [00:37<02:11,  2.39it/s,
# Running rollout with at most 400 steps:  22%|▏| 86/400 [00:37<02:11,  2.39it/s,
# Running rollout with at most 400 steps:  22%|▏| 87/400 [00:37<02:10,  2.40it/s,
# Running rollout with at most 400 steps:  22%|▏| 87/400 [00:38<02:10,  2.40it/s,
# Running rollout with at most 400 steps:  22%|▏| 88/400 [00:38<02:08,  2.43it/s,
# Running rollout with at most 400 steps:  22%|▏| 88/400 [00:38<02:08,  2.43it/s,
# Running rollout with at most 400 steps:  22%|▏| 89/400 [00:38<02:07,  2.44it/s,
# Running rollout with at most 400 steps:  22%|▏| 89/400 [00:38<02:07,  2.44it/s,
# Running rollout with at most 400 steps:  22%|▏| 90/400 [00:38<02:06,  2.44it/s,
# Running rollout with at most 400 steps:  22%|▏| 90/400 [00:39<02:06,  2.44it/s,
# Running rollout with at most 400 steps:  23%|▏| 91/400 [00:39<02:06,  2.45it/s,
# Running rollout with at most 400 steps:  23%|▏| 91/400 [00:39<02:06,  2.45it/s,
# Running rollout with at most 400 steps:  23%|▏| 92/400 [00:39<02:05,  2.45it/s,
# Running rollout with at most 400 steps:  23%|▏| 92/400 [00:40<02:05,  2.45it/s,
# Running rollout with at most 400 steps:  23%|▏| 93/400 [00:40<02:07,  2.41it/s,
# Running rollout with at most 400 steps:  23%|▏| 93/400 [00:40<02:07,  2.41it/s,
# Running rollout with at most 400 steps:  24%|▏| 94/400 [00:40<02:06,  2.42it/s,
# Running rollout with at most 400 steps:  24%|▏| 94/400 [00:41<02:06,  2.42it/s,
# Running rollout with at most 400 steps:  24%|▏| 95/400 [00:41<02:05,  2.43it/s,
# Running rollout with at most 400 steps:  24%|▏| 95/400 [00:41<02:05,  2.43it/s,
# Running rollout with at most 400 steps:  24%|▏| 96/400 [00:41<02:05,  2.43it/s,
# Running rollout with at most 400 steps:  24%|▏| 96/400 [00:41<02:05,  2.43it/s,
# Running rollout with at most 400 steps:  24%|▏| 97/400 [00:41<02:04,  2.44it/s,
# Running rollout with at most 400 steps:  24%|▏| 97/400 [00:42<02:04,  2.44it/s,
# Running rollout with at most 400 steps:  24%|▏| 98/400 [00:42<02:03,  2.44it/s,
# Running rollout with at most 400 steps:  24%|▏| 98/400 [00:42<02:03,  2.44it/s,
# Running rollout with at most 400 steps:  25%|▏| 99/400 [00:42<02:04,  2.43it/s,
# Running rollout with at most 400 steps:  25%|▏| 99/400 [00:43<02:04,  2.43it/s,
# Running rollout with at most 400 steps:  25%|▎| 100/400 [00:43<02:13,  2.25it/s,
# Running rollout with at most 400 steps:  25%|▎| 100/400 [00:43<02:13,  2.25it/s,
# Running rollout with at most 400 steps:  25%|▎| 101/400 [00:43<02:26,  2.04it/s,
# Running rollout with at most 400 steps:  25%|▎| 101/400 [00:44<02:26,  2.04it/s,
# Running rollout with at most 400 steps:  26%|▎| 102/400 [00:44<02:17,  2.17it/s,
# Running rollout with at most 400 steps:  26%|▎| 102/400 [00:44<02:17,  2.17it/s,
# Running rollout with at most 400 steps:  26%|▎| 103/400 [00:44<02:11,  2.26it/s,
# Running rollout with at most 400 steps:  26%|▎| 103/400 [00:44<02:11,  2.26it/s,
# Running rollout with at most 400 steps:  26%|▎| 104/400 [00:44<02:06,  2.34it/s,
# Running rollout with at most 400 steps:  26%|▎| 104/400 [00:45<02:06,  2.34it/s,
# Running rollout with at most 400 steps:  26%|▎| 105/400 [00:45<02:03,  2.40it/s,
# Running rollout with at most 400 steps:  26%|▎| 105/400 [00:45<02:03,  2.40it/s,
# Running rollout with at most 400 steps:  26%|▎| 106/400 [00:45<02:01,  2.41it/s,
# Running rollout with at most 400 steps:  26%|▎| 106/400 [00:46<02:01,  2.41it/s,
# Running rollout with at most 400 steps:  27%|▎| 107/400 [00:46<02:01,  2.42it/s,
# Running rollout with at most 400 steps:  27%|▎| 107/400 [00:46<02:01,  2.42it/s,
# Running rollout with at most 400 steps:  27%|▎| 108/400 [00:46<02:11,  2.22it/s,
# Running rollout with at most 400 steps:  27%|▎| 108/400 [00:47<02:11,  2.22it/s,
# Running rollout with at most 400 steps:  27%|▎| 109/400 [00:47<02:07,  2.29it/s,
# Running rollout with at most 400 steps:  27%|▎| 109/400 [00:47<02:07,  2.29it/s,
# Running rollout with at most 400 steps:  28%|▎| 110/400 [00:47<02:04,  2.32it/s,
# Running rollout with at most 400 steps:  28%|▎| 110/400 [00:47<02:04,  2.32it/s,
# Running rollout with at most 400 steps:  28%|▎| 111/400 [00:47<02:02,  2.35it/s,
# Running rollout with at most 400 steps:  28%|▎| 111/400 [00:48<02:02,  2.35it/s,
# Running rollout with at most 400 steps:  28%|▎| 112/400 [00:48<02:01,  2.37it/s,
# Running rollout with at most 400 steps:  28%|▎| 112/400 [00:48<02:01,  2.37it/s,
# Running rollout with at most 400 steps:  28%|▎| 113/400 [00:48<02:09,  2.22it/s,
# Running rollout with at most 400 steps:  28%|▎| 113/400 [00:49<02:09,  2.22it/s,
# Running rollout with at most 400 steps:  28%|▎| 114/400 [00:49<02:07,  2.25it/s,
# Running rollout with at most 400 steps:  28%|▎| 114/400 [00:49<02:07,  2.25it/s,
# Running rollout with at most 400 steps:  29%|▎| 115/400 [00:49<02:03,  2.31it/s,
# Running rollout with at most 400 steps:  29%|▎| 115/400 [00:50<02:03,  2.31it/s,
# Running rollout with at most 400 steps:  29%|▎| 116/400 [00:50<02:00,  2.36it/s,
# Running rollout with at most 400 steps:  29%|▎| 116/400 [00:50<02:00,  2.36it/s,
# Running rollout with at most 400 steps:  29%|▎| 117/400 [00:50<01:58,  2.38it/s,
# Running rollout with at most 400 steps:  29%|▎| 117/400 [00:50<01:58,  2.38it/s,
# Running rollout with at most 400 steps:  30%|▎| 118/400 [00:50<01:57,  2.40it/s,
# Running rollout with at most 400 steps:  30%|▎| 118/400 [00:51<01:57,  2.40it/s,
# Running rollout with at most 400 steps:  30%|▎| 119/400 [00:51<01:55,  2.42it/s,
# Running rollout with at most 400 steps:  30%|▎| 119/400 [00:51<01:55,  2.42it/s,
# Running rollout with at most 400 steps:  30%|▎| 120/400 [00:51<01:55,  2.43it/s,
# Running rollout with at most 400 steps:  30%|▎| 120/400 [00:52<01:55,  2.43it/s,
# Running rollout with at most 400 steps:  30%|▎| 121/400 [00:52<01:54,  2.44it/s,
# Running rollout with at most 400 steps:  30%|▎| 121/400 [00:52<01:54,  2.44it/s,
# Running rollout with at most 400 steps:  30%|▎| 122/400 [00:52<01:54,  2.44it/s,
# Running rollout with at most 400 steps:  30%|▎| 122/400 [00:52<01:54,  2.44it/s,
# Running rollout with at most 400 steps:  31%|▎| 123/400 [00:52<01:53,  2.45it/s,
# Running rollout with at most 400 steps:  31%|▎| 123/400 [00:53<01:53,  2.45it/s,
# Running rollout with at most 400 steps:  31%|▎| 124/400 [00:53<02:02,  2.26it/s,
# Running rollout with at most 400 steps:  31%|▎| 124/400 [00:53<02:02,  2.26it/s,
# Running rollout with at most 400 steps:  31%|▎| 125/400 [00:53<01:59,  2.30it/s,
# Running rollout with at most 400 steps:  31%|▎| 125/400 [00:54<01:59,  2.30it/s,
# Running rollout with at most 400 steps:  32%|▎| 126/400 [00:54<01:57,  2.32it/s,
# Running rollout with at most 400 steps:  32%|▎| 126/400 [00:54<01:57,  2.32it/s,
# Running rollout with at most 400 steps:  32%|▎| 127/400 [00:54<02:05,  2.18it/s,
# Running rollout with at most 400 steps:  32%|▎| 127/400 [00:55<02:05,  2.18it/s,
# Running rollout with at most 400 steps:  32%|▎| 128/400 [00:55<02:00,  2.26it/s,
# Running rollout with at most 400 steps:  32%|▎| 128/400 [00:55<02:00,  2.26it/s,
# Running rollout with at most 400 steps:  32%|▎| 129/400 [00:55<01:57,  2.31it/s,
# Running rollout with at most 400 steps:  32%|▎| 129/400 [00:56<01:57,  2.31it/s,
# Running rollout with at most 400 steps:  32%|▎| 130/400 [00:56<01:54,  2.35it/s,
# Running rollout with at most 400 steps:  32%|▎| 130/400 [00:56<01:54,  2.35it/s,
# Running rollout with at most 400 steps:  33%|▎| 131/400 [00:56<01:53,  2.38it/s,
# Running rollout with at most 400 steps:  33%|▎| 131/400 [00:56<01:53,  2.38it/s,
# Running rollout with at most 400 steps:  33%|▎| 132/400 [00:56<01:51,  2.41it/s,
# Running rollout with at most 400 steps:  33%|▎| 132/400 [00:57<01:51,  2.41it/s,
# Running rollout with at most 400 steps:  33%|▎| 133/400 [00:57<01:49,  2.44it/s,
# Running rollout with at most 400 steps:  33%|▎| 133/400 [00:57<01:49,  2.44it/s,
# Running rollout with at most 400 steps:  34%|▎| 134/400 [00:57<01:48,  2.45it/s,
# Running rollout with at most 400 steps:  34%|▎| 134/400 [00:58<01:48,  2.45it/s,
# Running rollout with at most 400 steps:  34%|▎| 135/400 [00:58<01:48,  2.45it/s,
# Running rollout with at most 400 steps:  34%|▎| 135/400 [00:58<01:48,  2.45it/s,
# Running rollout with at most 400 steps:  34%|▎| 136/400 [00:58<01:47,  2.45it/s,
# Running rollout with at most 400 steps:  34%|▎| 136/400 [00:59<01:47,  2.45it/s,
# Running rollout with at most 400 steps:  34%|▎| 137/400 [00:59<01:53,  2.32it/s,
# Running rollout with at most 400 steps:  34%|▎| 137/400 [00:59<01:53,  2.32it/s,
# Running rollout with at most 400 steps:  34%|▎| 138/400 [00:59<02:13,  1.96it/s,
# Running rollout with at most 400 steps:  34%|▎| 138/400 [01:00<02:13,  1.96it/s,
# Running rollout with at most 400 steps:  35%|▎| 139/400 [01:00<02:07,  2.05it/s,
# Running rollout with at most 400 steps:  35%|▎| 139/400 [01:00<02:07,  2.05it/s,
# Running rollout with at most 400 steps:  35%|▎| 140/400 [01:00<02:01,  2.15it/s,
# Running rollout with at most 400 steps:  35%|▎| 140/400 [01:00<02:01,  2.15it/s,
# Running rollout with at most 400 steps:  35%|▎| 141/400 [01:00<01:57,  2.21it/s,
# Running rollout with at most 400 steps:  35%|▎| 141/400 [01:01<01:57,  2.21it/s,
# Running rollout with at most 400 steps:  36%|▎| 142/400 [01:01<01:56,  2.21it/s,
# Running rollout with at most 400 steps:  36%|▎| 142/400 [01:01<01:56,  2.21it/s,
# Running rollout with at most 400 steps:  36%|▎| 143/400 [01:01<01:53,  2.27it/s,
# Running rollout with at most 400 steps:  36%|▎| 143/400 [01:02<01:53,  2.27it/s,
# Running rollout with at most 400 steps:  36%|▎| 144/400 [01:02<01:50,  2.31it/s,
# Running rollout with at most 400 steps:  36%|▎| 144/400 [01:02<01:50,  2.31it/s,
# Running rollout with at most 400 steps:  36%|▎| 145/400 [01:02<01:56,  2.20it/s,
# Running rollout with at most 400 steps:  36%|▎| 145/400 [01:03<01:56,  2.20it/s,
# Running rollout with at most 400 steps:  36%|▎| 146/400 [01:03<01:53,  2.25it/s,
# Running rollout with at most 400 steps:  36%|▎| 146/400 [01:03<01:53,  2.25it/s,
# Running rollout with at most 400 steps:  37%|▎| 147/400 [01:03<01:50,  2.30it/s,
# Running rollout with at most 400 steps:  37%|▎| 147/400 [01:04<01:50,  2.30it/s,
# Running rollout with at most 400 steps:  37%|▎| 148/400 [01:04<01:49,  2.31it/s,
# Running rollout with at most 400 steps:  37%|▎| 148/400 [01:04<01:49,  2.31it/s,
# Running rollout with at most 400 steps:  37%|▎| 149/400 [01:04<01:52,  2.22it/s,
# Running rollout with at most 400 steps:  37%|▎| 149/400 [01:04<01:52,  2.22it/s,
# Running rollout with at most 400 steps:  38%|▍| 150/400 [01:04<01:48,  2.29it/s,
# Running rollout with at most 400 steps:  38%|▍| 150/400 [01:05<01:48,  2.29it/s,
# Running rollout with at most 400 steps:  38%|▍| 151/400 [01:05<01:47,  2.31it/s,
# Running rollout with at most 400 steps:  38%|▍| 151/400 [01:05<01:47,  2.31it/s,
# Running rollout with at most 400 steps:  38%|▍| 152/400 [01:05<01:46,  2.34it/s,
# Running rollout with at most 400 steps:  38%|▍| 152/400 [01:06<01:46,  2.34it/s,
# Running rollout with at most 400 steps:  38%|▍| 153/400 [01:06<01:49,  2.25it/s,
# Running rollout with at most 400 steps:  38%|▍| 153/400 [01:06<01:49,  2.25it/s,
# Running rollout with at most 400 steps:  38%|▍| 154/400 [01:06<01:47,  2.28it/s,
# Running rollout with at most 400 steps:  38%|▍| 154/400 [01:07<01:47,  2.28it/s,
# Running rollout with at most 400 steps:  39%|▍| 155/400 [01:07<01:45,  2.31it/s,
# Running rollout with at most 400 steps:  39%|▍| 155/400 [01:07<01:45,  2.31it/s,
# Running rollout with at most 400 steps:  39%|▍| 156/400 [01:07<01:44,  2.34it/s,
# Running rollout with at most 400 steps:  39%|▍| 156/400 [01:07<01:44,  2.34it/s,
# Running rollout with at most 400 steps:  39%|▍| 157/400 [01:07<01:42,  2.36it/s,
# Running rollout with at most 400 steps:  39%|▍| 157/400 [01:08<01:42,  2.36it/s,
# Running rollout with at most 400 steps:  40%|▍| 158/400 [01:08<01:41,  2.38it/s,
# Running rollout with at most 400 steps:  40%|▍| 158/400 [01:08<01:41,  2.38it/s,
# Running rollout with at most 400 steps:  40%|▍| 159/400 [01:08<01:40,  2.40it/s,
# Running rollout with at most 400 steps:  40%|▍| 159/400 [01:09<01:40,  2.40it/s,
# Running rollout with at most 400 steps:  40%|▍| 160/400 [01:09<01:39,  2.40it/s,
# Running rollout with at most 400 steps:  40%|▍| 160/400 [01:09<01:39,  2.40it/s,
# Running rollout with at most 400 steps:  40%|▍| 161/400 [01:09<01:39,  2.41it/s,
# Running rollout with at most 400 steps:  40%|▍| 161/400 [01:09<01:39,  2.41it/s,
# Running rollout with at most 400 steps:  40%|▍| 162/400 [01:09<01:38,  2.41it/s,
# Running rollout with at most 400 steps:  40%|▍| 162/400 [01:10<01:38,  2.41it/s,
# Running rollout with at most 400 steps:  41%|▍| 163/400 [01:10<01:47,  2.21it/s,
# Running rollout with at most 400 steps:  41%|▍| 163/400 [01:10<01:47,  2.21it/s,
# Running rollout with at most 400 steps:  41%|▍| 164/400 [01:10<01:43,  2.28it/s,
# Running rollout with at most 400 steps:  41%|▍| 164/400 [01:11<01:43,  2.28it/s,
# Running rollout with at most 400 steps:  41%|▍| 165/400 [01:11<01:49,  2.15it/s,
# Running rollout with at most 400 steps:  41%|▍| 165/400 [01:11<01:49,  2.15it/s,
# Running rollout with at most 400 steps:  42%|▍| 166/400 [01:11<01:45,  2.22it/s,
# Running rollout with at most 400 steps:  42%|▍| 166/400 [01:12<01:45,  2.22it/s,
# Running rollout with at most 400 steps:  42%|▍| 167/400 [01:12<01:42,  2.28it/s,
# Running rollout with at most 400 steps:  42%|▍| 167/400 [01:12<01:42,  2.28it/s,
# Running rollout with at most 400 steps:  42%|▍| 168/400 [01:12<01:40,  2.31it/s,
# Running rollout with at most 400 steps:  42%|▍| 168/400 [01:13<01:40,  2.31it/s,
# Running rollout with at most 400 steps:  42%|▍| 169/400 [01:13<01:38,  2.34it/s,
# Running rollout with at most 400 steps:  42%|▍| 169/400 [01:13<01:38,  2.34it/s,
# Running rollout with at most 400 steps:  42%|▍| 170/400 [01:13<01:37,  2.36it/s,
# Running rollout with at most 400 steps:  42%|▍| 170/400 [01:13<01:37,  2.36it/s,
# Running rollout with at most 400 steps:  43%|▍| 171/400 [01:13<01:36,  2.37it/s,
# Running rollout with at most 400 steps:  43%|▍| 171/400 [01:14<01:36,  2.37it/s,
# Running rollout with at most 400 steps:  43%|▍| 172/400 [01:14<01:35,  2.39it/s,
# Running rollout with at most 400 steps:  43%|▍| 172/400 [01:14<01:35,  2.39it/s,
# Running rollout with at most 400 steps:  43%|▍| 173/400 [01:14<01:35,  2.39it/s,
# Running rollout with at most 400 steps:  43%|▍| 173/400 [01:15<01:35,  2.39it/s,
# Running rollout with at most 400 steps:  44%|▍| 174/400 [01:15<01:34,  2.40it/s,
# Running rollout with at most 400 steps:  44%|▍| 174/400 [01:15<01:34,  2.40it/s,
# Running rollout with at most 400 steps:  44%|▍| 175/400 [01:15<01:33,  2.40it/s,
# Running rollout with at most 400 steps:  44%|▍| 175/400 [01:16<01:33,  2.40it/s,
# Running rollout with at most 400 steps:  44%|▍| 176/400 [01:16<01:33,  2.41it/s,
# Running rollout with at most 400 steps:  44%|▍| 176/400 [01:16<01:33,  2.41it/s,
# Running rollout with at most 400 steps:  44%|▍| 177/400 [01:16<01:32,  2.41it/s,
# Running rollout with at most 400 steps:  44%|▍| 177/400 [01:16<01:32,  2.41it/s,
# Running rollout with at most 400 steps:  44%|▍| 178/400 [01:16<01:31,  2.42it/s,
# Running rollout with at most 400 steps:  44%|▍| 178/400 [01:17<01:31,  2.42it/s,
# Running rollout with at most 400 steps:  45%|▍| 179/400 [01:17<01:30,  2.43it/s,
# Running rollout with at most 400 steps:  45%|▍| 179/400 [01:17<01:30,  2.43it/s,
# Running rollout with at most 400 steps:  45%|▍| 180/400 [01:17<01:30,  2.44it/s,
# Running rollout with at most 400 steps:  45%|▍| 180/400 [01:18<01:30,  2.44it/s,
# Running rollout with at most 400 steps:  45%|▍| 181/400 [01:18<01:31,  2.40it/s,
# Running rollout with at most 400 steps:  45%|▍| 181/400 [01:18<01:31,  2.40it/s,
# Running rollout with at most 400 steps:  46%|▍| 182/400 [01:18<01:30,  2.41it/s,
# Running rollout with at most 400 steps:  46%|▍| 182/400 [01:18<01:30,  2.41it/s,
# Running rollout with at most 400 steps:  46%|▍| 183/400 [01:18<01:30,  2.41it/s,
# Running rollout with at most 400 steps:  46%|▍| 183/400 [01:19<01:30,  2.41it/s,
# Running rollout with at most 400 steps:  46%|▍| 184/400 [01:19<01:29,  2.42it/s,
# Running rollout with at most 400 steps:  46%|▍| 184/400 [01:19<01:29,  2.42it/s,
# Running rollout with at most 400 steps:  46%|▍| 185/400 [01:19<01:28,  2.42it/s,
# Running rollout with at most 400 steps:  46%|▍| 185/400 [01:20<01:28,  2.42it/s,
# Running rollout with at most 400 steps:  46%|▍| 186/400 [01:20<01:28,  2.42it/s,
# Running rollout with at most 400 steps:  46%|▍| 186/400 [01:20<01:28,  2.42it/s,
# Running rollout with at most 400 steps:  47%|▍| 187/400 [01:20<01:27,  2.43it/s,
# Running rollout with at most 400 steps:  47%|▍| 187/400 [01:20<01:27,  2.43it/s,
# Running rollout with at most 400 steps:  47%|▍| 188/400 [01:20<01:27,  2.41it/s,
# Running rollout with at most 400 steps:  47%|▍| 188/400 [01:21<01:27,  2.41it/s,
# Running rollout with at most 400 steps:  47%|▍| 189/400 [01:21<01:27,  2.41it/s,
# Running rollout with at most 400 steps:  47%|▍| 189/400 [01:21<01:27,  2.41it/s,
# Running rollout with at most 400 steps:  48%|▍| 190/400 [01:21<01:26,  2.41it/s,
# Running rollout with at most 400 steps:  48%|▍| 190/400 [01:22<01:26,  2.41it/s,
# Running rollout with at most 400 steps:  48%|▍| 191/400 [01:22<01:26,  2.40it/s,
# Running rollout with at most 400 steps:  48%|▍| 191/400 [01:22<01:26,  2.40it/s,
# Running rollout with at most 400 steps:  48%|▍| 192/400 [01:22<01:26,  2.42it/s,
# Running rollout with at most 400 steps:  48%|▍| 192/400 [01:23<01:26,  2.42it/s,
# Running rollout with at most 400 steps:  48%|▍| 193/400 [01:23<01:25,  2.42it/s,
# Running rollout with at most 400 steps:  48%|▍| 193/400 [01:23<01:25,  2.42it/s,
# Running rollout with at most 400 steps:  48%|▍| 194/400 [01:23<01:25,  2.42it/s,
# Running rollout with at most 400 steps:  48%|▍| 194/400 [01:23<01:25,  2.42it/s,
# Running rollout with at most 400 steps:  49%|▍| 195/400 [01:23<01:24,  2.43it/s,
# Running rollout with at most 400 steps:  49%|▍| 195/400 [01:24<01:24,  2.43it/s,
# Running rollout with at most 400 steps:  49%|▍| 196/400 [01:24<01:23,  2.43it/s,
# Running rollout with at most 400 steps:  49%|▍| 196/400 [01:24<01:23,  2.43it/s,
# Running rollout with at most 400 steps:  49%|▍| 197/400 [01:24<01:23,  2.43it/s,
# Running rollout with at most 400 steps:  49%|▍| 197/400 [01:25<01:23,  2.43it/s,
# Running rollout with at most 400 steps:  50%|▍| 198/400 [01:25<01:23,  2.42it/s,
# Running rollout with at most 400 steps:  50%|▍| 198/400 [01:25<01:23,  2.42it/s,
# Running rollout with at most 400 steps:  50%|▍| 199/400 [01:25<01:23,  2.42it/s,
# Running rollout with at most 400 steps:  50%|▍| 199/400 [01:25<01:23,  2.42it/s,
# Running rollout with at most 400 steps:  50%|▌| 200/400 [01:25<01:22,  2.42it/s,
# Running rollout with at most 400 steps:  50%|▌| 200/400 [01:26<01:22,  2.42it/s,
# Running rollout with at most 400 steps:  50%|▌| 201/400 [01:26<01:33,  2.13it/s,
# Running rollout with at most 400 steps:  50%|▌| 201/400 [01:26<01:33,  2.13it/s,
# Running rollout with at most 400 steps:  50%|▌| 202/400 [01:26<01:29,  2.21it/s,
# Running rollout with at most 400 steps:  50%|▌| 202/400 [01:27<01:29,  2.21it/s,
# Running rollout with at most 400 steps:  51%|▌| 203/400 [01:27<01:27,  2.26it/s,
# Running rollout with at most 400 steps:  51%|▌| 203/400 [01:27<01:27,  2.26it/s,
# Running rollout with at most 400 steps:  51%|▌| 204/400 [01:27<01:30,  2.17it/s,
# Running rollout with at most 400 steps:  51%|▌| 204/400 [01:28<01:30,  2.17it/s,
# Running rollout with at most 400 steps:  51%|▌| 205/400 [01:28<01:26,  2.25it/s,
# Running rollout with at most 400 steps:  51%|▌| 205/400 [01:28<01:26,  2.25it/s,
# Running rollout with at most 400 steps:  52%|▌| 206/400 [01:28<01:24,  2.30it/s,
# Running rollout with at most 400 steps:  52%|▌| 206/400 [01:29<01:24,  2.30it/s,
# Running rollout with at most 400 steps:  52%|▌| 207/400 [01:29<01:22,  2.35it/s,
# Running rollout with at most 400 steps:  52%|▌| 207/400 [01:29<01:22,  2.35it/s,
# Running rollout with at most 400 steps:  52%|▌| 208/400 [01:29<01:20,  2.38it/s,
# Running rollout with at most 400 steps:  52%|▌| 208/400 [01:30<01:20,  2.38it/s,
# Running rollout with at most 400 steps:  52%|▌| 209/400 [01:30<01:24,  2.27it/s,
# Running rollout with at most 400 steps:  52%|▌| 209/400 [01:30<01:24,  2.27it/s,
# Running rollout with at most 400 steps:  52%|▌| 210/400 [01:30<01:27,  2.17it/s,
# Running rollout with at most 400 steps:  52%|▌| 210/400 [01:30<01:27,  2.17it/s,
# Running rollout with at most 400 steps:  53%|▌| 211/400 [01:30<01:24,  2.23it/s,
# Running rollout with at most 400 steps:  53%|▌| 211/400 [01:31<01:24,  2.23it/s,
# Running rollout with at most 400 steps:  53%|▌| 212/400 [01:31<01:22,  2.28it/s,
# Running rollout with at most 400 steps:  53%|▌| 212/400 [01:31<01:22,  2.28it/s,
# Running rollout with at most 400 steps:  53%|▌| 213/400 [01:31<01:20,  2.31it/s,
# Running rollout with at most 400 steps:  53%|▌| 213/400 [01:32<01:20,  2.31it/s,
# Running rollout with at most 400 steps:  54%|▌| 214/400 [01:32<01:19,  2.34it/s,
# Running rollout with at most 400 steps:  54%|▌| 214/400 [01:32<01:19,  2.34it/s,
# Running rollout with at most 400 steps:  54%|▌| 215/400 [01:32<01:18,  2.35it/s,
# Running rollout with at most 400 steps:  54%|▌| 215/400 [01:33<01:18,  2.35it/s,
# Running rollout with at most 400 steps:  54%|▌| 216/400 [01:33<01:24,  2.18it/s,
# Running rollout with at most 400 steps:  54%|▌| 216/400 [01:33<01:24,  2.18it/s,
# Running rollout with at most 400 steps:  54%|▌| 217/400 [01:33<01:21,  2.25it/s,
# Running rollout with at most 400 steps:  54%|▌| 217/400 [01:33<01:21,  2.25it/s,
# Running rollout with at most 400 steps:  55%|▌| 218/400 [01:33<01:19,  2.29it/s,
# Running rollout with at most 400 steps:  55%|▌| 218/400 [01:34<01:19,  2.29it/s,
# Running rollout with at most 400 steps:  55%|▌| 219/400 [01:34<01:17,  2.33it/s,
# Running rollout with at most 400 steps:  55%|▌| 219/400 [01:34<01:17,  2.33it/s,
# Running rollout with at most 400 steps:  55%|▌| 220/400 [01:34<01:16,  2.35it/s,
# Running rollout with at most 400 steps:  55%|▌| 220/400 [01:35<01:16,  2.35it/s,
# Running rollout with at most 400 steps:  55%|▌| 221/400 [01:35<01:15,  2.37it/s,
# Running rollout with at most 400 steps:  55%|▌| 221/400 [01:35<01:15,  2.37it/s,
# Running rollout with at most 400 steps:  56%|▌| 222/400 [01:35<01:14,  2.38it/s,
# Running rollout with at most 400 steps:  56%|▌| 222/400 [01:36<01:14,  2.38it/s,
# Running rollout with at most 400 steps:  56%|▌| 223/400 [01:36<01:14,  2.39it/s,
# Running rollout with at most 400 steps:  56%|▌| 223/400 [01:36<01:14,  2.39it/s,
# Running rollout with at most 400 steps:  56%|▌| 224/400 [01:36<01:13,  2.41it/s,
# Running rollout with at most 400 steps:  56%|▌| 224/400 [01:36<01:13,  2.41it/s,
# Running rollout with at most 400 steps:  56%|▌| 225/400 [01:36<01:14,  2.34it/s,
# Running rollout with at most 400 steps:  56%|▌| 225/400 [01:37<01:14,  2.34it/s,
# Running rollout with at most 400 steps:  56%|▌| 226/400 [01:37<01:22,  2.10it/s,
# Running rollout with at most 400 steps:  56%|▌| 226/400 [01:37<01:22,  2.10it/s,
# Running rollout with at most 400 steps:  57%|▌| 227/400 [01:37<01:19,  2.19it/s,
# Running rollout with at most 400 steps:  57%|▌| 227/400 [01:38<01:19,  2.19it/s,
# Running rollout with at most 400 steps:  57%|▌| 228/400 [01:38<01:16,  2.25it/s,
# Running rollout with at most 400 steps:  57%|▌| 228/400 [01:38<01:16,  2.25it/s,
# Running rollout with at most 400 steps:  57%|▌| 229/400 [01:38<01:14,  2.30it/s,
# Running rollout with at most 400 steps:  57%|▌| 229/400 [01:39<01:14,  2.30it/s,
# Running rollout with at most 400 steps:  57%|▌| 230/400 [01:39<01:12,  2.34it/s,
# Running rollout with at most 400 steps:  57%|▌| 230/400 [01:39<01:12,  2.34it/s,
# Running rollout with at most 400 steps:  58%|▌| 231/400 [01:39<01:11,  2.37it/s,
# Running rollout with at most 400 steps:  58%|▌| 231/400 [01:39<01:11,  2.37it/s,
# Running rollout with at most 400 steps:  58%|▌| 232/400 [01:39<01:10,  2.39it/s,
# Running rollout with at most 400 steps:  58%|▌| 232/400 [01:40<01:10,  2.39it/s,
# Running rollout with at most 400 steps:  58%|▌| 233/400 [01:40<01:09,  2.39it/s,
# Running rollout with at most 400 steps:  58%|▌| 233/400 [01:40<01:09,  2.39it/s,
# Running rollout with at most 400 steps:  58%|▌| 234/400 [01:40<01:08,  2.41it/s,
# Running rollout with at most 400 steps:  58%|▌| 234/400 [01:41<01:08,  2.41it/s,
# Running rollout with at most 400 steps:  59%|▌| 235/400 [01:41<01:08,  2.41it/s,
# Running rollout with at most 400 steps:  59%|▌| 235/400 [01:41<01:08,  2.41it/s,
# Running rollout with at most 400 steps:  59%|▌| 236/400 [01:41<01:07,  2.41it/s,
# Running rollout with at most 400 steps:  59%|▌| 236/400 [01:42<01:07,  2.41it/s,
# Running rollout with at most 400 steps:  59%|▌| 237/400 [01:42<01:07,  2.42it/s,
# Running rollout with at most 400 steps:  59%|▌| 237/400 [01:42<01:07,  2.42it/s,
# Running rollout with at most 400 steps:  60%|▌| 238/400 [01:42<01:06,  2.42it/s,
# Running rollout with at most 400 steps:  60%|▌| 238/400 [01:42<01:06,  2.42it/s,
# Running rollout with at most 400 steps:  60%|▌| 239/400 [01:42<01:12,  2.22it/s,
# Running rollout with at most 400 steps:  60%|▌| 239/400 [01:43<01:12,  2.22it/s,
# Running rollout with at most 400 steps:  60%|▌| 240/400 [01:43<01:10,  2.27it/s,
# Running rollout with at most 400 steps:  60%|▌| 240/400 [01:43<01:10,  2.27it/s,
# Running rollout with at most 400 steps:  60%|▌| 241/400 [01:43<01:08,  2.31it/s,
# Running rollout with at most 400 steps:  60%|▌| 241/400 [01:44<01:08,  2.31it/s,
# Running rollout with at most 400 steps:  60%|▌| 242/400 [01:44<01:07,  2.35it/s,
# Running rollout with at most 400 steps:  60%|▌| 242/400 [01:44<01:07,  2.35it/s,
# Running rollout with at most 400 steps:  61%|▌| 243/400 [01:44<01:06,  2.37it/s,
# Running rollout with at most 400 steps:  61%|▌| 243/400 [01:45<01:06,  2.37it/s,
# Running rollout with at most 400 steps:  61%|▌| 244/400 [01:45<01:05,  2.38it/s,
# Running rollout with at most 400 steps:  61%|▌| 244/400 [01:45<01:05,  2.38it/s,
# ...
# Running rollout with at most 400 steps:  76%|▊| 305/400 [04:18<00:45,  2.08it/s,
# Running rollout with at most 400 steps:  76%|▊| 305/400 [04:19<00:45,  2.08it/s,
# Running rollout with at most 400 steps:  76%|▊| 306/400 [04:19<00:46,  2.01it/s,
# Running rollout with at most 400 steps:  76%|▊| 306/400 [04:19<00:46,  2.01it/s,
# Running rollout with at most 400 steps:  77%|▊| 307/400 [04:19<00:45,  2.07it/s,
# Running rollout with at most 400 steps:  77%|▊| 307/400 [04:20<00:45,  2.07it/s,
# Running rollout with at most 400 steps:  77%|▊| 308/400 [04:20<00:42,  2.15it/s,
# Running rollout with at most 400 steps:  77%|▊| 308/400 [04:20<00:42,  2.15it/s,
# Running rollout with at most 400 steps:  77%|▊| 309/400 [04:20<00:44,  2.03it/s,
# Running rollout with at most 400 steps:  77%|▊| 309/400 [04:21<00:44,  2.03it/s,
# Running rollout with at most 400 steps:  78%|▊| 310/400 [04:21<00:45,  1.99it/s,
# Running rollout with at most 400 steps:  78%|▊| 310/400 [04:21<00:45,  1.99it/s,
# Running rollout with at most 400 steps:  78%|▊| 311/400 [04:21<00:42,  2.10it/s,
# Running rollout with at most 400 steps:  78%|▊| 311/400 [04:22<00:42,  2.10it/s,
# Running rollout with at most 400 steps:  78%|▊| 312/400 [04:22<00:41,  2.14it/s,
# Running rollout with at most 400 steps:  78%|▊| 312/400 [04:22<00:41,  2.14it/s,
# Running rollout with at most 400 steps:  78%|▊| 313/400 [04:22<00:40,  2.14it/s,
# Running rollout with at most 400 steps:  78%|▊| 313/400 [04:23<00:40,  2.14it/s,
# Running rollout with at most 400 steps:  78%|▊| 314/400 [04:23<00:39,  2.20it/s,
# Running rollout with at most 400 steps:  78%|▊| 314/400 [04:23<00:39,  2.20it/s,
# Running rollout with at most 400 steps:  79%|▊| 315/400 [04:23<00:38,  2.22it/s,
# Running rollout with at most 400 steps:  79%|▊| 315/400 [04:24<00:38,  2.22it/s,
# Running rollout with at most 400 steps:  79%|▊| 316/400 [04:24<00:37,  2.22it/s,
# Running rollout with at most 400 steps:  79%|▊| 316/400 [04:24<00:37,  2.22it/s,
# Running rollout with at most 400 steps:  79%|▊| 317/400 [04:24<00:38,  2.17it/s,
# Running rollout with at most 400 steps:  79%|▊| 317/400 [04:24<00:38,  2.17it/s,
# Running rollout with at most 400 steps:  80%|▊| 318/400 [04:24<00:38,  2.16it/s,
# Running rollout with at most 400 steps:  80%|▊| 318/400 [04:25<00:38,  2.16it/s,
# Running rollout with at most 400 steps:  80%|▊| 319/400 [04:25<00:36,  2.19it/s,
# Running rollout with at most 400 steps:  80%|▊| 319/400 [04:25<00:36,  2.19it/s,
# Running rollout with at most 400 steps:  80%|▊| 320/400 [04:25<00:37,  2.15it/s,
# Running rollout with at most 400 steps:  80%|▊| 320/400 [04:26<00:37,  2.15it/s,
# Running rollout with at most 400 steps:  80%|▊| 321/400 [04:26<00:35,  2.23it/s,
# Running rollout with at most 400 steps:  80%|▊| 321/400 [04:26<00:35,  2.23it/s,
# Running rollout with at most 400 steps:  80%|▊| 322/400 [04:26<00:35,  2.19it/s,
# Running rollout with at most 400 steps:  80%|▊| 322/400 [04:27<00:35,  2.19it/s,
# Running rollout with at most 400 steps:  81%|▊| 323/400 [04:27<00:35,  2.17it/s,
# Running rollout with at most 400 steps:  81%|▊| 323/400 [04:27<00:35,  2.17it/s,
# Running rollout with at most 400 steps:  81%|▊| 324/400 [04:27<00:35,  2.15it/s,
# Running rollout with at most 400 steps:  81%|▊| 324/400 [04:28<00:35,  2.15it/s,
# Running rollout with at most 400 steps:  81%|▊| 325/400 [04:28<00:33,  2.22it/s,
# Running rollout with at most 400 steps:  81%|▊| 325/400 [04:28<00:33,  2.22it/s,
# Running rollout with at most 400 steps:  82%|▊| 326/400 [04:28<00:33,  2.22it/s,
# Running rollout with at most 400 steps:  82%|▊| 326/400 [04:29<00:33,  2.22it/s,
# Running rollout with at most 400 steps:  82%|▊| 327/400 [04:29<00:34,  2.14it/s,
# Running rollout with at most 400 steps:  82%|▊| 327/400 [04:29<00:34,  2.14it/s,
# Running rollout with at most 400 steps:  82%|▊| 328/400 [04:29<00:33,  2.16it/s,
# Running rollout with at most 400 steps:  82%|▊| 328/400 [04:30<00:33,  2.16it/s,
# Running rollout with at most 400 steps:  82%|▊| 329/400 [04:30<00:32,  2.19it/s,
# Running rollout with at most 400 steps:  82%|▊| 329/400 [04:30<00:32,  2.19it/s,
# Running rollout with at most 400 steps:  82%|▊| 330/400 [04:30<00:32,  2.17it/s,
# Running rollout with at most 400 steps:  82%|▊| 330/400 [04:31<00:32,  2.17it/s,
# Running rollout with at most 400 steps:  83%|▊| 331/400 [04:31<00:37,  1.85it/s,
# Running rollout with at most 400 steps:  83%|▊| 331/400 [04:31<00:37,  1.85it/s,
# Running rollout with at most 400 steps:  83%|▊| 332/400 [04:31<00:35,  1.89it/s,
# Running rollout with at most 400 steps:  83%|▊| 332/400 [04:32<00:35,  1.89it/s,
# Running rollout with at most 400 steps:  83%|▊| 333/400 [04:32<00:33,  2.01it/s,
# Running rollout with at most 400 steps:  83%|▊| 333/400 [04:32<00:33,  2.01it/s,
# Running rollout with at most 400 steps:  84%|▊| 334/400 [04:32<00:32,  2.03it/s,
# Running rollout with at most 400 steps:  84%|▊| 334/400 [04:33<00:32,  2.03it/s,
# Running rollout with at most 400 steps:  84%|▊| 335/400 [04:33<00:32,  2.02it/s,
# Running rollout with at most 400 steps:  84%|▊| 335/400 [04:33<00:32,  2.02it/s,
# Running rollout with at most 400 steps:  84%|▊| 336/400 [04:33<00:31,  2.04it/s,
# Running rollout with at most 400 steps:  84%|▊| 336/400 [04:34<00:31,  2.04it/s,
# Running rollout with at most 400 steps:  84%|▊| 337/400 [04:34<00:33,  1.88it/s,
# Running rollout with at most 400 steps:  84%|▊| 337/400 [04:34<00:33,  1.88it/s,
# Running rollout with at most 400 steps:  84%|▊| 338/400 [04:34<00:31,  1.96it/s,
# Running rollout with at most 400 steps:  84%|▊| 338/400 [04:35<00:31,  1.96it/s,
# Running rollout with at most 400 steps:  85%|▊| 339/400 [04:35<00:30,  2.03it/s,
# Running rollout with at most 400 steps:  85%|▊| 339/400 [04:35<00:30,  2.03it/s,
# Running rollout with at most 400 steps:  85%|▊| 340/400 [04:35<00:27,  2.15it/s,
# Running rollout with at most 400 steps:  85%|▊| 340/400 [04:36<00:27,  2.15it/s,
# Running rollout with at most 400 steps:  85%|▊| 341/400 [04:36<00:28,  2.09it/s,
# Running rollout with at most 400 steps:  85%|▊| 341/400 [04:36<00:28,  2.09it/s,
# Running rollout with at most 400 steps:  86%|▊| 342/400 [04:36<00:27,  2.10it/s,
# Running rollout with at most 400 steps:  86%|▊| 342/400 [04:36<00:27,  2.10it/s,
# Running rollout with at most 400 steps:  86%|▊| 343/400 [04:36<00:27,  2.11it/s,
# Running rollout with at most 400 steps:  86%|▊| 343/400 [04:37<00:27,  2.11it/s,
# Running rollout with at most 400 steps:  86%|▊| 344/400 [04:37<00:26,  2.14it/s,
# Running rollout with at most 400 steps:  86%|▊| 344/400 [04:37<00:26,  2.14it/s,
# Running rollout with at most 400 steps:  86%|▊| 345/400 [04:37<00:25,  2.12it/s,
# Running rollout with at most 400 steps:  86%|▊| 345/400 [04:38<00:25,  2.12it/s,
# Running rollout with at most 400 steps:  86%|▊| 346/400 [04:38<00:24,  2.22it/s,
# Running rollout with at most 400 steps:  86%|▊| 346/400 [04:38<00:24,  2.22it/s,
# Running rollout with at most 400 steps:  87%|▊| 347/400 [04:38<00:24,  2.18it/s,
# Running rollout with at most 400 steps:  87%|▊| 347/400 [04:39<00:24,  2.18it/s,
# Running rollout with at most 400 steps:  87%|▊| 348/400 [04:39<00:24,  2.13it/s,
# Running rollout with at most 400 steps:  87%|▊| 348/400 [04:39<00:24,  2.13it/s,
# Running rollout with at most 400 steps:  87%|▊| 349/400 [04:39<00:23,  2.19it/s,
# Running rollout with at most 400 steps:  87%|▊| 349/400 [04:40<00:23,  2.19it/s,
# Running rollout with at most 400 steps:  88%|▉| 350/400 [04:40<00:22,  2.22it/s,
# Running rollout with at most 400 steps:  88%|▉| 350/400 [04:40<00:22,  2.22it/s,
# Running rollout with at most 400 steps:  88%|▉| 351/400 [04:40<00:22,  2.19it/s,
# Running rollout with at most 400 steps:  88%|▉| 351/400 [04:41<00:22,  2.19it/s,
# Running rollout with at most 400 steps:  88%|▉| 352/400 [04:41<00:22,  2.18it/s,
# Running rollout with at most 400 steps:  88%|▉| 352/400 [04:41<00:22,  2.18it/s,
# Running rollout with at most 400 steps:  88%|▉| 353/400 [04:41<00:21,  2.22it/s,
# Running rollout with at most 400 steps:  88%|▉| 353/400 [04:42<00:21,  2.22it/s,
# Running rollout with at most 400 steps:  88%|▉| 354/400 [04:42<00:22,  2.07it/s,
# Running rollout with at most 400 steps:  88%|▉| 354/400 [04:42<00:22,  2.07it/s,
# Running rollout with at most 400 steps:  89%|▉| 355/400 [04:42<00:21,  2.08it/s,
# Running rollout with at most 400 steps:  89%|▉| 355/400 [04:43<00:21,  2.08it/s,
# Running rollout with at most 400 steps:  89%|▉| 356/400 [04:43<00:20,  2.12it/s,
# Running rollout with at most 400 steps:  89%|▉| 356/400 [04:43<00:20,  2.12it/s,
# Running rollout with at most 400 steps:  89%|▉| 357/400 [04:43<00:20,  2.13it/s,
# Running rollout with at most 400 steps:  89%|▉| 357/400 [04:43<00:20,  2.13it/s,
# Running rollout with at most 400 steps:  90%|▉| 358/400 [04:43<00:19,  2.14it/s,
# Running rollout with at most 400 steps:  90%|▉| 358/400 [04:44<00:19,  2.14it/s,
# Running rollout with at most 400 steps:  90%|▉| 359/400 [04:44<00:19,  2.09it/s,
# Running rollout with at most 400 steps:  90%|▉| 359/400 [04:44<00:19,  2.09it/s,
# Running rollout with at most 400 steps:  90%|▉| 360/400 [04:44<00:19,  2.04it/s,
# Running rollout with at most 400 steps:  90%|▉| 360/400 [04:45<00:19,  2.04it/s,
# Running rollout with at most 400 steps:  90%|▉| 361/400 [04:45<00:19,  1.98it/s,
# Running rollout with at most 400 steps:  90%|▉| 361/400 [04:45<00:19,  1.98it/s,
# Running rollout with at most 400 steps:  90%|▉| 362/400 [04:45<00:18,  2.04it/s,
# Running rollout with at most 400 steps:  90%|▉| 362/400 [04:46<00:18,  2.04it/s,
# Running rollout with at most 400 steps:  91%|▉| 363/400 [04:46<00:17,  2.08it/s,
# Running rollout with at most 400 steps:  91%|▉| 363/400 [04:46<00:17,  2.08it/s,
# Running rollout with at most 400 steps:  91%|▉| 364/400 [04:46<00:18,  1.97it/s,
# Running rollout with at most 400 steps:  91%|▉| 364/400 [04:47<00:18,  1.97it/s,
# Running rollout with at most 400 steps:  91%|▉| 365/400 [04:47<00:17,  2.00it/s,
# Running rollout with at most 400 steps:  91%|▉| 365/400 [04:47<00:17,  2.00it/s,
# Running rollout with at most 400 steps:  92%|▉| 366/400 [04:47<00:17,  1.99it/s,
# Running rollout with at most 400 steps:  92%|▉| 366/400 [04:48<00:17,  1.99it/s,
# Running rollout with at most 400 steps:  92%|▉| 367/400 [04:48<00:17,  1.87it/s,
# Running rollout with at most 400 steps:  92%|▉| 367/400 [04:49<00:17,  1.87it/s,
# Running rollout with at most 400 steps:  92%|▉| 368/400 [04:49<00:16,  1.90it/s,
# Running rollout with at most 400 steps:  92%|▉| 368/400 [04:49<00:16,  1.90it/s,
# Running rollout with at most 400 steps:  92%|▉| 369/400 [04:49<00:16,  1.86it/s,
# Running rollout with at most 400 steps:  92%|▉| 369/400 [04:50<00:16,  1.86it/s,
# Running rollout with at most 400 steps:  92%|▉| 370/400 [04:50<00:15,  1.93it/s,
# Running rollout with at most 400 steps:  92%|▉| 370/400 [04:50<00:15,  1.93it/s,
# Running rollout with at most 400 steps:  93%|▉| 371/400 [04:50<00:14,  1.96it/s,
# Running rollout with at most 400 steps:  93%|▉| 371/400 [04:51<00:14,  1.96it/s,
# Running rollout with at most 400 steps:  93%|▉| 372/400 [04:51<00:15,  1.86it/s,
# Running rollout with at most 400 steps:  93%|▉| 372/400 [04:51<00:15,  1.86it/s,
# Running rollout with at most 400 steps:  93%|▉| 373/400 [04:51<00:14,  1.84it/s,
# Running rollout with at most 400 steps:  93%|▉| 373/400 [04:52<00:14,  1.84it/s,
# Running rollout with at most 400 steps:  94%|▉| 374/400 [04:52<00:14,  1.84it/s,
# Running rollout with at most 400 steps:  94%|▉| 374/400 [04:52<00:14,  1.84it/s,
# Running rollout with at most 400 steps:  94%|▉| 375/400 [04:52<00:14,  1.77it/s,
# Running rollout with at most 400 steps:  94%|▉| 375/400 [04:53<00:14,  1.77it/s,
# Running rollout with at most 400 steps:  94%|▉| 376/400 [04:53<00:13,  1.79it/s,
# Running rollout with at most 400 steps:  94%|▉| 376/400 [04:54<00:13,  1.79it/s,
# Running rollout with at most 400 steps:  94%|▉| 377/400 [04:54<00:12,  1.77it/s,
# Running rollout with at most 400 steps:  94%|▉| 377/400 [04:54<00:12,  1.77it/s,
# Running rollout with at most 400 steps:  94%|▉| 378/400 [04:54<00:12,  1.74it/s,
# Running rollout with at most 400 steps:  94%|▉| 378/400 [04:55<00:12,  1.74it/s,
# Running rollout with at most 400 steps:  95%|▉| 379/400 [04:55<00:12,  1.74it/s,
# Running rollout with at most 400 steps:  95%|▉| 379/400 [04:55<00:12,  1.74it/s,
# Running rollout with at most 400 steps:  95%|▉| 380/400 [04:55<00:10,  1.83it/s,
# Running rollout with at most 400 steps:  95%|▉| 380/400 [04:56<00:10,  1.83it/s,
# Running rollout with at most 400 steps:  95%|▉| 381/400 [04:56<00:09,  1.91it/s,
# Running rollout with at most 400 steps:  95%|▉| 381/400 [04:56<00:09,  1.91it/s,
# Running rollout with at most 400 steps:  96%|▉| 382/400 [04:56<00:09,  1.84it/s,
# Running rollout with at most 400 steps:  96%|▉| 382/400 [04:57<00:09,  1.84it/s,
# Running rollout with at most 400 steps:  96%|▉| 383/400 [04:57<00:09,  1.77it/s,
# Running rollout with at most 400 steps:  96%|▉| 383/400 [04:57<00:09,  1.77it/s,
# Running rollout with at most 400 steps:  96%|▉| 384/400 [04:57<00:09,  1.76it/s,
# Running rollout with at most 400 steps:  96%|▉| 384/400 [04:58<00:09,  1.76it/s,
# Running rollout with at most 400 steps:  96%|▉| 385/400 [04:58<00:08,  1.71it/s,
# Running rollout with at most 400 steps:  96%|▉| 385/400 [04:59<00:08,  1.71it/s,
# Running rollout with at most 400 steps:  96%|▉| 386/400 [04:59<00:08,  1.70it/s,
# Running rollout with at most 400 steps:  96%|▉| 386/400 [04:59<00:08,  1.70it/s,
# Running rollout with at most 400 steps:  97%|▉| 387/400 [04:59<00:07,  1.71it/s,
# Running rollout with at most 400 steps:  97%|▉| 387/400 [05:00<00:07,  1.71it/s,
# Running rollout with at most 400 steps:  97%|▉| 388/400 [05:00<00:07,  1.67it/s,
# Running rollout with at most 400 steps:  97%|▉| 388/400 [05:00<00:07,  1.67it/s,
# Running rollout with at most 400 steps:  97%|▉| 389/400 [05:00<00:06,  1.68it/s,
# Running rollout with at most 400 steps:  97%|▉| 389/400 [05:01<00:06,  1.68it/s,
# Running rollout with at most 400 steps:  98%|▉| 390/400 [05:01<00:05,  1.78it/s,
# Running rollout with at most 400 steps:  98%|▉| 390/400 [05:01<00:05,  1.78it/s,
# Running rollout with at most 400 steps:  98%|▉| 391/400 [05:01<00:04,  1.88it/s,
# Running rollout with at most 400 steps:  98%|▉| 391/400 [05:02<00:04,  1.88it/s,
# Running rollout with at most 400 steps:  98%|▉| 392/400 [05:02<00:04,  1.99it/s,
# Running rollout with at most 400 steps:  98%|▉| 392/400 [05:02<00:04,  1.99it/s,
# Running rollout with at most 400 steps:  98%|▉| 393/400 [05:02<00:03,  2.04it/s,
# Running rollout with at most 400 steps:  98%|▉| 393/400 [05:03<00:03,  2.04it/s,
# Running rollout with at most 400 steps:  98%|▉| 394/400 [05:03<00:02,  2.02it/s,
# Running rollout with at most 400 steps:  98%|▉| 394/400 [05:03<00:02,  2.02it/s,
# Running rollout with at most 400 steps:  99%|▉| 395/400 [05:03<00:02,  2.13it/s,
# Running rollout with at most 400 steps:  99%|▉| 395/400 [05:04<00:02,  2.13it/s,
# Running rollout with at most 400 steps:  99%|▉| 396/400 [05:04<00:01,  2.25it/s,
# Running rollout with at most 400 steps:  99%|▉| 396/400 [05:04<00:01,  2.25it/s,
# Running rollout with at most 400 steps:  99%|▉| 397/400 [05:04<00:01,  2.23it/s,
# Running rollout with at most 400 steps:  99%|▉| 397/400 [05:05<00:01,  2.23it/s,
# Running rollout with at most 400 steps: 100%|▉| 398/400 [05:05<00:00,  2.17it/s,
# Running rollout with at most 400 steps: 100%|▉| 398/400 [05:05<00:00,  2.17it/s,
# Running rollout with at most 400 steps: 100%|▉| 399/400 [05:05<00:00,  2.24it/s,
# Running rollout with at most 400 steps: 100%|▉| 399/400 [05:06<00:00,  2.24it/s,
# Running rollout with at most 400 steps: 100%|█| 400/400 [05:06<00:00,  1.81it/s,
# Stepping through eval batches: 100%|█| 1/1 [05:08<00:00, 308.06s/it, running_suc
# INFO 2025-09-10 13:34:28 ts/train.py:275 step:4K smpl:64K ep:160 epch:3.20 ∑rwrd:127.080 success:28.0 eval_s:309.798
# INFO 2025-09-10 13:35:20 ts/train.py:232 step:4K smpl:67K ep:168 epch:3.36 loss:0.291 grdn:18.138 lr:1.0e-05 updt_s:0.259 data_s:0.000
# INFO 2025-09-10 13:36:12 ts/train.py:232 step:4K smpl:70K ep:176 epch:3.52 loss:0.270 grdn:17.480 lr:1.0e-05 updt_s:0.260 data_s:0.000

# %% [markdown]
# ## Resume the training

# %%
config_path = os.path.join(output_dir, "checkpoints/last/pretrained_model/train_config.json")
print(config_path)
# Out:
# ./temp/outputs/aloha_sim_transfer_cube_human/checkpoints/last/pretrained_model/train_config.json

# %%
# !python -m lerobot.scripts.train \
    --config_path=$config_path \
    --resume=true
# Out:
# INFO 2025-09-10 16:22:47 ts/train.py:111 {'batch_size': 16,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'lerobot/aloha_sim_transfer_cube_human',
#              'revision': None,
#              'root': None,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': {'episode_length': 400,
#          'features': {'action': {'shape': [14],
#                                  'type': <FeatureType.ACTION: 'ACTION'>},
#                       'agent_pos': {'shape': [14],
#                                     'type': <FeatureType.STATE: 'STATE'>},
#                       'pixels/top': {'shape': [480, 640, 3],
#                                      'type': <FeatureType.VISUAL: 'VISUAL'>}},
#          'features_map': {'action': 'action',
#                           'agent_pos': 'observation.state',
#                           'pixels/top': 'observation.images.top',
#                           'top': 'observation.image.top'},
#          'fps': 50,
#          'obs_type': 'pixels_agent_pos',
#          'render_mode': 'rgb_array',
#          'task': 'AlohaTransferCube-v0',
#          'type': 'aloha'},
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 500,
#  'job_name': 'aloha_act',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'temp/outputs/aloha_sim_transfer_cube_human',
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {'observation.images.top': {'shape': [3,
#                                                                     480,
#                                                                     640],
#                                                           'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                'observation.state': {'shape': [14],
#                                                      'type': <FeatureType.STATE: 'STATE'>}},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {'action': {'shape': [14],
#                                            'type': <FeatureType.ACTION: 'ACTION'>}},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'private': None,
#             'push_to_hub': False,
#             'replace_final_stride_with_dilation': 0,
#             'repo_id': None,
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'resume': True,
#  'save_checkpoint': True,
#  'save_freq': 500,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 20000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': False,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2025-09-10 16:22:47 ts/train.py:117 Logs will be saved locally.
# INFO 2025-09-10 16:22:47 ts/train.py:127 Creating dataset
# Resolving data files: 100%|█████████████████| 50/50 [00:00<00:00, 450032.62it/s]
# INFO 2025-09-10 16:22:48 ts/train.py:135 Creating env
# INFO 2025-09-10 16:22:48 /__init__.py:88 MUJOCO_GL is not set, so an OpenGL backend will be chosen automatically.
# INFO 2025-09-10 16:22:48 /__init__.py:96 Successfully imported OpenGL backend: glfw
# INFO 2025-09-10 16:22:48 /__init__.py:31 MuJoCo library version is: 2.3.7
# INFO 2025-09-10 16:22:52 ts/train.py:138 Creating policy
# Loading weights from local directory
# INFO 2025-09-10 16:22:53 ts/train.py:144 Creating optimizer and scheduler
# INFO 2025-09-10 16:22:54 ts/train.py:156 Output dir: temp/outputs/aloha_sim_transfer_cube_human
# INFO 2025-09-10 16:22:54 ts/train.py:158 cfg.env.task='AlohaTransferCube-v0'
# INFO 2025-09-10 16:22:54 ts/train.py:159 cfg.steps=20000 (20K)
# INFO 2025-09-10 16:22:54 ts/train.py:160 dataset.num_frames=20000 (20K)
# INFO 2025-09-10 16:22:54 ts/train.py:161 dataset.num_episodes=50
# INFO 2025-09-10 16:22:54 ts/train.py:162 num_learnable_params=51613582 (52M)
# INFO 2025-09-10 16:22:54 ts/train.py:163 num_total_params=51613672 (52M)
# INFO 2025-09-10 16:22:54 ts/train.py:202 Start offline training on a fixed dataset
# INFO 2025-09-10 16:23:23 ts/train.py:232 step:18K smpl:282K ep:704 epch:14.08 loss:0.078 grdn:6.581 lr:1.0e-05 updt_s:0.277 data_s:0.012
# INFO 2025-09-10 16:24:07 ts/train.py:232 step:18K smpl:285K ep:712 epch:14.24 loss:0.078 grdn:6.859 lr:1.0e-05 updt_s:0.218 data_s:0.000
# INFO 2025-09-10 16:24:51 ts/train.py:232 step:18K smpl:288K ep:720 epch:14.40 loss:0.076 grdn:6.723 lr:1.0e-05 updt_s:0.219 data_s:0.000
# INFO 2025-09-10 16:24:51 ts/train.py:241 Checkpoint policy after step 18000
# INFO 2025-09-10 16:24:52 ts/train.py:250 Eval policy at step 18000
# Stepping through eval batches:   0%|                      | 0/1 [00:00<?, ?it/s]
# Running rollout with at most 400 steps:   0%|           | 0/400 [00:00<?, ?it/s]/home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.task_description to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.task_description` for environment variables or `env.get_wrapper_attr('task_description')` that will search the reminding wrappers.
#   logger.warn(
# /home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/lerobot/scripts/eval.py:147: UserWarning: The environment does not have 'task_description' and 'task'. Some policies require these features.
#   check_env_attributes_and_types(env)
# /home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.task_description to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.task_description` for environment variables or `env.get_wrapper_attr('task_description')` that will search the reminding wrappers.
#   logger.warn(
# /home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.task to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.task` for environment variables or `env.get_wrapper_attr('task')` that will search the reminding wrappers.
#   logger.warn(
#
# Running rollout with at most 400 steps:   0%| | 0/400 [00:02<?, ?it/s, running_s
# Running rollout with at most 400 steps:   0%| | 1/400 [00:02<16:01,  2.41s/it, r
# Running rollout with at most 400 steps:   0%| | 1/400 [00:02<16:01,  2.41s/it, r
# Running rollout with at most 400 steps:   0%| | 2/400 [00:02<08:04,  1.22s/it, r
# Running rollout with at most 400 steps:   0%| | 2/400 [00:03<08:04,  1.22s/it, r
# Running rollout with at most 400 steps:   1%| | 3/400 [00:03<05:30,  1.20it/s, r
# Running rollout with at most 400 steps:   1%| | 3/400 [00:03<05:30,  1.20it/s, r
# Running rollout with at most 400 steps:   1%| | 4/400 [00:03<04:35,  1.44it/s, r
# Running rollout with at most 400 steps:   1%| | 4/400 [00:04<04:35,  1.44it/s, r
# Running rollout with at most 400 steps:   1%| | 5/400 [00:04<03:48,  1.73it/s, r
# Running rollout with at most 400 steps:   1%| | 5/400 [00:04<03:48,  1.73it/s, r
# Running rollout with at most 400 steps:   2%| | 6/400 [00:04<03:21,  1.96it/s, r
# Running rollout with at most 400 steps:   2%| | 6/400 [00:04<03:21,  1.96it/s, r
# Running rollout with at most 400 steps:   2%| | 7/400 [00:04<03:04,  2.14it/s, r
# Running rollout with at most 400 steps:   2%| | 7/400 [00:05<03:04,  2.14it/s, r
# Running rollout with at most 400 steps:   2%| | 8/400 [00:05<02:52,  2.27it/s, r
# Running rollout with at most 400 steps:   2%| | 8/400 [00:05<02:52,  2.27it/s, r
# Running rollout with at most 400 steps:   2%| | 9/400 [00:05<02:44,  2.37it/s, r
# Running rollout with at most 400 steps:   2%| | 9/400 [00:05<02:44,  2.37it/s, r
# Running rollout with at most 400 steps:   2%| | 10/400 [00:05<02:40,  2.44it/s,
# Running rollout with at most 400 steps:   2%| | 10/400 [00:06<02:40,  2.44it/s,
# Running rollout with at most 400 steps:   3%| | 11/400 [00:06<02:36,  2.49it/s,
# Running rollout with at most 400 steps:   3%| | 11/400 [00:06<02:36,  2.49it/s,
# Running rollout with at most 400 steps:   3%| | 12/400 [00:06<02:34,  2.51it/s,
# Running rollout with at most 400 steps:   3%| | 12/400 [00:07<02:34,  2.51it/s,
# Running rollout with at most 400 steps:   3%| | 13/400 [00:07<02:32,  2.53it/s,
# Running rollout with at most 400 steps:   3%| | 13/400 [00:07<02:32,  2.53it/s,
# Running rollout with at most 400 steps:   4%| | 14/400 [00:07<02:30,  2.56it/s,
# Running rollout with at most 400 steps:   4%| | 14/400 [00:07<02:30,  2.56it/s,
# Running rollout with at most 400 steps:   4%| | 15/400 [00:07<02:29,  2.57it/s,
# Running rollout with at most 400 steps:   4%| | 15/400 [00:08<02:29,  2.57it/s,
# Running rollout with at most 400 steps:   4%| | 16/400 [00:08<02:29,  2.58it/s,
# Running rollout with at most 400 steps:   4%| | 16/400 [00:08<02:29,  2.58it/s,
# Running rollout with at most 400 steps:   4%| | 17/400 [00:08<02:28,  2.59it/s,
# Running rollout with at most 400 steps:   4%| | 17/400 [00:09<02:28,  2.59it/s,
# Running rollout with at most 400 steps:   4%| | 18/400 [00:09<02:27,  2.59it/s,
# Running rollout with at most 400 steps:   4%| | 18/400 [00:09<02:27,  2.59it/s,
# Running rollout with at most 400 steps:   5%| | 19/400 [00:09<02:26,  2.61it/s,
# Running rollout with at most 400 steps:   5%| | 19/400 [00:09<02:26,  2.61it/s,
# Running rollout with at most 400 steps:   5%| | 20/400 [00:09<02:37,  2.42it/s,
# Running rollout with at most 400 steps:   5%| | 20/400 [00:10<02:37,  2.42it/s,
# Running rollout with at most 400 steps:   5%| | 21/400 [00:10<02:35,  2.45it/s,
# Running rollout with at most 400 steps:   5%| | 21/400 [00:10<02:35,  2.45it/s,
# Running rollout with at most 400 steps:   6%| | 22/400 [00:10<02:33,  2.47it/s,
# Running rollout with at most 400 steps:   6%| | 22/400 [00:11<02:33,  2.47it/s,
# Running rollout with at most 400 steps:   6%| | 23/400 [00:11<02:31,  2.49it/s,
# Running rollout with at most 400 steps:   6%| | 23/400 [00:11<02:31,  2.49it/s,
# Running rollout with at most 400 steps:   6%| | 24/400 [00:11<02:28,  2.53it/s,
# Running rollout with at most 400 steps:   6%| | 24/400 [00:11<02:28,  2.53it/s,
# Running rollout with at most 400 steps:   6%| | 25/400 [00:11<02:27,  2.55it/s,
# Running rollout with at most 400 steps:   6%| | 25/400 [00:12<02:27,  2.55it/s,
# Running rollout with at most 400 steps:   6%| | 26/400 [00:12<02:24,  2.58it/s,
# Running rollout with at most 400 steps:   6%| | 26/400 [00:12<02:24,  2.58it/s,
# Running rollout with at most 400 steps:   7%| | 27/400 [00:12<02:25,  2.57it/s,
# Running rollout with at most 400 steps:   7%| | 27/400 [00:12<02:25,  2.57it/s,
# Running rollout with at most 400 steps:   7%| | 28/400 [00:12<02:23,  2.59it/s,
# Running rollout with at most 400 steps:   7%| | 28/400 [00:13<02:23,  2.59it/s,
# Running rollout with at most 400 steps:   7%| | 29/400 [00:13<02:22,  2.60it/s,
# Running rollout with at most 400 steps:   7%| | 29/400 [00:13<02:22,  2.60it/s,
# Running rollout with at most 400 steps:   8%| | 30/400 [00:13<02:21,  2.61it/s,
# Running rollout with at most 400 steps:   8%| | 30/400 [00:14<02:21,  2.61it/s,
# Running rollout with at most 400 steps:   8%| | 31/400 [00:14<02:48,  2.19it/s,
# Running rollout with at most 400 steps:   8%| | 31/400 [00:14<02:48,  2.19it/s,
# Running rollout with at most 400 steps:   8%| | 32/400 [00:14<02:40,  2.30it/s,
# Running rollout with at most 400 steps:   8%| | 32/400 [00:15<02:40,  2.30it/s,
# Running rollout with at most 400 steps:   8%| | 33/400 [00:15<02:33,  2.39it/s,
# Running rollout with at most 400 steps:   8%| | 33/400 [00:15<02:33,  2.39it/s,
# Running rollout with at most 400 steps:   8%| | 34/400 [00:15<02:30,  2.44it/s,
# Running rollout with at most 400 steps:   8%| | 34/400 [00:15<02:30,  2.44it/s,
# Running rollout with at most 400 steps:   9%| | 35/400 [00:15<02:26,  2.48it/s,
# Running rollout with at most 400 steps:   9%| | 35/400 [00:16<02:26,  2.48it/s,
# Running rollout with at most 400 steps:   9%| | 36/400 [00:16<02:23,  2.53it/s,
# Running rollout with at most 400 steps:   9%| | 36/400 [00:16<02:23,  2.53it/s,
# Running rollout with at most 400 steps:   9%| | 37/400 [00:16<02:22,  2.55it/s,
# Running rollout with at most 400 steps:   9%| | 37/400 [00:17<02:22,  2.55it/s,
# Running rollout with at most 400 steps:  10%| | 38/400 [00:17<02:22,  2.54it/s,
# Running rollout with at most 400 steps:  10%| | 38/400 [00:17<02:22,  2.54it/s,
# Running rollout with at most 400 steps:  10%| | 39/400 [00:17<02:25,  2.48it/s,
# Running rollout with at most 400 steps:  10%| | 39/400 [00:17<02:25,  2.48it/s,
# Running rollout with at most 400 steps:  10%| | 40/400 [00:17<02:29,  2.42it/s,
# Running rollout with at most 400 steps:  10%| | 40/400 [00:18<02:29,  2.42it/s,
# Running rollout with at most 400 steps:  10%| | 41/400 [00:18<02:25,  2.46it/s,
# Running rollout with at most 400 steps:  10%| | 41/400 [00:18<02:25,  2.46it/s,
# Running rollout with at most 400 steps:  10%| | 42/400 [00:18<02:22,  2.51it/s,
# Running rollout with at most 400 steps:  10%| | 42/400 [00:19<02:22,  2.51it/s,
# Running rollout with at most 400 steps:  11%| | 43/400 [00:19<02:20,  2.53it/s,
# Running rollout with at most 400 steps:  11%| | 43/400 [00:19<02:20,  2.53it/s,
# Running rollout with at most 400 steps:  11%| | 44/400 [00:19<02:19,  2.56it/s,
# Running rollout with at most 400 steps:  11%| | 44/400 [00:19<02:19,  2.56it/s,
# Running rollout with at most 400 steps:  11%| | 45/400 [00:19<02:19,  2.55it/s,
# Running rollout with at most 400 steps:  11%| | 45/400 [00:20<02:19,  2.55it/s,
# Running rollout with at most 400 steps:  12%| | 46/400 [00:20<02:18,  2.56it/s,
# Running rollout with at most 400 steps:  12%| | 46/400 [00:20<02:18,  2.56it/s,
# Running rollout with at most 400 steps:  12%| | 47/400 [00:20<02:32,  2.32it/s,
# Running rollout with at most 400 steps:  12%| | 47/400 [00:21<02:32,  2.32it/s,
# Running rollout with at most 400 steps:  12%| | 48/400 [00:21<02:26,  2.40it/s,
# Running rollout with at most 400 steps:  12%| | 48/400 [00:21<02:26,  2.40it/s,
# Running rollout with at most 400 steps:  12%| | 49/400 [00:21<02:23,  2.45it/s,
# Running rollout with at most 400 steps:  12%| | 49/400 [00:21<02:23,  2.45it/s,
# Running rollout with at most 400 steps:  12%|▏| 50/400 [00:21<02:20,  2.49it/s,
# Running rollout with at most 400 steps:  12%|▏| 50/400 [00:22<02:20,  2.49it/s,
# Running rollout with at most 400 steps:  13%|▏| 51/400 [00:22<02:18,  2.52it/s,
# Running rollout with at most 400 steps:  13%|▏| 51/400 [00:22<02:18,  2.52it/s,
# Running rollout with at most 400 steps:  13%|▏| 52/400 [00:22<02:17,  2.53it/s,
# Running rollout with at most 400 steps:  13%|▏| 52/400 [00:23<02:17,  2.53it/s,
# Running rollout with at most 400 steps:  13%|▏| 53/400 [00:23<02:20,  2.47it/s,
# Running rollout with at most 400 steps:  13%|▏| 53/400 [00:23<02:20,  2.47it/s,
# Running rollout with at most 400 steps:  14%|▏| 54/400 [00:23<02:23,  2.41it/s,
# Running rollout with at most 400 steps:  14%|▏| 54/400 [00:23<02:23,  2.41it/s,
# Running rollout with at most 400 steps:  14%|▏| 55/400 [00:23<02:20,  2.45it/s,
# Running rollout with at most 400 steps:  14%|▏| 55/400 [00:24<02:20,  2.45it/s,
# Running rollout with at most 400 steps:  14%|▏| 56/400 [00:24<02:17,  2.51it/s,
# Running rollout with at most 400 steps:  14%|▏| 56/400 [00:24<02:17,  2.51it/s,
# Running rollout with at most 400 steps:  14%|▏| 57/400 [00:24<02:15,  2.53it/s,
# Running rollout with at most 400 steps:  14%|▏| 57/400 [00:25<02:15,  2.53it/s,
# Running rollout with at most 400 steps:  14%|▏| 58/400 [00:25<02:20,  2.44it/s,
# Running rollout with at most 400 steps:  14%|▏| 58/400 [00:25<02:20,  2.44it/s,
# Running rollout with at most 400 steps:  15%|▏| 59/400 [00:25<02:19,  2.44it/s,
# Running rollout with at most 400 steps:  15%|▏| 59/400 [00:25<02:19,  2.44it/s,
# Running rollout with at most 400 steps:  15%|▏| 60/400 [00:25<02:19,  2.44it/s,
# Running rollout with at most 400 steps:  15%|▏| 60/400 [00:26<02:19,  2.44it/s,
# Running rollout with at most 400 steps:  15%|▏| 61/400 [00:26<02:16,  2.48it/s,
# Running rollout with at most 400 steps:  15%|▏| 61/400 [00:26<02:16,  2.48it/s,
# Running rollout with at most 400 steps:  16%|▏| 62/400 [00:26<02:16,  2.48it/s,
# Running rollout with at most 400 steps:  16%|▏| 62/400 [00:27<02:16,  2.48it/s,
# Running rollout with at most 400 steps:  16%|▏| 63/400 [00:27<02:14,  2.50it/s,
# Running rollout with at most 400 steps:  16%|▏| 63/400 [00:27<02:14,  2.50it/s,
# Running rollout with at most 400 steps:  16%|▏| 64/400 [00:27<02:13,  2.52it/s,
# Running rollout with at most 400 steps:  16%|▏| 64/400 [00:27<02:13,  2.52it/s,
# Running rollout with at most 400 steps:  16%|▏| 65/400 [00:27<02:12,  2.54it/s,
# Running rollout with at most 400 steps:  16%|▏| 65/400 [00:28<02:12,  2.54it/s,
# Running rollout with at most 400 steps:  16%|▏| 66/400 [00:28<02:11,  2.54it/s,
# Running rollout with at most 400 steps:  16%|▏| 66/400 [00:28<02:11,  2.54it/s,
# Running rollout with at most 400 steps:  17%|▏| 67/400 [00:28<02:10,  2.55it/s,
# Running rollout with at most 400 steps:  17%|▏| 67/400 [00:29<02:10,  2.55it/s,
# Running rollout with at most 400 steps:  17%|▏| 68/400 [00:29<02:16,  2.43it/s,
# Running rollout with at most 400 steps:  17%|▏| 68/400 [00:29<02:16,  2.43it/s,
# Running rollout with at most 400 steps:  17%|▏| 69/400 [00:29<02:16,  2.42it/s,
# Running rollout with at most 400 steps:  17%|▏| 69/400 [00:29<02:16,  2.42it/s,
# Running rollout with at most 400 steps:  18%|▏| 70/400 [00:29<02:13,  2.48it/s,
# Running rollout with at most 400 steps:  18%|▏| 70/400 [00:30<02:13,  2.48it/s,
# Running rollout with at most 400 steps:  18%|▏| 71/400 [00:30<02:10,  2.51it/s,
# Running rollout with at most 400 steps:  18%|▏| 71/400 [00:30<02:10,  2.51it/s,
# Running rollout with at most 400 steps:  18%|▏| 72/400 [00:30<02:10,  2.52it/s,
# Running rollout with at most 400 steps:  18%|▏| 72/400 [00:31<02:10,  2.52it/s,
# Running rollout with at most 400 steps:  18%|▏| 73/400 [00:31<02:08,  2.54it/s,
# Running rollout with at most 400 steps:  18%|▏| 73/400 [00:31<02:08,  2.54it/s,
# Running rollout with at most 400 steps:  18%|▏| 74/400 [00:31<02:07,  2.56it/s,
# Running rollout with at most 400 steps:  18%|▏| 74/400 [00:31<02:07,  2.56it/s,
# Running rollout with at most 400 steps:  19%|▏| 75/400 [00:31<02:06,  2.57it/s,
# Running rollout with at most 400 steps:  19%|▏| 75/400 [00:32<02:06,  2.57it/s,
# Running rollout with at most 400 steps:  19%|▏| 76/400 [00:32<02:06,  2.56it/s,
# Running rollout with at most 400 steps:  19%|▏| 76/400 [00:32<02:06,  2.56it/s,
# Running rollout with at most 400 steps:  19%|▏| 77/400 [00:32<02:05,  2.57it/s,
# Running rollout with at most 400 steps:  19%|▏| 77/400 [00:33<02:05,  2.57it/s,
# Running rollout with at most 400 steps:  20%|▏| 78/400 [00:33<02:04,  2.58it/s,
# Running rollout with at most 400 steps:  20%|▏| 78/400 [00:33<02:04,  2.58it/s,
# Running rollout with at most 400 steps:  20%|▏| 79/400 [00:33<02:04,  2.57it/s,
# Running rollout with at most 400 steps:  20%|▏| 79/400 [00:33<02:04,  2.57it/s,
# Running rollout with at most 400 steps:  20%|▏| 80/400 [00:33<02:04,  2.58it/s,
# Running rollout with at most 400 steps:  20%|▏| 80/400 [00:34<02:04,  2.58it/s,
# Running rollout with at most 400 steps:  20%|▏| 81/400 [00:34<02:16,  2.34it/s,
# Running rollout with at most 400 steps:  20%|▏| 81/400 [00:34<02:16,  2.34it/s,
# Running rollout with at most 400 steps:  20%|▏| 82/400 [00:34<02:12,  2.40it/s,
# Running rollout with at most 400 steps:  20%|▏| 82/400 [00:35<02:12,  2.40it/s,
# Running rollout with at most 400 steps:  21%|▏| 83/400 [00:35<02:09,  2.45it/s,
# Running rollout with at most 400 steps:  21%|▏| 83/400 [00:35<02:09,  2.45it/s,
# Running rollout with at most 400 steps:  21%|▏| 84/400 [00:35<02:07,  2.48it/s,
# Running rollout with at most 400 steps:  21%|▏| 84/400 [00:35<02:07,  2.48it/s,
# Running rollout with at most 400 steps:  21%|▏| 85/400 [00:35<02:05,  2.51it/s,
# Running rollout with at most 400 steps:  21%|▏| 85/400 [00:36<02:05,  2.51it/s,
# Running rollout with at most 400 steps:  22%|▏| 86/400 [00:36<02:13,  2.35it/s,
# Running rollout with at most 400 steps:  22%|▏| 86/400 [00:36<02:13,  2.35it/s,
# Running rollout with at most 400 steps:  22%|▏| 87/400 [00:36<02:09,  2.41it/s,
# Running rollout with at most 400 steps:  22%|▏| 87/400 [00:37<02:09,  2.41it/s,
# Running rollout with at most 400 steps:  22%|▏| 88/400 [00:37<02:15,  2.30it/s,
# Running rollout with at most 400 steps:  22%|▏| 88/400 [00:37<02:15,  2.30it/s,
# Running rollout with at most 400 steps:  22%|▏| 89/400 [00:37<02:11,  2.37it/s,
# Running rollout with at most 400 steps:  22%|▏| 89/400 [00:38<02:11,  2.37it/s,
# Running rollout with at most 400 steps:  22%|▏| 90/400 [00:38<02:07,  2.44it/s,
# Running rollout with at most 400 steps:  22%|▏| 90/400 [00:38<02:07,  2.44it/s,
# Running rollout with at most 400 steps:  23%|▏| 91/400 [00:38<02:04,  2.48it/s,
# Running rollout with at most 400 steps:  23%|▏| 91/400 [00:38<02:04,  2.48it/s,
# Running rollout with at most 400 steps:  23%|▏| 92/400 [00:38<02:02,  2.51it/s,
# Running rollout with at most 400 steps:  23%|▏| 92/400 [00:39<02:02,  2.51it/s,
# Running rollout with at most 400 steps:  23%|▏| 93/400 [00:39<02:01,  2.53it/s,
# Running rollout with at most 400 steps:  23%|▏| 93/400 [00:39<02:01,  2.53it/s,
# Running rollout with at most 400 steps:  24%|▏| 94/400 [00:39<02:00,  2.55it/s,
# Running rollout with at most 400 steps:  24%|▏| 94/400 [00:40<02:00,  2.55it/s,
# Running rollout with at most 400 steps:  24%|▏| 95/400 [00:40<01:59,  2.55it/s,
# Running rollout with at most 400 steps:  24%|▏| 95/400 [00:40<01:59,  2.55it/s,
# Running rollout with at most 400 steps:  24%|▏| 96/400 [00:40<01:58,  2.56it/s,
# Running rollout with at most 400 steps:  24%|▏| 96/400 [00:40<01:58,  2.56it/s,
# Running rollout with at most 400 steps:  24%|▏| 97/400 [00:40<01:57,  2.57it/s,
# Running rollout with at most 400 steps:  24%|▏| 97/400 [00:41<01:57,  2.57it/s,
# Running rollout with at most 400 steps:  24%|▏| 98/400 [00:41<01:57,  2.58it/s,
# Running rollout with at most 400 steps:  24%|▏| 98/400 [00:41<01:57,  2.58it/s,
# Running rollout with at most 400 steps:  25%|▏| 99/400 [00:41<01:56,  2.59it/s,
# Running rollout with at most 400 steps:  25%|▏| 99/400 [00:41<01:56,  2.59it/s,
# Running rollout with at most 400 steps:  25%|▎| 100/400 [00:41<01:56,  2.58it/s,
# Running rollout with at most 400 steps:  25%|▎| 100/400 [00:42<01:56,  2.58it/s,
# Running rollout with at most 400 steps:  25%|▎| 101/400 [00:42<02:13,  2.23it/s,
# Running rollout with at most 400 steps:  25%|▎| 101/400 [00:42<02:13,  2.23it/s,
# Running rollout with at most 400 steps:  26%|▎| 102/400 [00:42<02:09,  2.30it/s,
# Running rollout with at most 400 steps:  26%|▎| 102/400 [00:43<02:09,  2.30it/s,
# Running rollout with at most 400 steps:  26%|▎| 103/400 [00:43<02:04,  2.38it/s,
# Running rollout with at most 400 steps:  26%|▎| 103/400 [00:43<02:04,  2.38it/s,
# Running rollout with at most 400 steps:  26%|▎| 104/400 [00:43<02:02,  2.42it/s,
# Running rollout with at most 400 steps:  26%|▎| 104/400 [00:44<02:02,  2.42it/s,
# Running rollout with at most 400 steps:  26%|▎| 105/400 [00:44<01:59,  2.46it/s,
# Running rollout with at most 400 steps:  26%|▎| 105/400 [00:44<01:59,  2.46it/s,
# Running rollout with at most 400 steps:  26%|▎| 106/400 [00:44<01:57,  2.50it/s,
# Running rollout with at most 400 steps:  26%|▎| 106/400 [00:44<01:57,  2.50it/s,
# Running rollout with at most 400 steps:  27%|▎| 107/400 [00:44<01:56,  2.52it/s,
# Running rollout with at most 400 steps:  27%|▎| 107/400 [00:45<01:56,  2.52it/s,
# Running rollout with at most 400 steps:  27%|▎| 108/400 [00:45<01:55,  2.53it/s,
# Running rollout with at most 400 steps:  27%|▎| 108/400 [00:45<01:55,  2.53it/s,
# Running rollout with at most 400 steps:  27%|▎| 109/400 [00:45<01:54,  2.54it/s,
# Running rollout with at most 400 steps:  27%|▎| 109/400 [00:46<01:54,  2.54it/s,
# Running rollout with at most 400 steps:  28%|▎| 110/400 [00:46<01:54,  2.53it/s,
# Running rollout with at most 400 steps:  28%|▎| 110/400 [00:46<01:54,  2.53it/s,
# Running rollout with at most 400 steps:  28%|▎| 111/400 [00:46<01:53,  2.54it/s,
# Running rollout with at most 400 steps:  28%|▎| 111/400 [00:46<01:53,  2.54it/s,
# Running rollout with at most 400 steps:  28%|▎| 112/400 [00:46<01:53,  2.55it/s,
# Running rollout with at most 400 steps:  28%|▎| 112/400 [00:47<01:53,  2.55it/s,
# Running rollout with at most 400 steps:  28%|▎| 113/400 [00:47<01:52,  2.55it/s,
# Running rollout with at most 400 steps:  28%|▎| 113/400 [00:47<01:52,  2.55it/s,
# Running rollout with at most 400 steps:  28%|▎| 114/400 [00:47<01:52,  2.55it/s,
# Running rollout with at most 400 steps:  28%|▎| 114/400 [00:48<01:52,  2.55it/s,
# Running rollout with at most 400 steps:  29%|▎| 115/400 [00:48<01:51,  2.56it/s,
# Running rollout with at most 400 steps:  29%|▎| 115/400 [00:48<01:51,  2.56it/s,
# Running rollout with at most 400 steps:  29%|▎| 116/400 [00:48<01:50,  2.57it/s,
# Running rollout with at most 400 steps:  29%|▎| 116/400 [00:48<01:50,  2.57it/s,
# Running rollout with at most 400 steps:  29%|▎| 117/400 [00:48<01:50,  2.57it/s,
# Running rollout with at most 400 steps:  29%|▎| 117/400 [00:49<01:50,  2.57it/s,
# Running rollout with at most 400 steps:  30%|▎| 118/400 [00:49<01:50,  2.56it/s,
# Running rollout with at most 400 steps:  30%|▎| 118/400 [00:49<01:50,  2.56it/s,
# Running rollout with at most 400 steps:  30%|▎| 119/400 [00:49<01:49,  2.57it/s,
# Running rollout with at most 400 steps:  30%|▎| 119/400 [00:49<01:49,  2.57it/s,
# Running rollout with at most 400 steps:  30%|▎| 120/400 [00:49<01:49,  2.56it/s,
# Running rollout with at most 400 steps:  30%|▎| 120/400 [00:50<01:49,  2.56it/s,
# Running rollout with at most 400 steps:  30%|▎| 121/400 [00:50<01:48,  2.57it/s,
# Running rollout with at most 400 steps:  30%|▎| 121/400 [00:50<01:48,  2.57it/s,
# Running rollout with at most 400 steps:  30%|▎| 122/400 [00:50<01:48,  2.56it/s,
# Running rollout with at most 400 steps:  30%|▎| 122/400 [00:51<01:48,  2.56it/s,
# Running rollout with at most 400 steps:  31%|▎| 123/400 [00:51<01:48,  2.56it/s,
# Running rollout with at most 400 steps:  31%|▎| 123/400 [00:51<01:48,  2.56it/s,
# Running rollout with at most 400 steps:  31%|▎| 124/400 [00:51<01:48,  2.55it/s,
# Running rollout with at most 400 steps:  31%|▎| 124/400 [00:51<01:48,  2.55it/s,
# Running rollout with at most 400 steps:  31%|▎| 125/400 [00:51<01:48,  2.55it/s,
# Running rollout with at most 400 steps:  31%|▎| 125/400 [00:52<01:48,  2.55it/s,
# Running rollout with at most 400 steps:  32%|▎| 126/400 [00:52<01:47,  2.55it/s,
# Running rollout with at most 400 steps:  32%|▎| 126/400 [00:52<01:47,  2.55it/s,
# Running rollout with at most 400 steps:  32%|▎| 127/400 [00:52<01:46,  2.55it/s,
# Running rollout with at most 400 steps:  32%|▎| 127/400 [00:53<01:46,  2.55it/s,
# Running rollout with at most 400 steps:  32%|▎| 128/400 [00:53<01:56,  2.34it/s,
# Running rollout with at most 400 steps:  32%|▎| 128/400 [00:53<01:56,  2.34it/s,
# Running rollout with at most 400 steps:  32%|▎| 129/400 [00:53<01:53,  2.38it/s,
# Running rollout with at most 400 steps:  32%|▎| 129/400 [00:54<01:53,  2.38it/s,
# Running rollout with at most 400 steps:  32%|▎| 130/400 [00:54<01:50,  2.44it/s,
# Running rollout with at most 400 steps:  32%|▎| 130/400 [00:54<01:50,  2.44it/s,
# Running rollout with at most 400 steps:  33%|▎| 131/400 [00:54<01:48,  2.48it/s,
# Running rollout with at most 400 steps:  33%|▎| 131/400 [00:54<01:48,  2.48it/s,
# Running rollout with at most 400 steps:  33%|▎| 132/400 [00:54<01:48,  2.48it/s,
# Running rollout with at most 400 steps:  33%|▎| 132/400 [00:55<01:48,  2.48it/s,
# Running rollout with at most 400 steps:  33%|▎| 133/400 [00:55<01:49,  2.44it/s,
# Running rollout with at most 400 steps:  33%|▎| 133/400 [00:55<01:49,  2.44it/s,
# Running rollout with at most 400 steps:  34%|▎| 134/400 [00:55<01:48,  2.45it/s,
# Running rollout with at most 400 steps:  34%|▎| 134/400 [00:56<01:48,  2.45it/s,
# Running rollout with at most 400 steps:  34%|▎| 135/400 [00:56<01:46,  2.48it/s,
# Running rollout with at most 400 steps:  34%|▎| 135/400 [00:56<01:46,  2.48it/s,
# Running rollout with at most 400 steps:  34%|▎| 136/400 [00:56<01:46,  2.47it/s,
# Running rollout with at most 400 steps:  34%|▎| 136/400 [00:56<01:46,  2.47it/s,
# Running rollout with at most 400 steps:  34%|▎| 137/400 [00:56<01:52,  2.33it/s,
# Running rollout with at most 400 steps:  34%|▎| 137/400 [00:57<01:52,  2.33it/s,
# Running rollout with at most 400 steps:  34%|▎| 138/400 [00:57<01:49,  2.39it/s,
# Running rollout with at most 400 steps:  34%|▎| 138/400 [00:57<01:49,  2.39it/s,
# Running rollout with at most 400 steps:  35%|▎| 139/400 [00:57<01:56,  2.24it/s,
# Running rollout with at most 400 steps:  35%|▎| 139/400 [00:58<01:56,  2.24it/s,
# Running rollout with at most 400 steps:  35%|▎| 140/400 [00:58<01:51,  2.33it/s,
# Running rollout with at most 400 steps:  35%|▎| 140/400 [00:58<01:51,  2.33it/s,
# Running rollout with at most 400 steps:  35%|▎| 141/400 [00:58<01:48,  2.40it/s,
# Running rollout with at most 400 steps:  35%|▎| 141/400 [00:58<01:48,  2.40it/s,
# Running rollout with at most 400 steps:  36%|▎| 142/400 [00:58<01:45,  2.44it/s,
# Running rollout with at most 400 steps:  36%|▎| 142/400 [00:59<01:45,  2.44it/s,
# Running rollout with at most 400 steps:  36%|▎| 143/400 [00:59<01:43,  2.48it/s,
# Running rollout with at most 400 steps:  36%|▎| 143/400 [00:59<01:43,  2.48it/s,
# Running rollout with at most 400 steps:  36%|▎| 144/400 [00:59<01:42,  2.50it/s,
# Running rollout with at most 400 steps:  36%|▎| 144/400 [01:00<01:42,  2.50it/s,
# Running rollout with at most 400 steps:  36%|▎| 145/400 [01:00<01:46,  2.39it/s,
# Running rollout with at most 400 steps:  36%|▎| 145/400 [01:00<01:46,  2.39it/s,
# Running rollout with at most 400 steps:  36%|▎| 146/400 [01:00<01:45,  2.42it/s,
# Running rollout with at most 400 steps:  36%|▎| 146/400 [01:01<01:45,  2.42it/s,
# Running rollout with at most 400 steps:  37%|▎| 147/400 [01:01<01:42,  2.46it/s,
# Running rollout with at most 400 steps:  37%|▎| 147/400 [01:01<01:42,  2.46it/s,
# Running rollout with at most 400 steps:  37%|▎| 148/400 [01:01<01:41,  2.48it/s,
# Running rollout with at most 400 steps:  37%|▎| 148/400 [01:01<01:41,  2.48it/s,
# Running rollout with at most 400 steps:  37%|▎| 149/400 [01:01<01:40,  2.51it/s,
# Running rollout with at most 400 steps:  37%|▎| 149/400 [01:02<01:40,  2.51it/s,
# Running rollout with at most 400 steps:  38%|▍| 150/400 [01:02<01:45,  2.36it/s,
# Running rollout with at most 400 steps:  38%|▍| 150/400 [01:02<01:45,  2.36it/s,
# Running rollout with at most 400 steps:  38%|▍| 151/400 [01:02<01:48,  2.30it/s,
# Running rollout with at most 400 steps:  38%|▍| 151/400 [01:03<01:48,  2.30it/s,
# Running rollout with at most 400 steps:  38%|▍| 152/400 [01:03<01:44,  2.38it/s,
# Running rollout with at most 400 steps:  38%|▍| 152/400 [01:03<01:44,  2.38it/s,
# Running rollout with at most 400 steps:  38%|▍| 153/400 [01:03<01:41,  2.43it/s,
# Running rollout with at most 400 steps:  38%|▍| 153/400 [01:03<01:41,  2.43it/s,
# Running rollout with at most 400 steps:  38%|▍| 154/400 [01:03<01:39,  2.47it/s,
# Running rollout with at most 400 steps:  38%|▍| 154/400 [01:04<01:39,  2.47it/s,
# Running rollout with at most 400 steps:  39%|▍| 155/400 [01:04<01:38,  2.50it/s,
# Running rollout with at most 400 steps:  39%|▍| 155/400 [01:04<01:38,  2.50it/s,
# Running rollout with at most 400 steps:  39%|▍| 156/400 [01:04<01:36,  2.52it/s,
# Running rollout with at most 400 steps:  39%|▍| 156/400 [01:05<01:36,  2.52it/s,
# Running rollout with at most 400 steps:  39%|▍| 157/400 [01:05<01:36,  2.52it/s,
# Running rollout with at most 400 steps:  39%|▍| 157/400 [01:05<01:36,  2.52it/s,
# Running rollout with at most 400 steps:  40%|▍| 158/400 [01:05<01:35,  2.53it/s,
# Running rollout with at most 400 steps:  40%|▍| 158/400 [01:05<01:35,  2.53it/s,
# Running rollout with at most 400 steps:  40%|▍| 159/400 [01:05<01:35,  2.53it/s,
# Running rollout with at most 400 steps:  40%|▍| 159/400 [01:06<01:35,  2.53it/s,
# Running rollout with at most 400 steps:  40%|▍| 160/400 [01:06<01:34,  2.54it/s,
# Running rollout with at most 400 steps:  40%|▍| 160/400 [01:06<01:34,  2.54it/s,
# Running rollout with at most 400 steps:  40%|▍| 161/400 [01:06<01:33,  2.55it/s,
# Running rollout with at most 400 steps:  40%|▍| 161/400 [01:07<01:33,  2.55it/s,
# Running rollout with at most 400 steps:  40%|▍| 162/400 [01:07<01:33,  2.55it/s,
# Running rollout with at most 400 steps:  40%|▍| 162/400 [01:07<01:33,  2.55it/s,
# Running rollout with at most 400 steps:  41%|▍| 163/400 [01:07<01:32,  2.55it/s,
# Running rollout with at most 400 steps:  41%|▍| 163/400 [01:07<01:32,  2.55it/s,
# Running rollout with at most 400 steps:  41%|▍| 164/400 [01:07<01:31,  2.57it/s,
# Running rollout with at most 400 steps:  41%|▍| 164/400 [01:08<01:31,  2.57it/s,
# Running rollout with at most 400 steps:  41%|▍| 165/400 [01:08<01:31,  2.57it/s,
# Running rollout with at most 400 steps:  41%|▍| 165/400 [01:08<01:31,  2.57it/s,
# Running rollout with at most 400 steps:  42%|▍| 166/400 [01:08<01:30,  2.58it/s,
# Running rollout with at most 400 steps:  42%|▍| 166/400 [01:08<01:30,  2.58it/s,
# Running rollout with at most 400 steps:  42%|▍| 167/400 [01:08<01:30,  2.57it/s,
# Running rollout with at most 400 steps:  42%|▍| 167/400 [01:09<01:30,  2.57it/s,
# Running rollout with at most 400 steps:  42%|▍| 168/400 [01:09<01:30,  2.57it/s,
# Running rollout with at most 400 steps:  42%|▍| 168/400 [01:09<01:30,  2.57it/s,
# Running rollout with at most 400 steps:  42%|▍| 169/400 [01:09<01:29,  2.58it/s,
# Running rollout with at most 400 steps:  42%|▍| 169/400 [01:10<01:29,  2.58it/s,
# Running rollout with at most 400 steps:  42%|▍| 170/400 [01:10<01:28,  2.58it/s,
# Running rollout with at most 400 steps:  42%|▍| 170/400 [01:10<01:28,  2.58it/s,
# Running rollout with at most 400 steps:  43%|▍| 171/400 [01:10<01:30,  2.53it/s,
# Running rollout with at most 400 steps:  43%|▍| 171/400 [01:10<01:30,  2.53it/s,
# Running rollout with at most 400 steps:  43%|▍| 172/400 [01:10<01:29,  2.55it/s,
# Running rollout with at most 400 steps:  43%|▍| 172/400 [01:11<01:29,  2.55it/s,
# Running rollout with at most 400 steps:  43%|▍| 173/400 [01:11<01:29,  2.55it/s,
# Running rollout with at most 400 steps:  43%|▍| 173/400 [01:11<01:29,  2.55it/s,
# Running rollout with at most 400 steps:  44%|▍| 174/400 [01:11<01:28,  2.54it/s,
# Running rollout with at most 400 steps:  44%|▍| 174/400 [01:12<01:28,  2.54it/s,
# Running rollout with at most 400 steps:  44%|▍| 175/400 [01:12<01:28,  2.55it/s,
# Running rollout with at most 400 steps:  44%|▍| 175/400 [01:12<01:28,  2.55it/s,
# Running rollout with at most 400 steps:  44%|▍| 176/400 [01:12<01:27,  2.57it/s,
# Running rollout with at most 400 steps:  44%|▍| 176/400 [01:12<01:27,  2.57it/s,
# Running rollout with at most 400 steps:  44%|▍| 177/400 [01:12<01:27,  2.56it/s,
# Running rollout with at most 400 steps:  44%|▍| 177/400 [01:13<01:27,  2.56it/s,
# Running rollout with at most 400 steps:  44%|▍| 178/400 [01:13<01:26,  2.55it/s,
# Running rollout with at most 400 steps:  44%|▍| 178/400 [01:13<01:26,  2.55it/s,
# Running rollout with at most 400 steps:  45%|▍| 179/400 [01:13<01:26,  2.56it/s,
# Running rollout with at most 400 steps:  45%|▍| 179/400 [01:14<01:26,  2.56it/s,
# Running rollout with at most 400 steps:  45%|▍| 180/400 [01:14<01:25,  2.57it/s,
# Running rollout with at most 400 steps:  45%|▍| 180/400 [01:14<01:25,  2.57it/s,
# Running rollout with at most 400 steps:  45%|▍| 181/400 [01:14<01:25,  2.56it/s,
# Running rollout with at most 400 steps:  45%|▍| 181/400 [01:14<01:25,  2.56it/s,
# Running rollout with at most 400 steps:  46%|▍| 182/400 [01:14<01:25,  2.56it/s,
# Running rollout with at most 400 steps:  46%|▍| 182/400 [01:15<01:25,  2.56it/s,
# Running rollout with at most 400 steps:  46%|▍| 183/400 [01:15<01:24,  2.56it/s,
# Running rollout with at most 400 steps:  46%|▍| 183/400 [01:15<01:24,  2.56it/s,
# Running rollout with at most 400 steps:  46%|▍| 184/400 [01:15<01:24,  2.57it/s,
# Running rollout with at most 400 steps:  46%|▍| 184/400 [01:16<01:24,  2.57it/s,
# Running rollout with at most 400 steps:  46%|▍| 185/400 [01:16<01:23,  2.57it/s,
# Running rollout with at most 400 steps:  46%|▍| 185/400 [01:16<01:23,  2.57it/s,
# Running rollout with at most 400 steps:  46%|▍| 186/400 [01:16<01:23,  2.56it/s,
# Running rollout with at most 400 steps:  46%|▍| 186/400 [01:16<01:23,  2.56it/s,
# Running rollout with at most 400 steps:  47%|▍| 187/400 [01:16<01:23,  2.56it/s,
# Running rollout with at most 400 steps:  47%|▍| 187/400 [01:17<01:23,  2.56it/s,
# Running rollout with at most 400 steps:  47%|▍| 188/400 [01:17<01:22,  2.56it/s,
# Running rollout with at most 400 steps:  47%|▍| 188/400 [01:17<01:22,  2.56it/s,
# Running rollout with at most 400 steps:  47%|▍| 189/400 [01:17<01:22,  2.55it/s,
# Running rollout with at most 400 steps:  47%|▍| 189/400 [01:17<01:22,  2.55it/s,
# Running rollout with at most 400 steps:  48%|▍| 190/400 [01:17<01:22,  2.56it/s,
# Running rollout with at most 400 steps:  48%|▍| 190/400 [01:18<01:22,  2.56it/s,
# Running rollout with at most 400 steps:  48%|▍| 191/400 [01:18<01:21,  2.56it/s,
# Running rollout with at most 400 steps:  48%|▍| 191/400 [01:18<01:21,  2.56it/s,
# Running rollout with at most 400 steps:  48%|▍| 192/400 [01:18<01:21,  2.56it/s,
# Running rollout with at most 400 steps:  48%|▍| 192/400 [01:19<01:21,  2.56it/s,
# Running rollout with at most 400 steps:  48%|▍| 193/400 [01:19<01:20,  2.57it/s,
# Running rollout with at most 400 steps:  48%|▍| 193/400 [01:19<01:20,  2.57it/s,
# Running rollout with at most 400 steps:  48%|▍| 194/400 [01:19<01:20,  2.56it/s,
# Running rollout with at most 400 steps:  48%|▍| 194/400 [01:19<01:20,  2.56it/s,
# Running rollout with at most 400 steps:  49%|▍| 195/400 [01:19<01:20,  2.56it/s,
# Running rollout with at most 400 steps:  49%|▍| 195/400 [01:20<01:20,  2.56it/s,
# Running rollout with at most 400 steps:  49%|▍| 196/400 [01:20<01:19,  2.56it/s,
# Running rollout with at most 400 steps:  49%|▍| 196/400 [01:20<01:19,  2.56it/s,
# Running rollout with at most 400 steps:  49%|▍| 197/400 [01:20<01:19,  2.56it/s,
# Running rollout with at most 400 steps:  49%|▍| 197/400 [01:21<01:19,  2.56it/s,
# Running rollout with at most 400 steps:  50%|▍| 198/400 [01:21<01:19,  2.55it/s,
# Running rollout with at most 400 steps:  50%|▍| 198/400 [01:21<01:19,  2.55it/s,
# Running rollout with at most 400 steps:  50%|▍| 199/400 [01:21<01:18,  2.55it/s,
# Running rollout with at most 400 steps:  50%|▍| 199/400 [01:21<01:18,  2.55it/s,
# Running rollout with at most 400 steps:  50%|▌| 200/400 [01:21<01:18,  2.55it/s,
# Running rollout with at most 400 steps:  50%|▌| 200/400 [01:22<01:18,  2.55it/s,
# Running rollout with at most 400 steps:  50%|▌| 201/400 [01:22<01:29,  2.23it/s,
# Running rollout with at most 400 steps:  50%|▌| 201/400 [01:22<01:29,  2.23it/s,
# Running rollout with at most 400 steps:  50%|▌| 202/400 [01:22<01:26,  2.30it/s,
# Running rollout with at most 400 steps:  50%|▌| 202/400 [01:23<01:26,  2.30it/s,
# Running rollout with at most 400 steps:  51%|▌| 203/400 [01:23<01:22,  2.38it/s,
# Running rollout with at most 400 steps:  51%|▌| 203/400 [01:23<01:22,  2.38it/s,
# Running rollout with at most 400 steps:  51%|▌| 204/400 [01:23<01:20,  2.44it/s,
# Running rollout with at most 400 steps:  51%|▌| 204/400 [01:24<01:20,  2.44it/s,
# Running rollout with at most 400 steps:  51%|▌| 205/400 [01:24<01:18,  2.48it/s,
# Running rollout with at most 400 steps:  51%|▌| 205/400 [01:24<01:18,  2.48it/s,
# Running rollout with at most 400 steps:  52%|▌| 206/400 [01:24<01:17,  2.50it/s,
# Running rollout with at most 400 steps:  52%|▌| 206/400 [01:24<01:17,  2.50it/s,
# Running rollout with at most 400 steps:  52%|▌| 207/400 [01:24<01:16,  2.52it/s,
# Running rollout with at most 400 steps:  52%|▌| 207/400 [01:25<01:16,  2.52it/s,
# Running rollout with at most 400 steps:  52%|▌| 208/400 [01:25<01:16,  2.50it/s,
# Running rollout with at most 400 steps:  52%|▌| 208/400 [01:25<01:16,  2.50it/s,
# Running rollout with at most 400 steps:  52%|▌| 209/400 [01:25<01:16,  2.49it/s,
# Running rollout with at most 400 steps:  52%|▌| 209/400 [01:26<01:16,  2.49it/s,
# Running rollout with at most 400 steps:  52%|▌| 210/400 [01:26<01:15,  2.50it/s,
# Running rollout with at most 400 steps:  52%|▌| 210/400 [01:26<01:15,  2.50it/s,
# Running rollout with at most 400 steps:  53%|▌| 211/400 [01:26<01:15,  2.51it/s,
# Running rollout with at most 400 steps:  53%|▌| 211/400 [01:26<01:15,  2.51it/s,
# Running rollout with at most 400 steps:  53%|▌| 212/400 [01:26<01:14,  2.53it/s,
# Running rollout with at most 400 steps:  53%|▌| 212/400 [01:27<01:14,  2.53it/s,
# Running rollout with at most 400 steps:  53%|▌| 213/400 [01:27<01:14,  2.53it/s,
# Running rollout with at most 400 steps:  53%|▌| 213/400 [01:27<01:14,  2.53it/s,
# Running rollout with at most 400 steps:  54%|▌| 214/400 [01:27<01:13,  2.52it/s,
# Running rollout with at most 400 steps:  54%|▌| 214/400 [01:28<01:13,  2.52it/s,
# Running rollout with at most 400 steps:  54%|▌| 215/400 [01:28<01:13,  2.53it/s,
# Running rollout with at most 400 steps:  54%|▌| 215/400 [01:28<01:13,  2.53it/s,
# Running rollout with at most 400 steps:  54%|▌| 216/400 [01:28<01:12,  2.53it/s,
# Running rollout with at most 400 steps:  54%|▌| 216/400 [01:28<01:12,  2.53it/s,
# Running rollout with at most 400 steps:  54%|▌| 217/400 [01:28<01:11,  2.54it/s,
# Running rollout with at most 400 steps:  54%|▌| 217/400 [01:29<01:11,  2.54it/s,
# Running rollout with at most 400 steps:  55%|▌| 218/400 [01:29<01:11,  2.55it/s,
# Running rollout with at most 400 steps:  55%|▌| 218/400 [01:29<01:11,  2.55it/s,
# Running rollout with at most 400 steps:  55%|▌| 219/400 [01:29<01:10,  2.55it/s,
# Running rollout with at most 400 steps:  55%|▌| 219/400 [01:29<01:10,  2.55it/s,
# Running rollout with at most 400 steps:  55%|▌| 220/400 [01:29<01:10,  2.55it/s,
# Running rollout with at most 400 steps:  55%|▌| 220/400 [01:30<01:10,  2.55it/s,
# Running rollout with at most 400 steps:  55%|▌| 221/400 [01:30<01:11,  2.52it/s,
# Running rollout with at most 400 steps:  55%|▌| 221/400 [01:30<01:11,  2.52it/s,
# Running rollout with at most 400 steps:  56%|▌| 222/400 [01:30<01:10,  2.53it/s,
# Running rollout with at most 400 steps:  56%|▌| 222/400 [01:31<01:10,  2.53it/s,
# Running rollout with at most 400 steps:  56%|▌| 223/400 [01:31<01:09,  2.54it/s,
# Running rollout with at most 400 steps:  56%|▌| 223/400 [01:31<01:09,  2.54it/s,
# Running rollout with at most 400 steps:  56%|▌| 224/400 [01:31<01:09,  2.54it/s,
# Running rollout with at most 400 steps:  56%|▌| 224/400 [01:31<01:09,  2.54it/s,
# Running rollout with at most 400 steps:  56%|▌| 225/400 [01:31<01:08,  2.55it/s,
# Running rollout with at most 400 steps:  56%|▌| 225/400 [01:32<01:08,  2.55it/s,
# Running rollout with at most 400 steps:  56%|▌| 226/400 [01:32<01:08,  2.55it/s,
# Running rollout with at most 400 steps:  56%|▌| 226/400 [01:32<01:08,  2.55it/s,
# Running rollout with at most 400 steps:  57%|▌| 227/400 [01:32<01:07,  2.57it/s,
# Running rollout with at most 400 steps:  57%|▌| 227/400 [01:33<01:07,  2.57it/s,
# Running rollout with at most 400 steps:  57%|▌| 228/400 [01:33<01:06,  2.57it/s,
# Running rollout with at most 400 steps:  57%|▌| 228/400 [01:33<01:06,  2.57it/s,
# Running rollout with at most 400 steps:  57%|▌| 229/400 [01:33<01:06,  2.56it/s,
# Running rollout with at most 400 steps:  57%|▌| 229/400 [01:33<01:06,  2.56it/s,
# Running rollout with at most 400 steps:  57%|▌| 230/400 [01:33<01:06,  2.57it/s,
# Running rollout with at most 400 steps:  57%|▌| 230/400 [01:34<01:06,  2.57it/s,
# Running rollout with at most 400 steps:  58%|▌| 231/400 [01:34<01:05,  2.56it/s,
# Running rollout with at most 400 steps:  58%|▌| 231/400 [01:34<01:05,  2.56it/s,
# Running rollout with at most 400 steps:  58%|▌| 232/400 [01:34<01:05,  2.57it/s,
# Running rollout with at most 400 steps:  58%|▌| 232/400 [01:35<01:05,  2.57it/s,
# Running rollout with at most 400 steps:  58%|▌| 233/400 [01:35<01:05,  2.57it/s,
# Running rollout with at most 400 steps:  58%|▌| 233/400 [01:35<01:05,  2.57it/s,
# Running rollout with at most 400 steps:  58%|▌| 234/400 [01:35<01:04,  2.57it/s,
# Running rollout with at most 400 steps:  58%|▌| 234/400 [01:35<01:04,  2.57it/s,
# Running rollout with at most 400 steps:  59%|▌| 235/400 [01:35<01:04,  2.58it/s,
# Running rollout with at most 400 steps:  59%|▌| 235/400 [01:36<01:04,  2.58it/s,
# Running rollout with at most 400 steps:  59%|▌| 236/400 [01:36<01:03,  2.58it/s,
# Running rollout with at most 400 steps:  59%|▌| 236/400 [01:36<01:03,  2.58it/s,
# Running rollout with at most 400 steps:  59%|▌| 237/400 [01:36<01:03,  2.56it/s,
# Running rollout with at most 400 steps:  59%|▌| 237/400 [01:36<01:03,  2.56it/s,
# Running rollout with at most 400 steps:  60%|▌| 238/400 [01:36<01:03,  2.57it/s,
# Running rollout with at most 400 steps:  60%|▌| 238/400 [01:37<01:03,  2.57it/s,
# Running rollout with at most 400 steps:  60%|▌| 239/400 [01:37<01:02,  2.56it/s,
# Running rollout with at most 400 steps:  60%|▌| 239/400 [01:37<01:02,  2.56it/s,
# Running rollout with at most 400 steps:  60%|▌| 240/400 [01:37<01:02,  2.56it/s,
# ...
# Running rollout with at most 400 steps:  76%|▊| 303/400 [02:03<00:42,  2.26it/s,
# Running rollout with at most 400 steps:  76%|▊| 304/400 [02:03<00:41,  2.33it/s,
# Running rollout with at most 400 steps:  76%|▊| 304/400 [02:03<00:41,  2.33it/s,
# Running rollout with at most 400 steps:  76%|▊| 305/400 [02:03<00:40,  2.36it/s,
# Running rollout with at most 400 steps:  76%|▊| 305/400 [02:04<00:40,  2.36it/s,
# Running rollout with at most 400 steps:  76%|▊| 306/400 [02:04<00:39,  2.38it/s,
# Running rollout with at most 400 steps:  76%|▊| 306/400 [02:04<00:39,  2.38it/s,
# Running rollout with at most 400 steps:  77%|▊| 307/400 [02:04<00:38,  2.42it/s,
# Running rollout with at most 400 steps:  77%|▊| 307/400 [02:05<00:38,  2.42it/s,
# Running rollout with at most 400 steps:  77%|▊| 308/400 [02:05<00:38,  2.41it/s,
# Running rollout with at most 400 steps:  77%|▊| 308/400 [02:05<00:38,  2.41it/s,
# Running rollout with at most 400 steps:  77%|▊| 309/400 [02:05<00:37,  2.43it/s,
# Running rollout with at most 400 steps:  77%|▊| 309/400 [02:05<00:37,  2.43it/s,
# Running rollout with at most 400 steps:  78%|▊| 310/400 [02:05<00:36,  2.45it/s,
# Running rollout with at most 400 steps:  78%|▊| 310/400 [02:06<00:36,  2.45it/s,
# Running rollout with at most 400 steps:  78%|▊| 311/400 [02:06<00:36,  2.45it/s,
# Running rollout with at most 400 steps:  78%|▊| 311/400 [02:06<00:36,  2.45it/s,
# Running rollout with at most 400 steps:  78%|▊| 312/400 [02:06<00:36,  2.44it/s,
# Running rollout with at most 400 steps:  78%|▊| 312/400 [02:07<00:36,  2.44it/s,
# Running rollout with at most 400 steps:  78%|▊| 313/400 [02:07<00:35,  2.45it/s,
# Running rollout with at most 400 steps:  78%|▊| 313/400 [02:07<00:35,  2.45it/s,
# Running rollout with at most 400 steps:  78%|▊| 314/400 [02:07<00:35,  2.44it/s,
# Running rollout with at most 400 steps:  78%|▊| 314/400 [02:07<00:35,  2.44it/s,
# Running rollout with at most 400 steps:  79%|▊| 315/400 [02:07<00:34,  2.44it/s,
# Running rollout with at most 400 steps:  79%|▊| 315/400 [02:08<00:34,  2.44it/s,
# Running rollout with at most 400 steps:  79%|▊| 316/400 [02:08<00:34,  2.45it/s,
# Running rollout with at most 400 steps:  79%|▊| 316/400 [02:08<00:34,  2.45it/s,
# Running rollout with at most 400 steps:  79%|▊| 317/400 [02:08<00:33,  2.46it/s,
# Running rollout with at most 400 steps:  79%|▊| 317/400 [02:09<00:33,  2.46it/s,
# Running rollout with at most 400 steps:  80%|▊| 318/400 [02:09<00:33,  2.46it/s,
# Running rollout with at most 400 steps:  80%|▊| 318/400 [02:09<00:33,  2.46it/s,
# Running rollout with at most 400 steps:  80%|▊| 319/400 [02:09<00:32,  2.47it/s,
# Running rollout with at most 400 steps:  80%|▊| 319/400 [02:10<00:32,  2.47it/s,
# Running rollout with at most 400 steps:  80%|▊| 320/400 [02:10<00:32,  2.44it/s,
# Running rollout with at most 400 steps:  80%|▊| 320/400 [02:10<00:32,  2.44it/s,
# Running rollout with at most 400 steps:  80%|▊| 321/400 [02:10<00:32,  2.43it/s,
# Running rollout with at most 400 steps:  80%|▊| 321/400 [02:10<00:32,  2.43it/s,
# Running rollout with at most 400 steps:  80%|▊| 322/400 [02:10<00:31,  2.46it/s,
# Running rollout with at most 400 steps:  80%|▊| 322/400 [02:11<00:31,  2.46it/s,
# Running rollout with at most 400 steps:  81%|▊| 323/400 [02:11<00:31,  2.48it/s,
# Running rollout with at most 400 steps:  81%|▊| 323/400 [02:11<00:31,  2.48it/s,
# Running rollout with at most 400 steps:  81%|▊| 324/400 [02:11<00:30,  2.48it/s,
# Running rollout with at most 400 steps:  81%|▊| 324/400 [02:12<00:30,  2.48it/s,
# Running rollout with at most 400 steps:  81%|▊| 325/400 [02:12<00:30,  2.48it/s,
# Running rollout with at most 400 steps:  81%|▊| 325/400 [02:12<00:30,  2.48it/s,
# Running rollout with at most 400 steps:  82%|▊| 326/400 [02:12<00:30,  2.45it/s,
# Running rollout with at most 400 steps:  82%|▊| 326/400 [02:12<00:30,  2.45it/s,
# Running rollout with at most 400 steps:  82%|▊| 327/400 [02:12<00:29,  2.45it/s,
# Running rollout with at most 400 steps:  82%|▊| 327/400 [02:13<00:29,  2.45it/s,
# Running rollout with at most 400 steps:  82%|▊| 328/400 [02:13<00:29,  2.46it/s,
# Running rollout with at most 400 steps:  82%|▊| 328/400 [02:13<00:29,  2.46it/s,
# Running rollout with at most 400 steps:  82%|▊| 329/400 [02:13<00:31,  2.28it/s,
# Running rollout with at most 400 steps:  82%|▊| 329/400 [02:14<00:31,  2.28it/s,
# Running rollout with at most 400 steps:  82%|▊| 330/400 [02:14<00:29,  2.36it/s,
# Running rollout with at most 400 steps:  82%|▊| 330/400 [02:14<00:29,  2.36it/s,
# Running rollout with at most 400 steps:  83%|▊| 331/400 [02:14<00:28,  2.39it/s,
# Running rollout with at most 400 steps:  83%|▊| 331/400 [02:14<00:28,  2.39it/s,
# Running rollout with at most 400 steps:  83%|▊| 332/400 [02:14<00:28,  2.41it/s,
# Running rollout with at most 400 steps:  83%|▊| 332/400 [02:15<00:28,  2.41it/s,
# Running rollout with at most 400 steps:  83%|▊| 333/400 [02:15<00:27,  2.45it/s,
# Running rollout with at most 400 steps:  83%|▊| 333/400 [02:15<00:27,  2.45it/s,
# Running rollout with at most 400 steps:  84%|▊| 334/400 [02:15<00:26,  2.47it/s,
# Running rollout with at most 400 steps:  84%|▊| 334/400 [02:16<00:26,  2.47it/s,
# Running rollout with at most 400 steps:  84%|▊| 335/400 [02:16<00:26,  2.49it/s,
# Running rollout with at most 400 steps:  84%|▊| 335/400 [02:16<00:26,  2.49it/s,
# Running rollout with at most 400 steps:  84%|▊| 336/400 [02:16<00:27,  2.33it/s,
# Running rollout with at most 400 steps:  84%|▊| 336/400 [02:17<00:27,  2.33it/s,
# Running rollout with at most 400 steps:  84%|▊| 337/400 [02:17<00:26,  2.38it/s,
# Running rollout with at most 400 steps:  84%|▊| 337/400 [02:17<00:26,  2.38it/s,
# Running rollout with at most 400 steps:  84%|▊| 338/400 [02:17<00:25,  2.39it/s,
# Running rollout with at most 400 steps:  84%|▊| 338/400 [02:17<00:25,  2.39it/s,
# Running rollout with at most 400 steps:  85%|▊| 339/400 [02:17<00:25,  2.42it/s,
# Running rollout with at most 400 steps:  85%|▊| 339/400 [02:18<00:25,  2.42it/s,
# Running rollout with at most 400 steps:  85%|▊| 340/400 [02:18<00:24,  2.44it/s,
# Running rollout with at most 400 steps:  85%|▊| 340/400 [02:18<00:24,  2.44it/s,
# Running rollout with at most 400 steps:  85%|▊| 341/400 [02:18<00:24,  2.45it/s,
# Running rollout with at most 400 steps:  85%|▊| 341/400 [02:19<00:24,  2.45it/s,
# Running rollout with at most 400 steps:  86%|▊| 342/400 [02:19<00:23,  2.45it/s,
# Running rollout with at most 400 steps:  86%|▊| 342/400 [02:19<00:23,  2.45it/s,
# Running rollout with at most 400 steps:  86%|▊| 343/400 [02:19<00:25,  2.28it/s,
# Running rollout with at most 400 steps:  86%|▊| 343/400 [02:20<00:25,  2.28it/s,
# Running rollout with at most 400 steps:  86%|▊| 344/400 [02:20<00:24,  2.31it/s,
# Running rollout with at most 400 steps:  86%|▊| 344/400 [02:20<00:24,  2.31it/s,
# Running rollout with at most 400 steps:  86%|▊| 345/400 [02:20<00:23,  2.34it/s,
# Running rollout with at most 400 steps:  86%|▊| 345/400 [02:20<00:23,  2.34it/s,
# Running rollout with at most 400 steps:  86%|▊| 346/400 [02:20<00:22,  2.37it/s,
# Running rollout with at most 400 steps:  86%|▊| 346/400 [02:21<00:22,  2.37it/s,
# Running rollout with at most 400 steps:  87%|▊| 347/400 [02:21<00:21,  2.41it/s,
# Running rollout with at most 400 steps:  87%|▊| 347/400 [02:21<00:21,  2.41it/s,
# Running rollout with at most 400 steps:  87%|▊| 348/400 [02:21<00:21,  2.44it/s,
# Running rollout with at most 400 steps:  87%|▊| 348/400 [02:22<00:21,  2.44it/s,
# Running rollout with at most 400 steps:  87%|▊| 349/400 [02:22<00:20,  2.43it/s,
# Running rollout with at most 400 steps:  87%|▊| 349/400 [02:22<00:20,  2.43it/s,
# Running rollout with at most 400 steps:  88%|▉| 350/400 [02:22<00:20,  2.45it/s,
# Running rollout with at most 400 steps:  88%|▉| 350/400 [02:22<00:20,  2.45it/s,
# Running rollout with at most 400 steps:  88%|▉| 351/400 [02:22<00:20,  2.44it/s,
# Running rollout with at most 400 steps:  88%|▉| 351/400 [02:23<00:20,  2.44it/s,
# Running rollout with at most 400 steps:  88%|▉| 352/400 [02:23<00:20,  2.33it/s,
# Running rollout with at most 400 steps:  88%|▉| 352/400 [02:23<00:20,  2.33it/s,
# Running rollout with at most 400 steps:  88%|▉| 353/400 [02:23<00:19,  2.38it/s,
# Running rollout with at most 400 steps:  88%|▉| 353/400 [02:24<00:19,  2.38it/s,
# Running rollout with at most 400 steps:  88%|▉| 354/400 [02:24<00:18,  2.43it/s,
# Running rollout with at most 400 steps:  88%|▉| 354/400 [02:24<00:18,  2.43it/s,
# Running rollout with at most 400 steps:  89%|▉| 355/400 [02:24<00:18,  2.46it/s,
# Running rollout with at most 400 steps:  89%|▉| 355/400 [02:24<00:18,  2.46it/s,
# Running rollout with at most 400 steps:  89%|▉| 356/400 [02:24<00:18,  2.37it/s,
# Running rollout with at most 400 steps:  89%|▉| 356/400 [02:25<00:18,  2.37it/s,
# Running rollout with at most 400 steps:  89%|▉| 357/400 [02:25<00:17,  2.42it/s,
# Running rollout with at most 400 steps:  89%|▉| 357/400 [02:25<00:17,  2.42it/s,
# Running rollout with at most 400 steps:  90%|▉| 358/400 [02:25<00:17,  2.41it/s,
# Running rollout with at most 400 steps:  90%|▉| 358/400 [02:26<00:17,  2.41it/s,
# Running rollout with at most 400 steps:  90%|▉| 359/400 [02:26<00:17,  2.28it/s,
# Running rollout with at most 400 steps:  90%|▉| 359/400 [02:26<00:17,  2.28it/s,
# Running rollout with at most 400 steps:  90%|▉| 360/400 [02:26<00:17,  2.33it/s,
# Running rollout with at most 400 steps:  90%|▉| 360/400 [02:27<00:17,  2.33it/s,
# Running rollout with at most 400 steps:  90%|▉| 361/400 [02:27<00:17,  2.20it/s,
# Running rollout with at most 400 steps:  90%|▉| 361/400 [02:27<00:17,  2.20it/s,
# Running rollout with at most 400 steps:  90%|▉| 362/400 [02:27<00:16,  2.27it/s,
# Running rollout with at most 400 steps:  90%|▉| 362/400 [02:27<00:16,  2.27it/s,
# Running rollout with at most 400 steps:  91%|▉| 363/400 [02:27<00:15,  2.34it/s,
# Running rollout with at most 400 steps:  91%|▉| 363/400 [02:28<00:15,  2.34it/s,
# Running rollout with at most 400 steps:  91%|▉| 364/400 [02:28<00:15,  2.39it/s,
# Running rollout with at most 400 steps:  91%|▉| 364/400 [02:28<00:15,  2.39it/s,
# Running rollout with at most 400 steps:  91%|▉| 365/400 [02:28<00:14,  2.42it/s,
# Running rollout with at most 400 steps:  91%|▉| 365/400 [02:29<00:14,  2.42it/s,
# Running rollout with at most 400 steps:  92%|▉| 366/400 [02:29<00:13,  2.45it/s,
# Running rollout with at most 400 steps:  92%|▉| 366/400 [02:29<00:13,  2.45it/s,
# Running rollout with at most 400 steps:  92%|▉| 367/400 [02:29<00:13,  2.46it/s,
# Running rollout with at most 400 steps:  92%|▉| 367/400 [02:30<00:13,  2.46it/s,
# Running rollout with at most 400 steps:  92%|▉| 368/400 [02:30<00:12,  2.46it/s,
# Running rollout with at most 400 steps:  92%|▉| 368/400 [02:30<00:12,  2.46it/s,
# Running rollout with at most 400 steps:  92%|▉| 369/400 [02:30<00:12,  2.48it/s,
# Running rollout with at most 400 steps:  92%|▉| 369/400 [02:30<00:12,  2.48it/s,
# Running rollout with at most 400 steps:  92%|▉| 370/400 [02:30<00:12,  2.49it/s,
# Running rollout with at most 400 steps:  92%|▉| 370/400 [02:31<00:12,  2.49it/s,
# Running rollout with at most 400 steps:  93%|▉| 371/400 [02:31<00:11,  2.49it/s,
# Running rollout with at most 400 steps:  93%|▉| 371/400 [02:31<00:11,  2.49it/s,
# Running rollout with at most 400 steps:  93%|▉| 372/400 [02:31<00:11,  2.50it/s,
# Running rollout with at most 400 steps:  93%|▉| 372/400 [02:31<00:11,  2.50it/s,
# Running rollout with at most 400 steps:  93%|▉| 373/400 [02:31<00:10,  2.50it/s,
# Running rollout with at most 400 steps:  93%|▉| 373/400 [02:32<00:10,  2.50it/s,
# Running rollout with at most 400 steps:  94%|▉| 374/400 [02:32<00:10,  2.47it/s,
# Running rollout with at most 400 steps:  94%|▉| 374/400 [02:32<00:10,  2.47it/s,
# Running rollout with at most 400 steps:  94%|▉| 375/400 [02:32<00:10,  2.49it/s,
# Running rollout with at most 400 steps:  94%|▉| 375/400 [02:33<00:10,  2.49it/s,
# Running rollout with at most 400 steps:  94%|▉| 376/400 [02:33<00:09,  2.50it/s,
# Running rollout with at most 400 steps:  94%|▉| 376/400 [02:33<00:09,  2.50it/s,
# Running rollout with at most 400 steps:  94%|▉| 377/400 [02:33<00:09,  2.50it/s,
# Running rollout with at most 400 steps:  94%|▉| 377/400 [02:34<00:09,  2.50it/s,
# Running rollout with at most 400 steps:  94%|▉| 378/400 [02:34<00:08,  2.50it/s,
# Running rollout with at most 400 steps:  94%|▉| 378/400 [02:34<00:08,  2.50it/s,
# Running rollout with at most 400 steps:  95%|▉| 379/400 [02:34<00:08,  2.50it/s,
# Running rollout with at most 400 steps:  95%|▉| 379/400 [02:34<00:08,  2.50it/s,
# Running rollout with at most 400 steps:  95%|▉| 380/400 [02:34<00:08,  2.49it/s,
# Running rollout with at most 400 steps:  95%|▉| 380/400 [02:35<00:08,  2.49it/s,
# Running rollout with at most 400 steps:  95%|▉| 381/400 [02:35<00:07,  2.50it/s,
# Running rollout with at most 400 steps:  95%|▉| 381/400 [02:35<00:07,  2.50it/s,
# Running rollout with at most 400 steps:  96%|▉| 382/400 [02:35<00:07,  2.50it/s,
# Running rollout with at most 400 steps:  96%|▉| 382/400 [02:35<00:07,  2.50it/s,
# Running rollout with at most 400 steps:  96%|▉| 383/400 [02:35<00:06,  2.51it/s,
# Running rollout with at most 400 steps:  96%|▉| 383/400 [02:36<00:06,  2.51it/s,
# Running rollout with at most 400 steps:  96%|▉| 384/400 [02:36<00:06,  2.52it/s,
# Running rollout with at most 400 steps:  96%|▉| 384/400 [02:36<00:06,  2.52it/s,
# Running rollout with at most 400 steps:  96%|▉| 385/400 [02:36<00:05,  2.52it/s,
# Running rollout with at most 400 steps:  96%|▉| 385/400 [02:37<00:05,  2.52it/s,
# Running rollout with at most 400 steps:  96%|▉| 386/400 [02:37<00:05,  2.48it/s,
# Running rollout with at most 400 steps:  96%|▉| 386/400 [02:37<00:05,  2.48it/s,
# Running rollout with at most 400 steps:  97%|▉| 387/400 [02:37<00:05,  2.49it/s,
# Running rollout with at most 400 steps:  97%|▉| 387/400 [02:38<00:05,  2.49it/s,
# Running rollout with at most 400 steps:  97%|▉| 388/400 [02:38<00:04,  2.50it/s,
# Running rollout with at most 400 steps:  97%|▉| 388/400 [02:38<00:04,  2.50it/s,
# Running rollout with at most 400 steps:  97%|▉| 389/400 [02:38<00:04,  2.51it/s,
# Running rollout with at most 400 steps:  97%|▉| 389/400 [02:38<00:04,  2.51it/s,
# Running rollout with at most 400 steps:  98%|▉| 390/400 [02:38<00:03,  2.52it/s,
# Running rollout with at most 400 steps:  98%|▉| 390/400 [02:39<00:03,  2.52it/s,
# Running rollout with at most 400 steps:  98%|▉| 391/400 [02:39<00:03,  2.52it/s,
# Running rollout with at most 400 steps:  98%|▉| 391/400 [02:39<00:03,  2.52it/s,
# Running rollout with at most 400 steps:  98%|▉| 392/400 [02:39<00:03,  2.49it/s,
# Running rollout with at most 400 steps:  98%|▉| 392/400 [02:39<00:03,  2.49it/s,
# Running rollout with at most 400 steps:  98%|▉| 393/400 [02:39<00:02,  2.50it/s,
# Running rollout with at most 400 steps:  98%|▉| 393/400 [02:40<00:02,  2.50it/s,
# Running rollout with at most 400 steps:  98%|▉| 394/400 [02:40<00:02,  2.22it/s,
# Running rollout with at most 400 steps:  98%|▉| 394/400 [02:40<00:02,  2.22it/s,
# Running rollout with at most 400 steps:  99%|▉| 395/400 [02:40<00:02,  2.24it/s,
# Running rollout with at most 400 steps:  99%|▉| 395/400 [02:41<00:02,  2.24it/s,
# Running rollout with at most 400 steps:  99%|▉| 396/400 [02:41<00:01,  2.23it/s,
# Running rollout with at most 400 steps:  99%|▉| 396/400 [02:41<00:01,  2.23it/s,
# Running rollout with at most 400 steps:  99%|▉| 397/400 [02:41<00:01,  2.30it/s,
# Running rollout with at most 400 steps:  99%|▉| 397/400 [02:42<00:01,  2.30it/s,
# Running rollout with at most 400 steps: 100%|▉| 398/400 [02:42<00:00,  2.30it/s,
# Running rollout with at most 400 steps: 100%|▉| 398/400 [02:42<00:00,  2.30it/s,
# Running rollout with at most 400 steps: 100%|▉| 399/400 [02:42<00:00,  2.25it/s,
# Running rollout with at most 400 steps: 100%|▉| 399/400 [02:43<00:00,  2.25it/s,
# Running rollout with at most 400 steps: 100%|█| 400/400 [02:43<00:00,  2.10it/s,
# Stepping through eval batches: 100%|█| 1/1 [02:43<00:00, 163.99s/it, running_suc
# INFO 2025-09-10 16:46:25 ts/train.py:275 step:20K smpl:320K ep:800 epch:16.00 ∑rwrd:167.180 success:52.0 eval_s:165.481
# INFO 2025-09-10 16:46:25 ts/train.py:283 End of training

# %% [markdown]
# ## Video evaluation of the training sequence

# %%
from IPython.display import HTML, display

def display_video_grid(videos, cols=2, ratio = 100):
    """
    Display videos in a grid with titles.
    
    Args:
        videos (list of tuples): [(filepath, title), ...]
        cols (int): number of videos per row
    """
    # CSS for grid
    style = f"""
    <style>
    .video-grid {{
      display: grid;
      grid-template-columns: repeat({cols}, 1fr);
      gap: 20px;
      margin-top: 20px;
    }}
    .video-item {{
      text-align: center;
    }}
    .video-item video {{
      width: {ratio}%;
      border-radius: 10px;
      box-shadow: 0 4px 10px rgba(0,0,0,0.2);
    }}
    .video-title {{
      margin-top: 8px;
      font-weight: bold;
      font-family: sans-serif;
    }}
    </style>
    """

    # Build video HTML
    items = ""
    for path, title in videos:
        items += f"""
        <div class="video-item">
            <video controls>
                <source src="{path}" type="video/mp4">
            </video>
            <div class="video-title">{title}</div>
        </div>
        """

    html = style + f'<div class="video-grid">{items}</div>'
    display(HTML(html))

# %%
steps = ["step_000500", "step_005000", "step_010000", "step_015000", "step_020000"]
episodes = ["episode_0", "episode_1", "episode_2", "episode_3"]

video_list = []
for episode in episodes:
    for step in steps:
        v_fp = f"./output/train_videos_act_aloha_transfer/videos_{step}/eval_{episode}.mp4"
        v_title = f"{step}_{episode}"
        video_list.append((v_fp, v_title))

print(video_list)

display_video_grid(video_list, cols=len(steps))
# Out:
# [('./output/train_videos_act_aloha_transfer/videos_step_000500/eval_episode_0.mp4', 'step_000500_episode_0'), ('./output/train_videos_act_aloha_transfer/videos_step_005000/eval_episode_0.mp4', 'step_005000_episode_0'), ('./output/train_videos_act_aloha_transfer/videos_step_010000/eval_episode_0.mp4', 'step_010000_episode_0'), ('./output/train_videos_act_aloha_transfer/videos_step_015000/eval_episode_0.mp4', 'step_015000_episode_0'), ('./output/train_videos_act_aloha_transfer/videos_step_020000/eval_episode_0.mp4', 'step_020000_episode_0'), ('./output/train_videos_act_aloha_transfer/videos_step_000500/eval_episode_1.mp4', 'step_000500_episode_1'), ('./output/train_videos_act_aloha_transfer/videos_step_005000/eval_episode_1.mp4', 'step_005000_episode_1'), ('./output/train_videos_act_aloha_transfer/videos_step_010000/eval_episode_1.mp4', 'step_010000_episode_1'), ('./output/train_videos_act_aloha_transfer/videos_step_015000/eval_episode_1.mp4', 'step_015000_episode_1'), ('./output/train_videos_act_aloha_transfer/videos_step_020000/eval_episode_1.mp4', 'step_020000_episode_1'), ('./output/train_videos_act_aloha_transfer/videos_step_000500/eval_episode_2.mp4', 'step_000500_episode_2'), ('./output/train_videos_act_aloha_transfer/videos_step_005000/eval_episode_2.mp4', 'step_005000_episode_2'), ('./output/train_videos_act_aloha_transfer/videos_step_010000/eval_episode_2.mp4', 'step_010000_episode_2'), ('./output/train_videos_act_aloha_transfer/videos_step_015000/eval_episode_2.mp4', 'step_015000_episode_2'), ('./output/train_videos_act_aloha_transfer/videos_step_020000/eval_episode_2.mp4', 'step_020000_episode_2'), ('./output/train_videos_act_aloha_transfer/videos_step_000500/eval_episode_3.mp4', 'step_000500_episode_3'), ('./output/train_videos_act_aloha_transfer/videos_step_005000/eval_episode_3.mp4', 'step_005000_episode_3'), ('./output/train_videos_act_aloha_transfer/videos_step_010000/eval_episode_3.mp4', 'step_010000_episode_3'), ('./output/train_videos_act_aloha_transfer/videos_step_015000/eval_episode_3.mp4', 'step_015000_episode_3'), ('./output/train_videos_act_aloha_transfer/videos_step_020000/eval_episode_3.mp4', 'step_020000_episode_3')]
#     <style>
#     .video-grid {
#       display: grid;
#       grid-template-columns: repeat(5, 1fr);
#       gap: 20px;
#       margin-top: 20px;
#     }
#     .video-item {
#       text-align: center;
#     }
#     .video-item video {
#       width: 50%;
#       border-radius: 10px;
#       box-shadow: 0 4px 10px rgba(0,0,0,0.2);
#     }
#     .video-title {
#       margin-top: 8px;
#       font-weight: bold;
#       font-family: sans-serif;
#     }
#     </style>
#     <div class="video-grid">
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_000500/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_000500_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_005000/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_005000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_010000/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_010000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_015000/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_015000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_020000/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_020000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_000500/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_000500_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_005000/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_005000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_010000/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_010000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_015000/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_015000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_020000/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_020000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_000500/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_000500_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_005000/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_005000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_010000/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_010000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_015000/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_015000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_020000/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_020000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_000500/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_000500_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_005000/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_005000_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_010000/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_010000_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_015000/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_015000_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_act_aloha_transfer/videos_step_020000/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_020000_episode_3</div>
#         </div>
#         </div>

# %% [markdown]
# ## Evaluation

# %%
pretrained_path = os.path.join(output_dir, "checkpoints/last/pretrained_model")
eval_output = os.path.join("./output", "post_eval/act_aloha_transfer")

print(pretrained_path)
print(eval_output)
# Out:
# ./temp/outputs/aloha_sim_transfer_cube_human/checkpoints/last/pretrained_model
# ./output/post_eval/act_aloha_transfer

# %%
# !python -m lerobot.scripts.eval \
    --policy.path=$pretrained_path \
    --output_dir=$eval_output \
    --env.type=aloha \
    --env.task=AlohaTransferCube-v0 \
    --eval.n_episodes=50 \
    --eval.batch_size=50 \
    --policy.device=$device \
    --policy.use_amp=false
# Out:
# INFO 2025-09-11 11:05:18 pts/eval.py:462 {'env': {'episode_length': 400,
#          'features': {'action': {'shape': (14,),
#                                  'type': <FeatureType.ACTION: 'ACTION'>},
#                       'agent_pos': {'shape': (14,),
#                                     'type': <FeatureType.STATE: 'STATE'>},
#                       'pixels/top': {'shape': (480, 640, 3),
#                                      'type': <FeatureType.VISUAL: 'VISUAL'>}},
#          'features_map': {'action': 'action',
#                           'agent_pos': 'observation.state',
#                           'pixels/top': 'observation.images.top',
#                           'top': 'observation.image.top'},
#          'fps': 50,
#          'obs_type': 'pixels_agent_pos',
#          'render_mode': 'rgb_array',
#          'task': 'AlohaTransferCube-v0'},
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'job_name': 'aloha_act',
#  'output_dir': PosixPath('output/post_eval/act_aloha_transfer'),
#  'policy': {'chunk_size': 100,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {'observation.images.top': {'shape': (3,
#                                                                     480,
#                                                                     640),
#                                                           'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                'observation.state': {'shape': (14,),
#                                                      'type': <FeatureType.STATE: 'STATE'>}},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'license': None,
#             'n_action_steps': 100,
#             'n_decoder_layers': 1,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {'action': {'shape': (14,),
#                                            'type': <FeatureType.ACTION: 'ACTION'>}},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'private': None,
#             'push_to_hub': False,
#             'replace_final_stride_with_dilation': 0,
#             'repo_id': None,
#             'tags': None,
#             'temporal_ensemble_coeff': None,
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'seed': 1000}
# INFO 2025-09-11 11:05:18 pts/eval.py:471 Output dir: output/post_eval/act_aloha_transfer
# INFO 2025-09-11 11:05:18 pts/eval.py:473 Making environment.
# INFO 2025-09-11 11:05:18 /__init__.py:88 MUJOCO_GL is not set, so an OpenGL backend will be chosen automatically.
# INFO 2025-09-11 11:05:18 /__init__.py:96 Successfully imported OpenGL backend: glfw
# INFO 2025-09-11 11:05:18 /__init__.py:31 MuJoCo library version is: 2.3.7
# INFO 2025-09-11 11:05:21 pts/eval.py:476 Making policy.
# Loading weights from local directory
# Stepping through eval batches:   0%|                      | 0/1 [00:00<?, ?it/s]
# Running rollout with at most 400 steps:   0%|           | 0/400 [00:00<?, ?it/s]/home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.task_description to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.task_description` for environment variables or `env.get_wrapper_attr('task_description')` that will search the reminding wrappers.
#   logger.warn(
# /home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/lerobot/scripts/eval.py:147: UserWarning: The environment does not have 'task_description' and 'task'. Some policies require these features.
#   check_env_attributes_and_types(env)
# /home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.task_description to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.task_description` for environment variables or `env.get_wrapper_attr('task_description')` that will search the reminding wrappers.
#   logger.warn(
# /home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.task to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.task` for environment variables or `env.get_wrapper_attr('task')` that will search the reminding wrappers.
#   logger.warn(
#
# Running rollout with at most 400 steps:   0%| | 0/400 [00:02<?, ?it/s, running_s
# Running rollout with at most 400 steps:   0%| | 1/400 [00:02<15:39,  2.35s/it, r
# Running rollout with at most 400 steps:   0%| | 1/400 [00:02<15:39,  2.35s/it, r
# Running rollout with at most 400 steps:   0%| | 2/400 [00:02<07:56,  1.20s/it, r
# Running rollout with at most 400 steps:   0%| | 2/400 [00:03<07:56,  1.20s/it, r
# Running rollout with at most 400 steps:   1%| | 3/400 [00:03<05:28,  1.21it/s, r
# Running rollout with at most 400 steps:   1%| | 3/400 [00:03<05:28,  1.21it/s, r
# Running rollout with at most 400 steps:   1%| | 4/400 [00:03<04:18,  1.53it/s, r
# Running rollout with at most 400 steps:   1%| | 4/400 [00:03<04:18,  1.53it/s, r
# Running rollout with at most 400 steps:   1%| | 5/400 [00:03<03:40,  1.79it/s, r
# Running rollout with at most 400 steps:   1%| | 5/400 [00:04<03:40,  1.79it/s, r
# Running rollout with at most 400 steps:   2%| | 6/400 [00:04<03:17,  2.00it/s, r
# Running rollout with at most 400 steps:   2%| | 6/400 [00:04<03:17,  2.00it/s, r
# Running rollout with at most 400 steps:   2%| | 7/400 [00:04<03:04,  2.13it/s, r
# Running rollout with at most 400 steps:   2%| | 7/400 [00:05<03:04,  2.13it/s, r
# Running rollout with at most 400 steps:   2%| | 8/400 [00:05<02:54,  2.24it/s, r
# Running rollout with at most 400 steps:   2%| | 8/400 [00:05<02:54,  2.24it/s, r
# Running rollout with at most 400 steps:   2%| | 9/400 [00:05<02:47,  2.34it/s, r
# Running rollout with at most 400 steps:   2%| | 9/400 [00:05<02:47,  2.34it/s, r
# Running rollout with at most 400 steps:   2%| | 10/400 [00:05<02:42,  2.41it/s,
# Running rollout with at most 400 steps:   2%| | 10/400 [00:06<02:42,  2.41it/s,
# Running rollout with at most 400 steps:   3%| | 11/400 [00:06<02:39,  2.45it/s,
# Running rollout with at most 400 steps:   3%| | 11/400 [00:06<02:39,  2.45it/s,
# Running rollout with at most 400 steps:   3%| | 12/400 [00:06<02:36,  2.48it/s,
# Running rollout with at most 400 steps:   3%| | 12/400 [00:07<02:36,  2.48it/s,
# Running rollout with at most 400 steps:   3%| | 13/400 [00:07<02:34,  2.51it/s,
# Running rollout with at most 400 steps:   3%| | 13/400 [00:07<02:34,  2.51it/s,
# Running rollout with at most 400 steps:   4%| | 14/400 [00:07<02:33,  2.52it/s,
# Running rollout with at most 400 steps:   4%| | 14/400 [00:07<02:33,  2.52it/s,
# Running rollout with at most 400 steps:   4%| | 15/400 [00:07<02:43,  2.36it/s,
# Running rollout with at most 400 steps:   4%| | 15/400 [00:08<02:43,  2.36it/s,
# Running rollout with at most 400 steps:   4%| | 16/400 [00:08<02:39,  2.41it/s,
# Running rollout with at most 400 steps:   4%| | 16/400 [00:08<02:39,  2.41it/s,
# Running rollout with at most 400 steps:   4%| | 17/400 [00:08<02:35,  2.46it/s,
# Running rollout with at most 400 steps:   4%| | 17/400 [00:09<02:35,  2.46it/s,
# Running rollout with at most 400 steps:   4%| | 18/400 [00:09<02:33,  2.49it/s,
# Running rollout with at most 400 steps:   4%| | 18/400 [00:09<02:33,  2.49it/s,
# Running rollout with at most 400 steps:   5%| | 19/400 [00:09<02:32,  2.49it/s,
# Running rollout with at most 400 steps:   5%| | 19/400 [00:09<02:32,  2.49it/s,
# Running rollout with at most 400 steps:   5%| | 20/400 [00:09<02:32,  2.49it/s,
# Running rollout with at most 400 steps:   5%| | 20/400 [00:10<02:32,  2.49it/s,
# Running rollout with at most 400 steps:   5%| | 21/400 [00:10<02:32,  2.49it/s,
# Running rollout with at most 400 steps:   5%| | 21/400 [00:10<02:32,  2.49it/s,
# Running rollout with at most 400 steps:   6%| | 22/400 [00:10<02:31,  2.50it/s,
# Running rollout with at most 400 steps:   6%| | 22/400 [00:11<02:31,  2.50it/s,
# Running rollout with at most 400 steps:   6%| | 23/400 [00:11<02:31,  2.49it/s,
# Running rollout with at most 400 steps:   6%| | 23/400 [00:11<02:31,  2.49it/s,
# Running rollout with at most 400 steps:   6%| | 24/400 [00:11<02:44,  2.28it/s,
# Running rollout with at most 400 steps:   6%| | 24/400 [00:12<02:44,  2.28it/s,
# Running rollout with at most 400 steps:   6%| | 25/400 [00:12<02:38,  2.36it/s,
# Running rollout with at most 400 steps:   6%| | 25/400 [00:12<02:38,  2.36it/s,
# Running rollout with at most 400 steps:   6%| | 26/400 [00:12<02:35,  2.40it/s,
# Running rollout with at most 400 steps:   6%| | 26/400 [00:12<02:35,  2.40it/s,
# Running rollout with at most 400 steps:   7%| | 27/400 [00:12<02:33,  2.43it/s,
# Running rollout with at most 400 steps:   7%| | 27/400 [00:13<02:33,  2.43it/s,
# Running rollout with at most 400 steps:   7%| | 28/400 [00:13<02:35,  2.40it/s,
# Running rollout with at most 400 steps:   7%| | 28/400 [00:13<02:35,  2.40it/s,
# Running rollout with at most 400 steps:   7%| | 29/400 [00:13<02:34,  2.40it/s,
# Running rollout with at most 400 steps:   7%| | 29/400 [00:14<02:34,  2.40it/s,
# Running rollout with at most 400 steps:   8%| | 30/400 [00:14<02:32,  2.43it/s,
# Running rollout with at most 400 steps:   8%| | 30/400 [00:14<02:32,  2.43it/s,
# Running rollout with at most 400 steps:   8%| | 31/400 [00:14<02:30,  2.44it/s,
# Running rollout with at most 400 steps:   8%| | 31/400 [00:14<02:30,  2.44it/s,
# Running rollout with at most 400 steps:   8%| | 32/400 [00:14<02:30,  2.45it/s,
# Running rollout with at most 400 steps:   8%| | 32/400 [00:15<02:30,  2.45it/s,
# Running rollout with at most 400 steps:   8%| | 33/400 [00:15<02:28,  2.47it/s,
# Running rollout with at most 400 steps:   8%| | 33/400 [00:15<02:28,  2.47it/s,
# Running rollout with at most 400 steps:   8%| | 34/400 [00:15<02:27,  2.48it/s,
# Running rollout with at most 400 steps:   8%| | 34/400 [00:16<02:27,  2.48it/s,
# Running rollout with at most 400 steps:   9%| | 35/400 [00:16<02:26,  2.49it/s,
# Running rollout with at most 400 steps:   9%| | 35/400 [00:16<02:26,  2.49it/s,
# Running rollout with at most 400 steps:   9%| | 36/400 [00:16<02:26,  2.49it/s,
# Running rollout with at most 400 steps:   9%| | 36/400 [00:17<02:26,  2.49it/s,
# Running rollout with at most 400 steps:   9%| | 37/400 [00:17<02:43,  2.22it/s,
# Running rollout with at most 400 steps:   9%| | 37/400 [00:17<02:43,  2.22it/s,
# Running rollout with at most 400 steps:  10%| | 38/400 [00:17<02:41,  2.24it/s,
# Running rollout with at most 400 steps:  10%| | 38/400 [00:17<02:41,  2.24it/s,
# Running rollout with at most 400 steps:  10%| | 39/400 [00:17<02:35,  2.32it/s,
# Running rollout with at most 400 steps:  10%| | 39/400 [00:18<02:35,  2.32it/s,
# Running rollout with at most 400 steps:  10%| | 40/400 [00:18<02:31,  2.38it/s,
# Running rollout with at most 400 steps:  10%| | 40/400 [00:18<02:31,  2.38it/s,
# Running rollout with at most 400 steps:  10%| | 41/400 [00:18<02:27,  2.43it/s,
# Running rollout with at most 400 steps:  10%| | 41/400 [00:19<02:27,  2.43it/s,
# Running rollout with at most 400 steps:  10%| | 42/400 [00:19<02:26,  2.44it/s,
# Running rollout with at most 400 steps:  10%| | 42/400 [00:19<02:26,  2.44it/s,
# Running rollout with at most 400 steps:  11%| | 43/400 [00:19<02:24,  2.47it/s,
# Running rollout with at most 400 steps:  11%| | 43/400 [00:19<02:24,  2.47it/s,
# Running rollout with at most 400 steps:  11%| | 44/400 [00:19<02:23,  2.48it/s,
# Running rollout with at most 400 steps:  11%| | 44/400 [00:20<02:23,  2.48it/s,
# Running rollout with at most 400 steps:  11%| | 45/400 [00:20<02:33,  2.32it/s,
# Running rollout with at most 400 steps:  11%| | 45/400 [00:20<02:33,  2.32it/s,
# Running rollout with at most 400 steps:  12%| | 46/400 [00:20<02:30,  2.36it/s,
# Running rollout with at most 400 steps:  12%| | 46/400 [00:21<02:30,  2.36it/s,
# Running rollout with at most 400 steps:  12%| | 47/400 [00:21<02:27,  2.40it/s,
# Running rollout with at most 400 steps:  12%| | 47/400 [00:21<02:27,  2.40it/s,
# Running rollout with at most 400 steps:  12%| | 48/400 [00:21<02:25,  2.41it/s,
# Running rollout with at most 400 steps:  12%| | 48/400 [00:21<02:25,  2.41it/s,
# Running rollout with at most 400 steps:  12%| | 49/400 [00:21<02:23,  2.44it/s,
# Running rollout with at most 400 steps:  12%| | 49/400 [00:22<02:23,  2.44it/s,
# Running rollout with at most 400 steps:  12%|▏| 50/400 [00:22<02:23,  2.44it/s,
# Running rollout with at most 400 steps:  12%|▏| 50/400 [00:22<02:23,  2.44it/s,
# Running rollout with at most 400 steps:  13%|▏| 51/400 [00:22<02:22,  2.45it/s,
# Running rollout with at most 400 steps:  13%|▏| 51/400 [00:23<02:22,  2.45it/s,
# Running rollout with at most 400 steps:  13%|▏| 52/400 [00:23<02:26,  2.38it/s,
# Running rollout with at most 400 steps:  13%|▏| 52/400 [00:23<02:26,  2.38it/s,
# Running rollout with at most 400 steps:  13%|▏| 53/400 [00:23<02:25,  2.39it/s,
# Running rollout with at most 400 steps:  13%|▏| 53/400 [00:24<02:25,  2.39it/s,
# Running rollout with at most 400 steps:  14%|▏| 54/400 [00:24<02:22,  2.42it/s,
# Running rollout with at most 400 steps:  14%|▏| 54/400 [00:24<02:22,  2.42it/s,
# Running rollout with at most 400 steps:  14%|▏| 55/400 [00:24<02:20,  2.45it/s,
# Running rollout with at most 400 steps:  14%|▏| 55/400 [00:24<02:20,  2.45it/s,
# Running rollout with at most 400 steps:  14%|▏| 56/400 [00:24<02:24,  2.37it/s,
# Running rollout with at most 400 steps:  14%|▏| 56/400 [00:25<02:24,  2.37it/s,
# Running rollout with at most 400 steps:  14%|▏| 57/400 [00:25<02:37,  2.18it/s,
# Running rollout with at most 400 steps:  14%|▏| 57/400 [00:25<02:37,  2.18it/s,
# Running rollout with at most 400 steps:  14%|▏| 58/400 [00:25<02:32,  2.25it/s,
# Running rollout with at most 400 steps:  14%|▏| 58/400 [00:26<02:32,  2.25it/s,
# Running rollout with at most 400 steps:  15%|▏| 59/400 [00:26<03:04,  1.85it/s,
# Running rollout with at most 400 steps:  15%|▏| 59/400 [00:27<03:04,  1.85it/s,
# Running rollout with at most 400 steps:  15%|▏| 60/400 [00:27<02:51,  1.98it/s,
# Running rollout with at most 400 steps:  15%|▏| 60/400 [00:27<02:51,  1.98it/s,
# Running rollout with at most 400 steps:  15%|▏| 61/400 [00:27<02:41,  2.10it/s,
# Running rollout with at most 400 steps:  15%|▏| 61/400 [00:27<02:41,  2.10it/s,
# Running rollout with at most 400 steps:  16%|▏| 62/400 [00:27<02:39,  2.12it/s,
# Running rollout with at most 400 steps:  16%|▏| 62/400 [00:28<02:39,  2.12it/s,
# Running rollout with at most 400 steps:  16%|▏| 63/400 [00:28<02:35,  2.17it/s,
# Running rollout with at most 400 steps:  16%|▏| 63/400 [00:28<02:35,  2.17it/s,
# Running rollout with at most 400 steps:  16%|▏| 64/400 [00:28<02:28,  2.26it/s,
# Running rollout with at most 400 steps:  16%|▏| 64/400 [00:29<02:28,  2.26it/s,
# Running rollout with at most 400 steps:  16%|▏| 65/400 [00:29<02:23,  2.33it/s,
# Running rollout with at most 400 steps:  16%|▏| 65/400 [00:29<02:23,  2.33it/s,
# Running rollout with at most 400 steps:  16%|▏| 66/400 [00:29<02:30,  2.21it/s,
# Running rollout with at most 400 steps:  16%|▏| 66/400 [00:30<02:30,  2.21it/s,
# Running rollout with at most 400 steps:  17%|▏| 67/400 [00:30<02:25,  2.29it/s,
# Running rollout with at most 400 steps:  17%|▏| 67/400 [00:30<02:25,  2.29it/s,
# Running rollout with at most 400 steps:  17%|▏| 68/400 [00:30<02:34,  2.15it/s,
# Running rollout with at most 400 steps:  17%|▏| 68/400 [00:30<02:34,  2.15it/s,
# Running rollout with at most 400 steps:  17%|▏| 69/400 [00:30<02:28,  2.23it/s,
# Running rollout with at most 400 steps:  17%|▏| 69/400 [00:31<02:28,  2.23it/s,
# Running rollout with at most 400 steps:  18%|▏| 70/400 [00:31<02:23,  2.29it/s,
# Running rollout with at most 400 steps:  18%|▏| 70/400 [00:31<02:23,  2.29it/s,
# Running rollout with at most 400 steps:  18%|▏| 71/400 [00:31<02:21,  2.33it/s,
# Running rollout with at most 400 steps:  18%|▏| 71/400 [00:32<02:21,  2.33it/s,
# Running rollout with at most 400 steps:  18%|▏| 72/400 [00:32<02:17,  2.38it/s,
# Running rollout with at most 400 steps:  18%|▏| 72/400 [00:32<02:17,  2.38it/s,
# Running rollout with at most 400 steps:  18%|▏| 73/400 [00:32<02:15,  2.41it/s,
# Running rollout with at most 400 steps:  18%|▏| 73/400 [00:33<02:15,  2.41it/s,
# Running rollout with at most 400 steps:  18%|▏| 74/400 [00:33<02:14,  2.43it/s,
# Running rollout with at most 400 steps:  18%|▏| 74/400 [00:33<02:14,  2.43it/s,
# Running rollout with at most 400 steps:  19%|▏| 75/400 [00:33<02:12,  2.46it/s,
# Running rollout with at most 400 steps:  19%|▏| 75/400 [00:33<02:12,  2.46it/s,
# Running rollout with at most 400 steps:  19%|▏| 76/400 [00:33<02:10,  2.48it/s,
# Running rollout with at most 400 steps:  19%|▏| 76/400 [00:34<02:10,  2.48it/s,
# Running rollout with at most 400 steps:  19%|▏| 77/400 [00:34<02:10,  2.48it/s,
# Running rollout with at most 400 steps:  19%|▏| 77/400 [00:34<02:10,  2.48it/s,
# Running rollout with at most 400 steps:  20%|▏| 78/400 [00:34<02:09,  2.48it/s,
# Running rollout with at most 400 steps:  20%|▏| 78/400 [00:35<02:09,  2.48it/s,
# Running rollout with at most 400 steps:  20%|▏| 79/400 [00:35<02:09,  2.49it/s,
# Running rollout with at most 400 steps:  20%|▏| 79/400 [00:35<02:09,  2.49it/s,
# Running rollout with at most 400 steps:  20%|▏| 80/400 [00:35<02:10,  2.44it/s,
# Running rollout with at most 400 steps:  20%|▏| 80/400 [00:35<02:10,  2.44it/s,
# Running rollout with at most 400 steps:  20%|▏| 81/400 [00:35<02:10,  2.44it/s,
# Running rollout with at most 400 steps:  20%|▏| 81/400 [00:36<02:10,  2.44it/s,
# Running rollout with at most 400 steps:  20%|▏| 82/400 [00:36<02:09,  2.45it/s,
# Running rollout with at most 400 steps:  20%|▏| 82/400 [00:36<02:09,  2.45it/s,
# Running rollout with at most 400 steps:  21%|▏| 83/400 [00:36<02:09,  2.45it/s,
# Running rollout with at most 400 steps:  21%|▏| 83/400 [00:37<02:09,  2.45it/s,
# Running rollout with at most 400 steps:  21%|▏| 84/400 [00:37<02:12,  2.39it/s,
# Running rollout with at most 400 steps:  21%|▏| 84/400 [00:37<02:12,  2.39it/s,
# Running rollout with at most 400 steps:  21%|▏| 85/400 [00:37<02:16,  2.31it/s,
# Running rollout with at most 400 steps:  21%|▏| 85/400 [00:37<02:16,  2.31it/s,
# Running rollout with at most 400 steps:  22%|▏| 86/400 [00:37<02:13,  2.35it/s,
# Running rollout with at most 400 steps:  22%|▏| 86/400 [00:38<02:13,  2.35it/s,
# Running rollout with at most 400 steps:  22%|▏| 87/400 [00:38<02:13,  2.34it/s,
# Running rollout with at most 400 steps:  22%|▏| 87/400 [00:38<02:13,  2.34it/s,
# Running rollout with at most 400 steps:  22%|▏| 88/400 [00:38<02:19,  2.23it/s,
# Running rollout with at most 400 steps:  22%|▏| 88/400 [00:39<02:19,  2.23it/s,
# Running rollout with at most 400 steps:  22%|▏| 89/400 [00:39<02:20,  2.22it/s,
# Running rollout with at most 400 steps:  22%|▏| 89/400 [00:39<02:20,  2.22it/s,
# Running rollout with at most 400 steps:  22%|▏| 90/400 [00:39<02:18,  2.23it/s,
# Running rollout with at most 400 steps:  22%|▏| 90/400 [00:40<02:18,  2.23it/s,
# Running rollout with at most 400 steps:  23%|▏| 91/400 [00:40<02:15,  2.29it/s,
# Running rollout with at most 400 steps:  23%|▏| 91/400 [00:40<02:15,  2.29it/s,
# Running rollout with at most 400 steps:  23%|▏| 92/400 [00:40<02:12,  2.33it/s,
# Running rollout with at most 400 steps:  23%|▏| 92/400 [00:41<02:12,  2.33it/s,
# Running rollout with at most 400 steps:  23%|▏| 93/400 [00:41<02:10,  2.36it/s,
# Running rollout with at most 400 steps:  23%|▏| 93/400 [00:41<02:10,  2.36it/s,
# Running rollout with at most 400 steps:  24%|▏| 94/400 [00:41<02:08,  2.39it/s,
# Running rollout with at most 400 steps:  24%|▏| 94/400 [00:41<02:08,  2.39it/s,
# Running rollout with at most 400 steps:  24%|▏| 95/400 [00:41<02:15,  2.25it/s,
# Running rollout with at most 400 steps:  24%|▏| 95/400 [00:42<02:15,  2.25it/s,
# Running rollout with at most 400 steps:  24%|▏| 96/400 [00:42<02:11,  2.32it/s,
# Running rollout with at most 400 steps:  24%|▏| 96/400 [00:42<02:11,  2.32it/s,
# Running rollout with at most 400 steps:  24%|▏| 97/400 [00:42<02:19,  2.17it/s,
# Running rollout with at most 400 steps:  24%|▏| 97/400 [00:43<02:19,  2.17it/s,
# Running rollout with at most 400 steps:  24%|▏| 98/400 [00:43<02:14,  2.25it/s,
# Running rollout with at most 400 steps:  24%|▏| 98/400 [00:43<02:14,  2.25it/s,
# Running rollout with at most 400 steps:  25%|▏| 99/400 [00:43<02:10,  2.31it/s,
# Running rollout with at most 400 steps:  25%|▏| 99/400 [00:44<02:10,  2.31it/s,
# Running rollout with at most 400 steps:  25%|▎| 100/400 [00:44<02:07,  2.36it/s,
# Running rollout with at most 400 steps:  25%|▎| 100/400 [00:44<02:07,  2.36it/s,
# Running rollout with at most 400 steps:  25%|▎| 101/400 [00:44<02:22,  2.10it/s,
# Running rollout with at most 400 steps:  25%|▎| 101/400 [00:45<02:22,  2.10it/s,
# Running rollout with at most 400 steps:  26%|▎| 102/400 [00:45<02:14,  2.21it/s,
# Running rollout with at most 400 steps:  26%|▎| 102/400 [00:45<02:14,  2.21it/s,
# Running rollout with at most 400 steps:  26%|▎| 103/400 [00:45<02:10,  2.28it/s,
# Running rollout with at most 400 steps:  26%|▎| 103/400 [00:45<02:10,  2.28it/s,
# Running rollout with at most 400 steps:  26%|▎| 104/400 [00:45<02:06,  2.34it/s,
# Running rollout with at most 400 steps:  26%|▎| 104/400 [00:46<02:06,  2.34it/s,
# Running rollout with at most 400 steps:  26%|▎| 105/400 [00:46<02:04,  2.38it/s,
# Running rollout with at most 400 steps:  26%|▎| 105/400 [00:46<02:04,  2.38it/s,
# Running rollout with at most 400 steps:  26%|▎| 106/400 [00:46<02:02,  2.39it/s,
# Running rollout with at most 400 steps:  26%|▎| 106/400 [00:47<02:02,  2.39it/s,
# Running rollout with at most 400 steps:  27%|▎| 107/400 [00:47<02:03,  2.38it/s,
# Running rollout with at most 400 steps:  27%|▎| 107/400 [00:47<02:03,  2.38it/s,
# Running rollout with at most 400 steps:  27%|▎| 108/400 [00:47<02:02,  2.38it/s,
# Running rollout with at most 400 steps:  27%|▎| 108/400 [00:48<02:02,  2.38it/s,
# Running rollout with at most 400 steps:  27%|▎| 109/400 [00:48<02:08,  2.26it/s,
# Running rollout with at most 400 steps:  27%|▎| 109/400 [00:48<02:08,  2.26it/s,
# Running rollout with at most 400 steps:  28%|▎| 110/400 [00:48<02:10,  2.23it/s,
# Running rollout with at most 400 steps:  28%|▎| 110/400 [00:48<02:10,  2.23it/s,
# Running rollout with at most 400 steps:  28%|▎| 111/400 [00:48<02:05,  2.30it/s,
# Running rollout with at most 400 steps:  28%|▎| 111/400 [00:49<02:05,  2.30it/s,
# Running rollout with at most 400 steps:  28%|▎| 112/400 [00:49<02:02,  2.35it/s,
# Running rollout with at most 400 steps:  28%|▎| 112/400 [00:49<02:02,  2.35it/s,
# Running rollout with at most 400 steps:  28%|▎| 113/400 [00:49<02:00,  2.39it/s,
# Running rollout with at most 400 steps:  28%|▎| 113/400 [00:50<02:00,  2.39it/s,
# Running rollout with at most 400 steps:  28%|▎| 114/400 [00:50<01:58,  2.41it/s,
# Running rollout with at most 400 steps:  28%|▎| 114/400 [00:50<01:58,  2.41it/s,
# Running rollout with at most 400 steps:  29%|▎| 115/400 [00:50<01:57,  2.43it/s,
# Running rollout with at most 400 steps:  29%|▎| 115/400 [00:50<01:57,  2.43it/s,
# Running rollout with at most 400 steps:  29%|▎| 116/400 [00:50<01:55,  2.45it/s,
# Running rollout with at most 400 steps:  29%|▎| 116/400 [00:51<01:55,  2.45it/s,
# Running rollout with at most 400 steps:  29%|▎| 117/400 [00:51<01:55,  2.46it/s,
# Running rollout with at most 400 steps:  29%|▎| 117/400 [00:51<01:55,  2.46it/s,
# Running rollout with at most 400 steps:  30%|▎| 118/400 [00:51<01:54,  2.46it/s,
# Running rollout with at most 400 steps:  30%|▎| 118/400 [00:52<01:54,  2.46it/s,
# Running rollout with at most 400 steps:  30%|▎| 119/400 [00:52<01:54,  2.46it/s,
# Running rollout with at most 400 steps:  30%|▎| 119/400 [00:52<01:54,  2.46it/s,
# Running rollout with at most 400 steps:  30%|▎| 120/400 [00:52<01:53,  2.47it/s,
# Running rollout with at most 400 steps:  30%|▎| 120/400 [00:52<01:53,  2.47it/s,
# Running rollout with at most 400 steps:  30%|▎| 121/400 [00:52<01:53,  2.46it/s,
# Running rollout with at most 400 steps:  30%|▎| 121/400 [00:53<01:53,  2.46it/s,
# Running rollout with at most 400 steps:  30%|▎| 122/400 [00:53<01:53,  2.44it/s,
# Running rollout with at most 400 steps:  30%|▎| 122/400 [00:53<01:53,  2.44it/s,
# Running rollout with at most 400 steps:  31%|▎| 123/400 [00:53<01:53,  2.45it/s,
# Running rollout with at most 400 steps:  31%|▎| 123/400 [00:54<01:53,  2.45it/s,
# Running rollout with at most 400 steps:  31%|▎| 124/400 [00:54<01:52,  2.46it/s,
# Running rollout with at most 400 steps:  31%|▎| 124/400 [00:54<01:52,  2.46it/s,
# Running rollout with at most 400 steps:  31%|▎| 125/400 [00:54<01:51,  2.46it/s,
# Running rollout with at most 400 steps:  31%|▎| 125/400 [00:54<01:51,  2.46it/s,
# Running rollout with at most 400 steps:  32%|▎| 126/400 [00:54<01:51,  2.45it/s,
# Running rollout with at most 400 steps:  32%|▎| 126/400 [00:55<01:51,  2.45it/s,
# Running rollout with at most 400 steps:  32%|▎| 127/400 [00:55<01:52,  2.43it/s,
# Running rollout with at most 400 steps:  32%|▎| 127/400 [00:55<01:52,  2.43it/s,
# Running rollout with at most 400 steps:  32%|▎| 128/400 [00:55<01:51,  2.43it/s,
# Running rollout with at most 400 steps:  32%|▎| 128/400 [00:56<01:51,  2.43it/s,
# Running rollout with at most 400 steps:  32%|▎| 129/400 [00:56<02:11,  2.06it/s,
# Running rollout with at most 400 steps:  32%|▎| 129/400 [00:56<02:11,  2.06it/s,
# Running rollout with at most 400 steps:  32%|▎| 130/400 [00:56<02:05,  2.15it/s,
# Running rollout with at most 400 steps:  32%|▎| 130/400 [00:57<02:05,  2.15it/s,
# Running rollout with at most 400 steps:  33%|▎| 131/400 [00:57<02:00,  2.24it/s,
# Running rollout with at most 400 steps:  33%|▎| 131/400 [00:57<02:00,  2.24it/s,
# Running rollout with at most 400 steps:  33%|▎| 132/400 [00:57<01:56,  2.30it/s,
# Running rollout with at most 400 steps:  33%|▎| 132/400 [00:58<01:56,  2.30it/s,
# Running rollout with at most 400 steps:  33%|▎| 133/400 [00:58<01:56,  2.29it/s,
# Running rollout with at most 400 steps:  33%|▎| 133/400 [00:58<01:56,  2.29it/s,
# Running rollout with at most 400 steps:  34%|▎| 134/400 [00:58<01:55,  2.31it/s,
# Running rollout with at most 400 steps:  34%|▎| 134/400 [00:58<01:55,  2.31it/s,
# Running rollout with at most 400 steps:  34%|▎| 135/400 [00:58<01:52,  2.36it/s,
# Running rollout with at most 400 steps:  34%|▎| 135/400 [00:59<01:52,  2.36it/s,
# Running rollout with at most 400 steps:  34%|▎| 136/400 [00:59<01:50,  2.38it/s,
# Running rollout with at most 400 steps:  34%|▎| 136/400 [00:59<01:50,  2.38it/s,
# Running rollout with at most 400 steps:  34%|▎| 137/400 [00:59<01:49,  2.40it/s,
# Running rollout with at most 400 steps:  34%|▎| 137/400 [01:00<01:49,  2.40it/s,
# Running rollout with at most 400 steps:  34%|▎| 138/400 [01:00<01:48,  2.42it/s,
# Running rollout with at most 400 steps:  34%|▎| 138/400 [01:00<01:48,  2.42it/s,
# Running rollout with at most 400 steps:  35%|▎| 139/400 [01:00<01:47,  2.43it/s,
# Running rollout with at most 400 steps:  35%|▎| 139/400 [01:01<01:47,  2.43it/s,
# Running rollout with at most 400 steps:  35%|▎| 140/400 [01:01<01:52,  2.31it/s,
# Running rollout with at most 400 steps:  35%|▎| 140/400 [01:01<01:52,  2.31it/s,
# Running rollout with at most 400 steps:  35%|▎| 141/400 [01:01<01:52,  2.30it/s,
# Running rollout with at most 400 steps:  35%|▎| 141/400 [01:01<01:52,  2.30it/s,
# Running rollout with at most 400 steps:  36%|▎| 142/400 [01:01<01:50,  2.34it/s,
# Running rollout with at most 400 steps:  36%|▎| 142/400 [01:02<01:50,  2.34it/s,
# Running rollout with at most 400 steps:  36%|▎| 143/400 [01:02<01:48,  2.37it/s,
# Running rollout with at most 400 steps:  36%|▎| 143/400 [01:02<01:48,  2.37it/s,
# Running rollout with at most 400 steps:  36%|▎| 144/400 [01:02<01:46,  2.40it/s,
# Running rollout with at most 400 steps:  36%|▎| 144/400 [01:03<01:46,  2.40it/s,
# Running rollout with at most 400 steps:  36%|▎| 145/400 [01:03<01:45,  2.41it/s,
# Running rollout with at most 400 steps:  36%|▎| 145/400 [01:03<01:45,  2.41it/s,
# Running rollout with at most 400 steps:  36%|▎| 146/400 [01:03<01:45,  2.42it/s,
# Running rollout with at most 400 steps:  36%|▎| 146/400 [01:03<01:45,  2.42it/s,
# Running rollout with at most 400 steps:  37%|▎| 147/400 [01:03<01:44,  2.41it/s,
# Running rollout with at most 400 steps:  37%|▎| 147/400 [01:04<01:44,  2.41it/s,
# Running rollout with at most 400 steps:  37%|▎| 148/400 [01:04<01:44,  2.41it/s,
# Running rollout with at most 400 steps:  37%|▎| 148/400 [01:04<01:44,  2.41it/s,
# Running rollout with at most 400 steps:  37%|▎| 149/400 [01:04<01:44,  2.41it/s,
# Running rollout with at most 400 steps:  37%|▎| 149/400 [01:05<01:44,  2.41it/s,
# Running rollout with at most 400 steps:  38%|▍| 150/400 [01:05<01:52,  2.22it/s,
# Running rollout with at most 400 steps:  38%|▍| 150/400 [01:05<01:52,  2.22it/s,
# Running rollout with at most 400 steps:  38%|▍| 151/400 [01:05<01:50,  2.26it/s,
# Running rollout with at most 400 steps:  38%|▍| 151/400 [01:06<01:50,  2.26it/s,
# Running rollout with at most 400 steps:  38%|▍| 152/400 [01:06<01:47,  2.30it/s,
# Running rollout with at most 400 steps:  38%|▍| 152/400 [01:06<01:47,  2.30it/s,
# Running rollout with at most 400 steps:  38%|▍| 153/400 [01:06<01:44,  2.36it/s,
# Running rollout with at most 400 steps:  38%|▍| 153/400 [01:07<01:44,  2.36it/s,
# Running rollout with at most 400 steps:  38%|▍| 154/400 [01:07<01:42,  2.40it/s,
# Running rollout with at most 400 steps:  38%|▍| 154/400 [01:07<01:42,  2.40it/s,
# Running rollout with at most 400 steps:  39%|▍| 155/400 [01:07<01:41,  2.41it/s,
# Running rollout with at most 400 steps:  39%|▍| 155/400 [01:07<01:41,  2.41it/s,
# Running rollout with at most 400 steps:  39%|▍| 156/400 [01:07<01:44,  2.34it/s,
# Running rollout with at most 400 steps:  39%|▍| 156/400 [01:08<01:44,  2.34it/s,
# Running rollout with at most 400 steps:  39%|▍| 157/400 [01:08<01:45,  2.30it/s,
# Running rollout with at most 400 steps:  39%|▍| 157/400 [01:08<01:45,  2.30it/s,
# Running rollout with at most 400 steps:  40%|▍| 158/400 [01:08<01:51,  2.17it/s,
# Running rollout with at most 400 steps:  40%|▍| 158/400 [01:09<01:51,  2.17it/s,
# Running rollout with at most 400 steps:  40%|▍| 159/400 [01:09<01:48,  2.22it/s,
# Running rollout with at most 400 steps:  40%|▍| 159/400 [01:09<01:48,  2.22it/s,
# Running rollout with at most 400 steps:  40%|▍| 160/400 [01:09<01:50,  2.17it/s,
# Running rollout with at most 400 steps:  40%|▍| 160/400 [01:10<01:50,  2.17it/s,
# Running rollout with at most 400 steps:  40%|▍| 161/400 [01:10<01:46,  2.24it/s,
# Running rollout with at most 400 steps:  40%|▍| 161/400 [01:10<01:46,  2.24it/s,
# Running rollout with at most 400 steps:  40%|▍| 162/400 [01:10<01:43,  2.30it/s,
# Running rollout with at most 400 steps:  40%|▍| 162/400 [01:11<01:43,  2.30it/s,
# Running rollout with at most 400 steps:  41%|▍| 163/400 [01:11<01:47,  2.21it/s,
# Running rollout with at most 400 steps:  41%|▍| 163/400 [01:11<01:47,  2.21it/s,
# Running rollout with at most 400 steps:  41%|▍| 164/400 [01:11<01:44,  2.25it/s,
# Running rollout with at most 400 steps:  41%|▍| 164/400 [01:11<01:44,  2.25it/s,
# Running rollout with at most 400 steps:  41%|▍| 165/400 [01:11<01:41,  2.30it/s,
# Running rollout with at most 400 steps:  41%|▍| 165/400 [01:12<01:41,  2.30it/s,
# Running rollout with at most 400 steps:  42%|▍| 166/400 [01:12<01:44,  2.24it/s,
# Running rollout with at most 400 steps:  42%|▍| 166/400 [01:12<01:44,  2.24it/s,
# Running rollout with at most 400 steps:  42%|▍| 167/400 [01:12<01:43,  2.24it/s,
# Running rollout with at most 400 steps:  42%|▍| 167/400 [01:13<01:43,  2.24it/s,
# Running rollout with at most 400 steps:  42%|▍| 168/400 [01:13<01:46,  2.18it/s,
# Running rollout with at most 400 steps:  42%|▍| 168/400 [01:13<01:46,  2.18it/s,
# Running rollout with at most 400 steps:  42%|▍| 169/400 [01:13<01:43,  2.23it/s,
# Running rollout with at most 400 steps:  42%|▍| 169/400 [01:14<01:43,  2.23it/s,
# Running rollout with at most 400 steps:  42%|▍| 170/400 [01:14<01:41,  2.27it/s,
# Running rollout with at most 400 steps:  42%|▍| 170/400 [01:14<01:41,  2.27it/s,
# Running rollout with at most 400 steps:  43%|▍| 171/400 [01:14<01:39,  2.31it/s,
# Running rollout with at most 400 steps:  43%|▍| 171/400 [01:14<01:39,  2.31it/s,
# Running rollout with at most 400 steps:  43%|▍| 172/400 [01:14<01:37,  2.33it/s,
# Running rollout with at most 400 steps:  43%|▍| 172/400 [01:15<01:37,  2.33it/s,
# Running rollout with at most 400 steps:  43%|▍| 173/400 [01:15<01:36,  2.35it/s,
# Running rollout with at most 400 steps:  43%|▍| 173/400 [01:15<01:36,  2.35it/s,
# Running rollout with at most 400 steps:  44%|▍| 174/400 [01:15<01:41,  2.22it/s,
# Running rollout with at most 400 steps:  44%|▍| 174/400 [01:16<01:41,  2.22it/s,
# Running rollout with at most 400 steps:  44%|▍| 175/400 [01:16<01:46,  2.11it/s,
# Running rollout with at most 400 steps:  44%|▍| 175/400 [01:16<01:46,  2.11it/s,
# Running rollout with at most 400 steps:  44%|▍| 176/400 [01:16<01:42,  2.18it/s,
# Running rollout with at most 400 steps:  44%|▍| 176/400 [01:17<01:42,  2.18it/s,
# Running rollout with at most 400 steps:  44%|▍| 177/400 [01:17<01:39,  2.25it/s,
# Running rollout with at most 400 steps:  44%|▍| 177/400 [01:17<01:39,  2.25it/s,
# Running rollout with at most 400 steps:  44%|▍| 178/400 [01:17<01:36,  2.30it/s,
# Running rollout with at most 400 steps:  44%|▍| 178/400 [01:18<01:36,  2.30it/s,
# Running rollout with at most 400 steps:  45%|▍| 179/400 [01:18<01:34,  2.33it/s,
# Running rollout with at most 400 steps:  45%|▍| 179/400 [01:18<01:34,  2.33it/s,
# Running rollout with at most 400 steps:  45%|▍| 180/400 [01:18<01:33,  2.35it/s,
# Running rollout with at most 400 steps:  45%|▍| 180/400 [01:18<01:33,  2.35it/s,
# Running rollout with at most 400 steps:  45%|▍| 181/400 [01:18<01:32,  2.37it/s,
# Running rollout with at most 400 steps:  45%|▍| 181/400 [01:19<01:32,  2.37it/s,
# Running rollout with at most 400 steps:  46%|▍| 182/400 [01:19<01:31,  2.39it/s,
# Running rollout with at most 400 steps:  46%|▍| 182/400 [01:19<01:31,  2.39it/s,
# Running rollout with at most 400 steps:  46%|▍| 183/400 [01:19<01:29,  2.42it/s,
# Running rollout with at most 400 steps:  46%|▍| 183/400 [01:20<01:29,  2.42it/s,
# Running rollout with at most 400 steps:  46%|▍| 184/400 [01:20<01:29,  2.43it/s,
# Running rollout with at most 400 steps:  46%|▍| 184/400 [01:20<01:29,  2.43it/s,
# Running rollout with at most 400 steps:  46%|▍| 185/400 [01:20<01:27,  2.44it/s,
# Running rollout with at most 400 steps:  46%|▍| 185/400 [01:20<01:27,  2.44it/s,
# Running rollout with at most 400 steps:  46%|▍| 186/400 [01:20<01:27,  2.44it/s,
# Running rollout with at most 400 steps:  46%|▍| 186/400 [01:21<01:27,  2.44it/s,
# Running rollout with at most 400 steps:  47%|▍| 187/400 [01:21<01:27,  2.44it/s,
# Running rollout with at most 400 steps:  47%|▍| 187/400 [01:21<01:27,  2.44it/s,
# Running rollout with at most 400 steps:  47%|▍| 188/400 [01:21<01:27,  2.42it/s,
# Running rollout with at most 400 steps:  47%|▍| 188/400 [01:22<01:27,  2.42it/s,
# Running rollout with at most 400 steps:  47%|▍| 189/400 [01:22<01:26,  2.43it/s,
# Running rollout with at most 400 steps:  47%|▍| 189/400 [01:22<01:26,  2.43it/s,
# Running rollout with at most 400 steps:  48%|▍| 190/400 [01:22<01:26,  2.44it/s,
# Running rollout with at most 400 steps:  48%|▍| 190/400 [01:23<01:26,  2.44it/s,
# Running rollout with at most 400 steps:  48%|▍| 191/400 [01:23<01:25,  2.44it/s,
# Running rollout with at most 400 steps:  48%|▍| 191/400 [01:23<01:25,  2.44it/s,
# Running rollout with at most 400 steps:  48%|▍| 192/400 [01:23<01:25,  2.44it/s,
# Running rollout with at most 400 steps:  48%|▍| 192/400 [01:23<01:25,  2.44it/s,
# Running rollout with at most 400 steps:  48%|▍| 193/400 [01:23<01:24,  2.45it/s,
# Running rollout with at most 400 steps:  48%|▍| 193/400 [01:24<01:24,  2.45it/s,
# Running rollout with at most 400 steps:  48%|▍| 194/400 [01:24<01:34,  2.19it/s,
# Running rollout with at most 400 steps:  48%|▍| 194/400 [01:24<01:34,  2.19it/s,
# Running rollout with at most 400 steps:  49%|▍| 195/400 [01:24<01:34,  2.17it/s,
# Running rollout with at most 400 steps:  49%|▍| 195/400 [01:25<01:34,  2.17it/s,
# Running rollout with at most 400 steps:  49%|▍| 196/400 [01:25<01:30,  2.24it/s,
# Running rollout with at most 400 steps:  49%|▍| 196/400 [01:25<01:30,  2.24it/s,
# Running rollout with at most 400 steps:  49%|▍| 197/400 [01:25<01:34,  2.14it/s,
# Running rollout with at most 400 steps:  49%|▍| 197/400 [01:26<01:34,  2.14it/s,
# Running rollout with at most 400 steps:  50%|▍| 198/400 [01:26<01:33,  2.16it/s,
# Running rollout with at most 400 steps:  50%|▍| 198/400 [01:26<01:33,  2.16it/s,
# Running rollout with at most 400 steps:  50%|▍| 199/400 [01:26<01:30,  2.23it/s,
# Running rollout with at most 400 steps:  50%|▍| 199/400 [01:27<01:30,  2.23it/s,
# Running rollout with at most 400 steps:  50%|▌| 200/400 [01:27<01:27,  2.29it/s,
# Running rollout with at most 400 steps:  50%|▌| 200/400 [01:27<01:27,  2.29it/s,
# Running rollout with at most 400 steps:  50%|▌| 201/400 [01:27<01:38,  2.02it/s,
# Running rollout with at most 400 steps:  50%|▌| 201/400 [01:28<01:38,  2.02it/s,
# Running rollout with at most 400 steps:  50%|▌| 202/400 [01:28<01:34,  2.10it/s,
# Running rollout with at most 400 steps:  50%|▌| 202/400 [01:28<01:34,  2.10it/s,
# Running rollout with at most 400 steps:  51%|▌| 203/400 [01:28<01:30,  2.18it/s,
# Running rollout with at most 400 steps:  51%|▌| 203/400 [01:28<01:30,  2.18it/s,
# Running rollout with at most 400 steps:  51%|▌| 204/400 [01:28<01:26,  2.27it/s,
# Running rollout with at most 400 steps:  51%|▌| 204/400 [01:29<01:26,  2.27it/s,
# Running rollout with at most 400 steps:  51%|▌| 205/400 [01:29<01:24,  2.31it/s,
# Running rollout with at most 400 steps:  51%|▌| 205/400 [01:29<01:24,  2.31it/s,
# Running rollout with at most 400 steps:  52%|▌| 206/400 [01:29<01:22,  2.34it/s,
# Running rollout with at most 400 steps:  52%|▌| 206/400 [01:30<01:22,  2.34it/s,
# Running rollout with at most 400 steps:  52%|▌| 207/400 [01:30<01:21,  2.36it/s,
# Running rollout with at most 400 steps:  52%|▌| 207/400 [01:30<01:21,  2.36it/s,
# Running rollout with at most 400 steps:  52%|▌| 208/400 [01:30<01:21,  2.37it/s,
# Running rollout with at most 400 steps:  52%|▌| 208/400 [01:31<01:21,  2.37it/s,
# Running rollout with at most 400 steps:  52%|▌| 209/400 [01:31<01:20,  2.36it/s,
# Running rollout with at most 400 steps:  52%|▌| 209/400 [01:31<01:20,  2.36it/s,
# Running rollout with at most 400 steps:  52%|▌| 210/400 [01:31<01:19,  2.38it/s,
# Running rollout with at most 400 steps:  52%|▌| 210/400 [01:31<01:19,  2.38it/s,
# Running rollout with at most 400 steps:  53%|▌| 211/400 [01:31<01:19,  2.39it/s,
# Running rollout with at most 400 steps:  53%|▌| 211/400 [01:32<01:19,  2.39it/s,
# Running rollout with at most 400 steps:  53%|▌| 212/400 [01:32<01:18,  2.38it/s,
# Running rollout with at most 400 steps:  53%|▌| 212/400 [01:32<01:18,  2.38it/s,
# Running rollout with at most 400 steps:  53%|▌| 213/400 [01:32<01:17,  2.40it/s,
# Running rollout with at most 400 steps:  53%|▌| 213/400 [01:33<01:17,  2.40it/s,
# Running rollout with at most 400 steps:  54%|▌| 214/400 [01:33<01:17,  2.39it/s,
# Running rollout with at most 400 steps:  54%|▌| 214/400 [01:33<01:17,  2.39it/s,
# Running rollout with at most 400 steps:  54%|▌| 215/400 [01:33<01:17,  2.38it/s,
# Running rollout with at most 400 steps:  54%|▌| 215/400 [01:33<01:17,  2.38it/s,
# Running rollout with at most 400 steps:  54%|▌| 216/400 [01:33<01:17,  2.37it/s,
# Running rollout with at most 400 steps:  54%|▌| 216/400 [01:34<01:17,  2.37it/s,
# Running rollout with at most 400 steps:  54%|▌| 217/400 [01:34<01:17,  2.37it/s,
# Running rollout with at most 400 steps:  54%|▌| 217/400 [01:34<01:17,  2.37it/s,
# Running rollout with at most 400 steps:  55%|▌| 218/400 [01:34<01:16,  2.39it/s,
# Running rollout with at most 400 steps:  55%|▌| 218/400 [01:35<01:16,  2.39it/s,
# Running rollout with at most 400 steps:  55%|▌| 219/400 [01:35<01:15,  2.39it/s,
# Running rollout with at most 400 steps:  55%|▌| 219/400 [01:35<01:15,  2.39it/s,
# Running rollout with at most 400 steps:  55%|▌| 220/400 [01:35<01:15,  2.39it/s,
# Running rollout with at most 400 steps:  55%|▌| 220/400 [01:36<01:15,  2.39it/s,
# Running rollout with at most 400 steps:  55%|▌| 221/400 [01:36<01:14,  2.39it/s,
# Running rollout with at most 400 steps:  55%|▌| 221/400 [01:36<01:14,  2.39it/s,
# Running rollout with at most 400 steps:  56%|▌| 222/400 [01:36<01:14,  2.40it/s,
# Running rollout with at most 400 steps:  56%|▌| 222/400 [01:36<01:14,  2.40it/s,
# Running rollout with at most 400 steps:  56%|▌| 223/400 [01:36<01:13,  2.39it/s,
# Running rollout with at most 400 steps:  56%|▌| 223/400 [01:37<01:13,  2.39it/s,
# Running rollout with at most 400 steps:  56%|▌| 224/400 [01:37<01:14,  2.36it/s,
# Running rollout with at most 400 steps:  56%|▌| 224/400 [01:37<01:14,  2.36it/s,
# Running rollout with at most 400 steps:  56%|▌| 225/400 [01:37<01:13,  2.38it/s,
# Running rollout with at most 400 steps:  56%|▌| 225/400 [01:38<01:13,  2.38it/s,
# Running rollout with at most 400 steps:  56%|▌| 226/400 [01:38<01:13,  2.37it/s,
# Running rollout with at most 400 steps:  56%|▌| 226/400 [01:38<01:13,  2.37it/s,
# Running rollout with at most 400 steps:  57%|▌| 227/400 [01:38<01:12,  2.38it/s,
# Running rollout with at most 400 steps:  57%|▌| 227/400 [01:39<01:12,  2.38it/s,
# Running rollout with at most 400 steps:  57%|▌| 228/400 [01:39<01:12,  2.36it/s,
# Running rollout with at most 400 steps:  57%|▌| 228/400 [01:39<01:12,  2.36it/s,
# Running rollout with at most 400 steps:  57%|▌| 229/400 [01:39<01:16,  2.25it/s,
# Running rollout with at most 400 steps:  57%|▌| 229/400 [01:40<01:16,  2.25it/s,
# Running rollout with at most 400 steps:  57%|▌| 230/400 [01:40<01:19,  2.13it/s,
# Running rollout with at most 400 steps:  57%|▌| 230/400 [01:40<01:19,  2.13it/s,
# Running rollout with at most 400 steps:  58%|▌| 231/400 [01:40<01:17,  2.17it/s,
# Running rollout with at most 400 steps:  58%|▌| 231/400 [01:41<01:17,  2.17it/s,
# Running rollout with at most 400 steps:  58%|▌| 232/400 [01:41<01:19,  2.10it/s,
# Running rollout with at most 400 steps:  58%|▌| 232/400 [01:41<01:19,  2.10it/s,
# Running rollout with at most 400 steps:  58%|▌| 233/400 [01:41<01:16,  2.19it/s,
# Running rollout with at most 400 steps:  58%|▌| 233/400 [01:41<01:16,  2.19it/s,
# Running rollout with at most 400 steps:  58%|▌| 234/400 [01:41<01:13,  2.26it/s,
# Running rollout with at most 400 steps:  58%|▌| 234/400 [01:42<01:13,  2.26it/s,
# Running rollout with at most 400 steps:  59%|▌| 235/400 [01:42<01:11,  2.31it/s,
# Running rollout with at most 400 steps:  59%|▌| 235/400 [01:42<01:11,  2.31it/s,
# Running rollout with at most 400 steps:  59%|▌| 236/400 [01:42<01:09,  2.35it/s,
# Running rollout with at most 400 steps:  59%|▌| 236/400 [01:43<01:09,  2.35it/s,
# Running rollout with at most 400 steps:  59%|▌| 237/400 [01:43<01:08,  2.38it/s,
# Running rollout with at most 400 steps:  59%|▌| 237/400 [01:43<01:08,  2.38it/s,
# Running rollout with at most 400 steps:  60%|▌| 238/400 [01:43<01:07,  2.40it/s,
# Running rollout with at most 400 steps:  60%|▌| 238/400 [01:43<01:07,  2.40it/s,
# Running rollout with at most 400 steps:  60%|▌| 239/400 [01:43<01:07,  2.40it/s,
# Running rollout with at most 400 steps:  60%|▌| 239/400 [01:44<01:07,  2.40it/s,
# Running rollout with at most 400 steps:  60%|▌| 240/400 [01:44<01:11,  2.23it/s,
# Running rollout with at most 400 steps:  60%|▌| 240/400 [01:44<01:11,  2.23it/s,
# Running rollout with at most 400 steps:  60%|▌| 241/400 [01:44<01:11,  2.23it/s,
# Running rollout with at most 400 steps:  60%|▌| 241/400 [01:45<01:11,  2.23it/s,
# Running rollout with at most 400 steps:  60%|▌| 242/400 [01:45<01:08,  2.29it/s,
# Running rollout with at most 400 steps:  60%|▌| 242/400 [01:45<01:08,  2.29it/s,
# Running rollout with at most 400 steps:  61%|▌| 243/400 [01:45<01:07,  2.33it/s,
# Running rollout with at most 400 steps:  61%|▌| 243/400 [01:46<01:07,  2.33it/s,
# Running rollout with at most 400 steps:  61%|▌| 244/400 [01:46<01:10,  2.21it/s,
# Running rollout with at most 400 steps:  61%|▌| 244/400 [01:46<01:10,  2.21it/s,
# Running rollout with at most 400 steps:  61%|▌| 245/400 [01:46<01:09,  2.22it/s,
# Running rollout with at most 400 steps:  61%|▌| 245/400 [01:47<01:09,  2.22it/s,
# Running rollout with at most 400 steps:  62%|▌| 246/400 [01:47<01:07,  2.28it/s,
# Running rollout with at most 400 steps:  62%|▌| 246/400 [01:47<01:07,  2.28it/s,
# Running rollout with at most 400 steps:  62%|▌| 247/400 [01:47<01:12,  2.12it/s,
# Running rollout with at most 400 steps:  62%|▌| 247/400 [01:47<01:12,  2.12it/s,
# Running rollout with at most 400 steps:  62%|▌| 248/400 [01:47<01:09,  2.20it/s,
# Running rollout with at most 400 steps:  62%|▌| 248/400 [01:48<01:09,  2.20it/s,
# Running rollout with at most 400 steps:  62%|▌| 249/400 [01:48<01:06,  2.26it/s,
# Running rollout with at most 400 steps:  62%|▌| 249/400 [01:48<01:06,  2.26it/s,
# Running rollout with at most 400 steps:  62%|▋| 250/400 [01:48<01:05,  2.31it/s,
# Running rollout with at most 400 steps:  62%|▋| 250/400 [01:49<01:05,  2.31it/s,
# Running rollout with at most 400 steps:  63%|▋| 251/400 [01:49<01:03,  2.35it/s,
# Running rollout with at most 400 steps:  63%|▋| 251/400 [01:49<01:03,  2.35it/s,
# Running rollout with at most 400 steps:  63%|▋| 252/400 [01:49<01:02,  2.37it/s,
# Running rollout with at most 400 steps:  63%|▋| 252/400 [01:50<01:02,  2.37it/s,
# Running rollout with at most 400 steps:  63%|▋| 253/400 [01:50<01:09,  2.13it/s,
# Running rollout with at most 400 steps:  63%|▋| 253/400 [01:50<01:09,  2.13it/s,
# Running rollout with at most 400 steps:  64%|▋| 254/400 [01:50<01:05,  2.21it/s,
# Running rollout with at most 400 steps:  64%|▋| 254/400 [01:51<01:05,  2.21it/s,
# Running rollout with at most 400 steps:  64%|▋| 255/400 [01:51<01:03,  2.27it/s,
# Running rollout with at most 400 steps:  64%|▋| 255/400 [01:51<01:03,  2.27it/s,
# Running rollout with at most 400 steps:  64%|▋| 256/400 [01:51<01:01,  2.33it/s,
# Running rollout with at most 400 steps:  64%|▋| 256/400 [01:51<01:01,  2.33it/s,
# Running rollout with at most 400 steps:  64%|▋| 257/400 [01:51<01:00,  2.36it/s,
# Running rollout with at most 400 steps:  64%|▋| 257/400 [01:52<01:00,  2.36it/s,
# Running rollout with at most 400 steps:  64%|▋| 258/400 [01:52<00:59,  2.38it/s,
# Running rollout with at most 400 steps:  64%|▋| 258/400 [01:52<00:59,  2.38it/s,
# Running rollout with at most 400 steps:  65%|▋| 259/400 [01:52<01:02,  2.25it/s,
# Running rollout with at most 400 steps:  65%|▋| 259/400 [01:53<01:02,  2.25it/s,
# Running rollout with at most 400 steps:  65%|▋| 260/400 [01:53<01:02,  2.25it/s,
# Running rollout with at most 400 steps:  65%|▋| 260/400 [01:53<01:02,  2.25it/s,
# Running rollout with at most 400 steps:  65%|▋| 261/400 [01:53<01:00,  2.29it/s,
# Running rollout with at most 400 steps:  65%|▋| 261/400 [01:54<01:00,  2.29it/s,
# Running rollout with at most 400 steps:  66%|▋| 262/400 [01:54<00:59,  2.31it/s,
# Running rollout with at most 400 steps:  66%|▋| 262/400 [01:54<00:59,  2.31it/s,
# Running rollout with at most 400 steps:  66%|▋| 263/400 [01:54<00:59,  2.32it/s,
# Running rollout with at most 400 steps:  66%|▋| 263/400 [01:54<00:59,  2.32it/s,
# Running rollout with at most 400 steps:  66%|▋| 264/400 [01:54<00:58,  2.32it/s,
# Running rollout with at most 400 steps:  66%|▋| 264/400 [01:55<00:58,  2.32it/s,
# Running rollout with at most 400 steps:  66%|▋| 265/400 [01:55<00:58,  2.30it/s,
# ...
# Running rollout with at most 400 steps:  76%|▊| 303/400 [02:12<00:43,  2.22it/s,
# Running rollout with at most 400 steps:  76%|▊| 304/400 [02:12<00:41,  2.29it/s,
# Running rollout with at most 400 steps:  76%|▊| 304/400 [02:12<00:41,  2.29it/s,
# Running rollout with at most 400 steps:  76%|▊| 305/400 [02:12<00:42,  2.23it/s,
# Running rollout with at most 400 steps:  76%|▊| 305/400 [02:13<00:42,  2.23it/s,
# Running rollout with at most 400 steps:  76%|▊| 306/400 [02:13<00:43,  2.17it/s,
# Running rollout with at most 400 steps:  76%|▊| 306/400 [02:13<00:43,  2.17it/s,
# Running rollout with at most 400 steps:  77%|▊| 307/400 [02:13<00:42,  2.20it/s,
# Running rollout with at most 400 steps:  77%|▊| 307/400 [02:14<00:42,  2.20it/s,
# Running rollout with at most 400 steps:  77%|▊| 308/400 [02:14<00:40,  2.25it/s,
# Running rollout with at most 400 steps:  77%|▊| 308/400 [02:14<00:40,  2.25it/s,
# Running rollout with at most 400 steps:  77%|▊| 309/400 [02:14<00:39,  2.30it/s,
# Running rollout with at most 400 steps:  77%|▊| 309/400 [02:15<00:39,  2.30it/s,
# Running rollout with at most 400 steps:  78%|▊| 310/400 [02:15<00:41,  2.18it/s,
# Running rollout with at most 400 steps:  78%|▊| 310/400 [02:15<00:41,  2.18it/s,
# Running rollout with at most 400 steps:  78%|▊| 311/400 [02:15<00:40,  2.21it/s,
# Running rollout with at most 400 steps:  78%|▊| 311/400 [02:16<00:40,  2.21it/s,
# Running rollout with at most 400 steps:  78%|▊| 312/400 [02:16<00:39,  2.26it/s,
# Running rollout with at most 400 steps:  78%|▊| 312/400 [02:16<00:39,  2.26it/s,
# Running rollout with at most 400 steps:  78%|▊| 313/400 [02:16<00:38,  2.28it/s,
# Running rollout with at most 400 steps:  78%|▊| 313/400 [02:16<00:38,  2.28it/s,
# Running rollout with at most 400 steps:  78%|▊| 314/400 [02:16<00:37,  2.30it/s,
# Running rollout with at most 400 steps:  78%|▊| 314/400 [02:17<00:37,  2.30it/s,
# Running rollout with at most 400 steps:  79%|▊| 315/400 [02:17<00:39,  2.15it/s,
# Running rollout with at most 400 steps:  79%|▊| 315/400 [02:17<00:39,  2.15it/s,
# Running rollout with at most 400 steps:  79%|▊| 316/400 [02:17<00:37,  2.23it/s,
# Running rollout with at most 400 steps:  79%|▊| 316/400 [02:18<00:37,  2.23it/s,
# Running rollout with at most 400 steps:  79%|▊| 317/400 [02:18<00:36,  2.25it/s,
# Running rollout with at most 400 steps:  79%|▊| 317/400 [02:18<00:36,  2.25it/s,
# Running rollout with at most 400 steps:  80%|▊| 318/400 [02:18<00:35,  2.29it/s,
# Running rollout with at most 400 steps:  80%|▊| 318/400 [02:19<00:35,  2.29it/s,
# Running rollout with at most 400 steps:  80%|▊| 319/400 [02:19<00:34,  2.33it/s,
# Running rollout with at most 400 steps:  80%|▊| 319/400 [02:19<00:34,  2.33it/s,
# Running rollout with at most 400 steps:  80%|▊| 320/400 [02:19<00:33,  2.36it/s,
# Running rollout with at most 400 steps:  80%|▊| 320/400 [02:20<00:33,  2.36it/s,
# Running rollout with at most 400 steps:  80%|▊| 321/400 [02:20<00:34,  2.30it/s,
# Running rollout with at most 400 steps:  80%|▊| 321/400 [02:20<00:34,  2.30it/s,
# Running rollout with at most 400 steps:  80%|▊| 322/400 [02:20<00:34,  2.25it/s,
# Running rollout with at most 400 steps:  80%|▊| 322/400 [02:20<00:34,  2.25it/s,
# Running rollout with at most 400 steps:  81%|▊| 323/400 [02:20<00:34,  2.25it/s,
# Running rollout with at most 400 steps:  81%|▊| 323/400 [02:21<00:34,  2.25it/s,
# Running rollout with at most 400 steps:  81%|▊| 324/400 [02:21<00:33,  2.28it/s,
# Running rollout with at most 400 steps:  81%|▊| 324/400 [02:21<00:33,  2.28it/s,
# Running rollout with at most 400 steps:  81%|▊| 325/400 [02:21<00:32,  2.32it/s,
# Running rollout with at most 400 steps:  81%|▊| 325/400 [02:22<00:32,  2.32it/s,
# Running rollout with at most 400 steps:  82%|▊| 326/400 [02:22<00:31,  2.33it/s,
# Running rollout with at most 400 steps:  82%|▊| 326/400 [02:22<00:31,  2.33it/s,
# Running rollout with at most 400 steps:  82%|▊| 327/400 [02:22<00:31,  2.28it/s,
# Running rollout with at most 400 steps:  82%|▊| 327/400 [02:23<00:31,  2.28it/s,
# Running rollout with at most 400 steps:  82%|▊| 328/400 [02:23<00:35,  2.05it/s,
# Running rollout with at most 400 steps:  82%|▊| 328/400 [02:23<00:35,  2.05it/s,
# Running rollout with at most 400 steps:  82%|▊| 329/400 [02:23<00:33,  2.13it/s,
# Running rollout with at most 400 steps:  82%|▊| 329/400 [02:24<00:33,  2.13it/s,
# Running rollout with at most 400 steps:  82%|▊| 330/400 [02:24<00:31,  2.19it/s,
# Running rollout with at most 400 steps:  82%|▊| 330/400 [02:24<00:31,  2.19it/s,
# Running rollout with at most 400 steps:  83%|▊| 331/400 [02:24<00:30,  2.24it/s,
# Running rollout with at most 400 steps:  83%|▊| 331/400 [02:24<00:30,  2.24it/s,
# Running rollout with at most 400 steps:  83%|▊| 332/400 [02:24<00:30,  2.26it/s,
# Running rollout with at most 400 steps:  83%|▊| 332/400 [02:25<00:30,  2.26it/s,
# Running rollout with at most 400 steps:  83%|▊| 333/400 [02:25<00:33,  2.03it/s,
# Running rollout with at most 400 steps:  83%|▊| 333/400 [02:25<00:33,  2.03it/s,
# Running rollout with at most 400 steps:  84%|▊| 334/400 [02:25<00:31,  2.12it/s,
# Running rollout with at most 400 steps:  84%|▊| 334/400 [02:26<00:31,  2.12it/s,
# Running rollout with at most 400 steps:  84%|▊| 335/400 [02:26<00:31,  2.05it/s,
# Running rollout with at most 400 steps:  84%|▊| 335/400 [02:26<00:31,  2.05it/s,
# Running rollout with at most 400 steps:  84%|▊| 336/400 [02:26<00:29,  2.14it/s,
# Running rollout with at most 400 steps:  84%|▊| 336/400 [02:27<00:29,  2.14it/s,
# Running rollout with at most 400 steps:  84%|▊| 337/400 [02:27<00:28,  2.22it/s,
# Running rollout with at most 400 steps:  84%|▊| 337/400 [02:27<00:28,  2.22it/s,
# Running rollout with at most 400 steps:  84%|▊| 338/400 [02:27<00:28,  2.19it/s,
# Running rollout with at most 400 steps:  84%|▊| 338/400 [02:28<00:28,  2.19it/s,
# Running rollout with at most 400 steps:  85%|▊| 339/400 [02:28<00:27,  2.18it/s,
# Running rollout with at most 400 steps:  85%|▊| 339/400 [02:28<00:27,  2.18it/s,
# Running rollout with at most 400 steps:  85%|▊| 340/400 [02:28<00:30,  1.96it/s,
# Running rollout with at most 400 steps:  85%|▊| 340/400 [02:29<00:30,  1.96it/s,
# Running rollout with at most 400 steps:  85%|▊| 341/400 [02:29<00:28,  2.04it/s,
# Running rollout with at most 400 steps:  85%|▊| 341/400 [02:29<00:28,  2.04it/s,
# Running rollout with at most 400 steps:  86%|▊| 342/400 [02:29<00:27,  2.11it/s,
# Running rollout with at most 400 steps:  86%|▊| 342/400 [02:30<00:27,  2.11it/s,
# Running rollout with at most 400 steps:  86%|▊| 343/400 [02:30<00:26,  2.18it/s,
# Running rollout with at most 400 steps:  86%|▊| 343/400 [02:30<00:26,  2.18it/s,
# Running rollout with at most 400 steps:  86%|▊| 344/400 [02:30<00:25,  2.24it/s,
# Running rollout with at most 400 steps:  86%|▊| 344/400 [02:31<00:25,  2.24it/s,
# Running rollout with at most 400 steps:  86%|▊| 345/400 [02:31<00:25,  2.18it/s,
# Running rollout with at most 400 steps:  86%|▊| 345/400 [02:31<00:25,  2.18it/s,
# Running rollout with at most 400 steps:  86%|▊| 346/400 [02:31<00:26,  2.05it/s,
# Running rollout with at most 400 steps:  86%|▊| 346/400 [02:32<00:26,  2.05it/s,
# Running rollout with at most 400 steps:  87%|▊| 347/400 [02:32<00:24,  2.14it/s,
# Running rollout with at most 400 steps:  87%|▊| 347/400 [02:32<00:24,  2.14it/s,
# Running rollout with at most 400 steps:  87%|▊| 348/400 [02:32<00:23,  2.19it/s,
# Running rollout with at most 400 steps:  87%|▊| 348/400 [02:32<00:23,  2.19it/s,
# Running rollout with at most 400 steps:  87%|▊| 349/400 [02:32<00:22,  2.24it/s,
# Running rollout with at most 400 steps:  87%|▊| 349/400 [02:33<00:22,  2.24it/s,
# Running rollout with at most 400 steps:  88%|▉| 350/400 [02:33<00:21,  2.29it/s,
# Running rollout with at most 400 steps:  88%|▉| 350/400 [02:33<00:21,  2.29it/s,
# Running rollout with at most 400 steps:  88%|▉| 351/400 [02:33<00:21,  2.31it/s,
# Running rollout with at most 400 steps:  88%|▉| 351/400 [02:34<00:21,  2.31it/s,
# Running rollout with at most 400 steps:  88%|▉| 352/400 [02:34<00:20,  2.34it/s,
# Running rollout with at most 400 steps:  88%|▉| 352/400 [02:34<00:20,  2.34it/s,
# Running rollout with at most 400 steps:  88%|▉| 353/400 [02:34<00:19,  2.36it/s,
# Running rollout with at most 400 steps:  88%|▉| 353/400 [02:35<00:19,  2.36it/s,
# Running rollout with at most 400 steps:  88%|▉| 354/400 [02:35<00:19,  2.37it/s,
# Running rollout with at most 400 steps:  88%|▉| 354/400 [02:35<00:19,  2.37it/s,
# Running rollout with at most 400 steps:  89%|▉| 355/400 [02:35<00:18,  2.39it/s,
# Running rollout with at most 400 steps:  89%|▉| 355/400 [02:35<00:18,  2.39it/s,
# Running rollout with at most 400 steps:  89%|▉| 356/400 [02:35<00:19,  2.26it/s,
# Running rollout with at most 400 steps:  89%|▉| 356/400 [02:36<00:19,  2.26it/s,
# Running rollout with at most 400 steps:  89%|▉| 357/400 [02:36<00:18,  2.27it/s,
# Running rollout with at most 400 steps:  89%|▉| 357/400 [02:36<00:18,  2.27it/s,
# Running rollout with at most 400 steps:  90%|▉| 358/400 [02:36<00:18,  2.31it/s,
# Running rollout with at most 400 steps:  90%|▉| 358/400 [02:37<00:18,  2.31it/s,
# Running rollout with at most 400 steps:  90%|▉| 359/400 [02:37<00:17,  2.33it/s,
# Running rollout with at most 400 steps:  90%|▉| 359/400 [02:37<00:17,  2.33it/s,
# Running rollout with at most 400 steps:  90%|▉| 360/400 [02:37<00:16,  2.36it/s,
# Running rollout with at most 400 steps:  90%|▉| 360/400 [02:38<00:16,  2.36it/s,
# Running rollout with at most 400 steps:  90%|▉| 361/400 [02:38<00:16,  2.36it/s,
# Running rollout with at most 400 steps:  90%|▉| 361/400 [02:38<00:16,  2.36it/s,
# Running rollout with at most 400 steps:  90%|▉| 362/400 [02:38<00:16,  2.37it/s,
# Running rollout with at most 400 steps:  90%|▉| 362/400 [02:38<00:16,  2.37it/s,
# Running rollout with at most 400 steps:  91%|▉| 363/400 [02:38<00:15,  2.38it/s,
# Running rollout with at most 400 steps:  91%|▉| 363/400 [02:39<00:15,  2.38it/s,
# Running rollout with at most 400 steps:  91%|▉| 364/400 [02:39<00:15,  2.36it/s,
# Running rollout with at most 400 steps:  91%|▉| 364/400 [02:39<00:15,  2.36it/s,
# Running rollout with at most 400 steps:  91%|▉| 365/400 [02:39<00:14,  2.37it/s,
# Running rollout with at most 400 steps:  91%|▉| 365/400 [02:40<00:14,  2.37it/s,
# Running rollout with at most 400 steps:  92%|▉| 366/400 [02:40<00:14,  2.37it/s,
# Running rollout with at most 400 steps:  92%|▉| 366/400 [02:40<00:14,  2.37it/s,
# Running rollout with at most 400 steps:  92%|▉| 367/400 [02:40<00:13,  2.38it/s,
# Running rollout with at most 400 steps:  92%|▉| 367/400 [02:40<00:13,  2.38it/s,
# Running rollout with at most 400 steps:  92%|▉| 368/400 [02:40<00:13,  2.38it/s,
# Running rollout with at most 400 steps:  92%|▉| 368/400 [02:41<00:13,  2.38it/s,
# Running rollout with at most 400 steps:  92%|▉| 369/400 [02:41<00:13,  2.38it/s,
# Running rollout with at most 400 steps:  92%|▉| 369/400 [02:41<00:13,  2.38it/s,
# Running rollout with at most 400 steps:  92%|▉| 370/400 [02:41<00:12,  2.32it/s,
# Running rollout with at most 400 steps:  92%|▉| 370/400 [02:42<00:12,  2.32it/s,
# Running rollout with at most 400 steps:  93%|▉| 371/400 [02:42<00:13,  2.16it/s,
# Running rollout with at most 400 steps:  93%|▉| 371/400 [02:42<00:13,  2.16it/s,
# Running rollout with at most 400 steps:  93%|▉| 372/400 [02:42<00:12,  2.22it/s,
# Running rollout with at most 400 steps:  93%|▉| 372/400 [02:43<00:12,  2.22it/s,
# Running rollout with at most 400 steps:  93%|▉| 373/400 [02:43<00:11,  2.27it/s,
# Running rollout with at most 400 steps:  93%|▉| 373/400 [02:43<00:11,  2.27it/s,
# Running rollout with at most 400 steps:  94%|▉| 374/400 [02:43<00:11,  2.30it/s,
# Running rollout with at most 400 steps:  94%|▉| 374/400 [02:44<00:11,  2.30it/s,
# Running rollout with at most 400 steps:  94%|▉| 375/400 [02:44<00:10,  2.33it/s,
# Running rollout with at most 400 steps:  94%|▉| 375/400 [02:44<00:10,  2.33it/s,
# Running rollout with at most 400 steps:  94%|▉| 376/400 [02:44<00:10,  2.35it/s,
# Running rollout with at most 400 steps:  94%|▉| 376/400 [02:44<00:10,  2.35it/s,
# Running rollout with at most 400 steps:  94%|▉| 377/400 [02:44<00:09,  2.36it/s,
# Running rollout with at most 400 steps:  94%|▉| 377/400 [02:45<00:09,  2.36it/s,
# Running rollout with at most 400 steps:  94%|▉| 378/400 [02:45<00:09,  2.36it/s,
# Running rollout with at most 400 steps:  94%|▉| 378/400 [02:45<00:09,  2.36it/s,
# Running rollout with at most 400 steps:  95%|▉| 379/400 [02:45<00:08,  2.35it/s,
# Running rollout with at most 400 steps:  95%|▉| 379/400 [02:46<00:08,  2.35it/s,
# Running rollout with at most 400 steps:  95%|▉| 380/400 [02:46<00:08,  2.36it/s,
# Running rollout with at most 400 steps:  95%|▉| 380/400 [02:46<00:08,  2.36it/s,
# Running rollout with at most 400 steps:  95%|▉| 381/400 [02:46<00:08,  2.37it/s,
# Running rollout with at most 400 steps:  95%|▉| 381/400 [02:47<00:08,  2.37it/s,
# Running rollout with at most 400 steps:  96%|▉| 382/400 [02:47<00:08,  2.19it/s,
# Running rollout with at most 400 steps:  96%|▉| 382/400 [02:47<00:08,  2.19it/s,
# Running rollout with at most 400 steps:  96%|▉| 383/400 [02:47<00:07,  2.24it/s,
# Running rollout with at most 400 steps:  96%|▉| 383/400 [02:47<00:07,  2.24it/s,
# Running rollout with at most 400 steps:  96%|▉| 384/400 [02:47<00:07,  2.28it/s,
# Running rollout with at most 400 steps:  96%|▉| 384/400 [02:48<00:07,  2.28it/s,
# Running rollout with at most 400 steps:  96%|▉| 385/400 [02:48<00:06,  2.33it/s,
# Running rollout with at most 400 steps:  96%|▉| 385/400 [02:48<00:06,  2.33it/s,
# Running rollout with at most 400 steps:  96%|▉| 386/400 [02:48<00:05,  2.35it/s,
# Running rollout with at most 400 steps:  96%|▉| 386/400 [02:49<00:05,  2.35it/s,
# Running rollout with at most 400 steps:  97%|▉| 387/400 [02:49<00:05,  2.36it/s,
# Running rollout with at most 400 steps:  97%|▉| 387/400 [02:49<00:05,  2.36it/s,
# Running rollout with at most 400 steps:  97%|▉| 388/400 [02:49<00:05,  2.36it/s,
# Running rollout with at most 400 steps:  97%|▉| 388/400 [02:50<00:05,  2.36it/s,
# Running rollout with at most 400 steps:  97%|▉| 389/400 [02:50<00:04,  2.36it/s,
# Running rollout with at most 400 steps:  97%|▉| 389/400 [02:50<00:04,  2.36it/s,
# Running rollout with at most 400 steps:  98%|▉| 390/400 [02:50<00:04,  2.23it/s,
# Running rollout with at most 400 steps:  98%|▉| 390/400 [02:51<00:04,  2.23it/s,
# Running rollout with at most 400 steps:  98%|▉| 391/400 [02:51<00:04,  2.24it/s,
# Running rollout with at most 400 steps:  98%|▉| 391/400 [02:51<00:04,  2.24it/s,
# Running rollout with at most 400 steps:  98%|▉| 392/400 [02:51<00:03,  2.30it/s,
# Running rollout with at most 400 steps:  98%|▉| 392/400 [02:51<00:03,  2.30it/s,
# Running rollout with at most 400 steps:  98%|▉| 393/400 [02:51<00:02,  2.34it/s,
# Running rollout with at most 400 steps:  98%|▉| 393/400 [02:52<00:02,  2.34it/s,
# Running rollout with at most 400 steps:  98%|▉| 394/400 [02:52<00:02,  2.37it/s,
# Running rollout with at most 400 steps:  98%|▉| 394/400 [02:52<00:02,  2.37it/s,
# Running rollout with at most 400 steps:  99%|▉| 395/400 [02:52<00:02,  2.18it/s,
# Running rollout with at most 400 steps:  99%|▉| 395/400 [02:53<00:02,  2.18it/s,
# Running rollout with at most 400 steps:  99%|▉| 396/400 [02:53<00:01,  2.22it/s,
# Running rollout with at most 400 steps:  99%|▉| 396/400 [02:53<00:01,  2.22it/s,
# Running rollout with at most 400 steps:  99%|▉| 397/400 [02:53<00:01,  2.26it/s,
# Running rollout with at most 400 steps:  99%|▉| 397/400 [02:54<00:01,  2.26it/s,
# Running rollout with at most 400 steps: 100%|▉| 398/400 [02:54<00:00,  2.31it/s,
# Running rollout with at most 400 steps: 100%|▉| 398/400 [02:54<00:00,  2.31it/s,
# Running rollout with at most 400 steps: 100%|▉| 399/400 [02:54<00:00,  2.17it/s,
# Running rollout with at most 400 steps: 100%|▉| 399/400 [02:55<00:00,  2.17it/s,
# Running rollout with at most 400 steps: 100%|█| 400/400 [02:55<00:00,  1.91it/s,
# Stepping through eval batches: 100%|█| 1/1 [03:25<00:00, 205.60s/it, running_suc
# {'avg_sum_reward': 167.04, 'avg_max_reward': 2.7, 'pc_success': 52.0, 'eval_s': 210.17465543746948, 'eval_ep_s': 4.203493118286133}
# INFO 2025-09-11 11:08:52 pts/eval.py:501 End of eval

# %%
eval_video_output_dir = os.path.join(eval_output, "videos")
all_entries = os.listdir(eval_video_output_dir)
eval_video_list= []
for vf in sorted(all_entries):
    vfp = os.path.join(eval_video_output_dir, vf)
    v_title = vf[:-4]
    eval_video_list.append((vfp, v_title))

print(eval_video_list)
display_video_grid(eval_video_list, cols=5)
# Out:
# [('./output/post_eval/act_aloha_transfer/videos/eval_episode_0.mp4', 'eval_episode_0'), ('./output/post_eval/act_aloha_transfer/videos/eval_episode_1.mp4', 'eval_episode_1'), ('./output/post_eval/act_aloha_transfer/videos/eval_episode_2.mp4', 'eval_episode_2'), ('./output/post_eval/act_aloha_transfer/videos/eval_episode_3.mp4', 'eval_episode_3'), ('./output/post_eval/act_aloha_transfer/videos/eval_episode_4.mp4', 'eval_episode_4'), ('./output/post_eval/act_aloha_transfer/videos/eval_episode_5.mp4', 'eval_episode_5'), ('./output/post_eval/act_aloha_transfer/videos/eval_episode_6.mp4', 'eval_episode_6'), ('./output/post_eval/act_aloha_transfer/videos/eval_episode_7.mp4', 'eval_episode_7'), ('./output/post_eval/act_aloha_transfer/videos/eval_episode_8.mp4', 'eval_episode_8'), ('./output/post_eval/act_aloha_transfer/videos/eval_episode_9.mp4', 'eval_episode_9')]
#     <style>
#     .video-grid {
#       display: grid;
#       grid-template-columns: repeat(5, 1fr);
#       gap: 20px;
#       margin-top: 20px;
#     }
#     .video-item {
#       text-align: center;
#     }
#     .video-item video {
#       width: 50%;
#       border-radius: 10px;
#       box-shadow: 0 4px 10px rgba(0,0,0,0.2);
#     }
#     .video-title {
#       margin-top: 8px;
#       font-weight: bold;
#       font-family: sans-serif;
#     }
#     </style>
#     <div class="video-grid">
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/post_eval/act_aloha_transfer/videos/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">eval_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/post_eval/act_aloha_transfer/videos/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">eval_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/post_eval/act_aloha_transfer/videos/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">eval_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/post_eval/act_aloha_transfer/videos/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">eval_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/post_eval/act_aloha_transfer/videos/eval_episode_4.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">eval_episode_4</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/post_eval/act_aloha_transfer/videos/eval_episode_5.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">eval_episode_5</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/post_eval/act_aloha_transfer/videos/eval_episode_6.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">eval_episode_6</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/post_eval/act_aloha_transfer/videos/eval_episode_7.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">eval_episode_7</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/post_eval/act_aloha_transfer/videos/eval_episode_8.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">eval_episode_8</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/post_eval/act_aloha_transfer/videos/eval_episode_9.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">eval_episode_9</div>
#         </div>
#         </div>
