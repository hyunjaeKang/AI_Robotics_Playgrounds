# %% [markdown]
# # TD_MPC Policy with Lerobot
#
# ---
#
# - Conda env : [lerobot](../README.md#setup-a-conda-environment)
#
# ----
#
# - Ref:
#     - https://huggingface.co/lerobot/vqbet_pusht

# %% [markdown]
# ## Device Setup

# %%
import torch

if torch.backends.mps.is_available():
    device = "mps"
elif torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

print(f"Available device : {device}")
# Out:
# Available device : cuda

# %% [markdown]
# ##  Train the diffusion policy for pushT environment

# %%
# !lerobot-train --output_dir=./temp/outputs/train/tdmpc_pusht \
    --policy.type=tdmpc \
    --dataset.repo_id=lerobot/pusht \
    --seed=100000 \
    --env.type=pusht \
    --batch_size=64 \
    --steps=200000 \
    --eval_freq=25000 \
    --save_freq=25000 \
    --policy.device=$device \
    --policy.push_to_hub=false \
    --wandb.enable=false
# Out:
# INFO 2026-01-11 14:05:14 ot_train.py:163 {'batch_size': 64,
#  'checkpoint_path': None,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'affine': {'kwargs': {'degrees': [-5.0,
#                                                                             5.0],
#                                                                 'translate': [0.05,
#                                                                               0.05]},
#                                                      'type': 'RandomAffine',
#                                                      'weight': 1.0},
#                                           'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'lerobot/pusht',
#              'revision': None,
#              'root': None,
#              'streaming': False,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': {'disable_env_checker': True,
#          'episode_length': 300,
#          'features': {'action': {'shape': [2],
#                                  'type': <FeatureType.ACTION: 'ACTION'>},
#                       'agent_pos': {'shape': [2],
#                                     'type': <FeatureType.STATE: 'STATE'>},
#                       'pixels': {'shape': [384, 384, 3],
#                                  'type': <FeatureType.VISUAL: 'VISUAL'>}},
#          'features_map': {'action': 'action',
#                           'agent_pos': 'observation.state',
#                           'environment_state': 'observation.environment_state',
#                           'pixels': 'observation.image'},
#          'fps': 10,
#          'max_parallel_tasks': 1,
#          'obs_type': 'pixels_agent_pos',
#          'observation_height': 384,
#          'observation_width': 384,
#          'render_mode': 'rgb_array',
#          'task': 'PushT-v0',
#          'type': 'pusht',
#          'visualization_height': 384,
#          'visualization_width': 384},
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 25000,
#  'job_name': 'pusht_tdmpc',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 0.0003,
#                'type': 'adam',
#                'weight_decay': 0.0},
#  'output_dir': 'temp/outputs/train/tdmpc_pusht',
#  'policy': {'advantage_scaling': 3.0,
#             'cem_iterations': 6,
#             'consistency_coeff': 20.0,
#             'device': 'cuda',
#             'discount': 0.9,
#             'elite_weighting_temperature': 0.5,
#             'expectile_weight': 0.9,
#             'gaussian_mean_momentum': 0.1,
#             'horizon': 5,
#             'image_encoder_hidden_dim': 32,
#             'input_features': {},
#             'latent_dim': 50,
#             'license': None,
#             'max_random_shift_ratio': 0.0476,
#             'max_std': 2.0,
#             'min_std': 0.05,
#             'mlp_dim': 512,
#             'n_action_repeats': 2,
#             'n_action_steps': 1,
#             'n_elites': 50,
#             'n_gaussian_samples': 512,
#             'n_obs_steps': 1,
#             'n_pi_samples': 51,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MIN_MAX: 'MIN_MAX'>,
#                                       'ENV': <NormalizationMode.IDENTITY: 'IDENTITY'>,
#                                       'STATE': <NormalizationMode.IDENTITY: 'IDENTITY'>,
#                                       'VISUAL': <NormalizationMode.IDENTITY: 'IDENTITY'>},
#             'optimizer_lr': 0.0003,
#             'output_features': {},
#             'pi_coeff': 0.5,
#             'pretrained_path': None,
#             'private': None,
#             'push_to_hub': False,
#             'q_ensemble_size': 5,
#             'repo_id': None,
#             'reward_coeff': 0.5,
#             'state_encoder_hidden_dim': 256,
#             'tags': None,
#             'target_model_momentum': 0.995,
#             'temporal_decay_coeff': 0.5,
#             'type': 'tdmpc',
#             'uncertainty_regularizer_coeff': 1.0,
#             'use_amp': False,
#             'use_mpc': True,
#             'value_coeff': 0.1},
#  'rename_map': {},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 25000,
#  'scheduler': None,
#  'seed': 100000,
#  'steps': 200000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': False,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2026-01-11 14:05:14 ot_train.py:171 Logs will be saved locally.
# INFO 2026-01-11 14:05:14 ot_train.py:183 Creating dataset
# INFO 2026-01-11 14:05:14 ot_train.py:198 Creating env
# gym id 'gym_pusht/PushT-v0' not found, attempting to import 'gym_pusht'...
# /home/hyunjae/.local/lib/python3.10/site-packages/pygame/pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# INFO 2026-01-11 14:05:14 ot_train.py:202 Creating policy
# INFO 2026-01-11 14:05:14 ot_train.py:247 Creating optimizer and scheduler
# INFO 2026-01-11 14:05:14 ot_train.py:259 Output dir: temp/outputs/train/tdmpc_pusht
# INFO 2026-01-11 14:05:14 ot_train.py:261 cfg.env.task='PushT-v0'
# INFO 2026-01-11 14:05:14 ot_train.py:262 Creating environment processors
# INFO 2026-01-11 14:05:14 ot_train.py:264 cfg.steps=200000 (200K)
# INFO 2026-01-11 14:05:14 ot_train.py:265 dataset.num_frames=25650 (26K)
# INFO 2026-01-11 14:05:14 ot_train.py:266 dataset.num_episodes=206
# INFO 2026-01-11 14:05:14 ot_train.py:269 Effective batch size: 64 x 1 = 64
# INFO 2026-01-11 14:05:14 ot_train.py:270 num_learnable_params=2737067 (3M)
# INFO 2026-01-11 14:05:14 ot_train.py:271 num_total_params=5474134 (5M)
# INFO 2026-01-11 14:05:14 ot_train.py:327 Start offline training on a fixed dataset
# INFO 2026-01-11 14:05:32 ot_train.py:354 step:200 smpl:13K ep:103 epch:0.50 loss:0.498 grdn:2.195 lr:3.0e-04 updt_s:0.034 data_s:0.052
# INFO 2026-01-11 14:05:48 ot_train.py:354 step:400 smpl:26K ep:206 epch:1.00 loss:0.177 grdn:2.532 lr:3.0e-04 updt_s:0.030 data_s:0.051
# INFO 2026-01-11 14:06:06 ot_train.py:354 step:600 smpl:38K ep:308 epch:1.50 loss:0.129 grdn:2.768 lr:3.0e-04 updt_s:0.031 data_s:0.056
# INFO 2026-01-11 14:06:22 ot_train.py:354 step:800 smpl:51K ep:411 epch:2.00 loss:0.204 grdn:4.587 lr:3.0e-04 updt_s:0.030 data_s:0.052
# INFO 2026-01-11 14:06:40 ot_train.py:354 step:1K smpl:64K ep:514 epch:2.50 loss:0.242 grdn:6.024 lr:3.0e-04 updt_s:0.030 data_s:0.058
# INFO 2026-01-11 14:06:56 ot_train.py:354 step:1K smpl:77K ep:617 epch:2.99 loss:0.148 grdn:3.133 lr:3.0e-04 updt_s:0.030 data_s:0.052
# INFO 2026-01-11 14:07:14 ot_train.py:354 step:1K smpl:90K ep:720 epch:3.49 loss:0.213 grdn:7.386 lr:3.0e-04 updt_s:0.030 data_s:0.059
# INFO 2026-01-11 14:07:30 ot_train.py:354 step:2K smpl:102K ep:822 epch:3.99 loss:0.214 grdn:8.381 lr:3.0e-04 updt_s:0.031 data_s:0.052
# INFO 2026-01-11 14:07:47 ot_train.py:354 step:2K smpl:115K ep:925 epch:4.49 loss:0.161 grdn:5.202 lr:3.0e-04 updt_s:0.029 data_s:0.056
# INFO 2026-01-11 14:08:03 ot_train.py:354 step:2K smpl:128K ep:1K epch:4.99 loss:0.170 grdn:6.138 lr:3.0e-04 updt_s:0.028 data_s:0.050
# INFO 2026-01-11 14:08:20 ot_train.py:354 step:2K smpl:141K ep:1K epch:5.49 loss:0.242 grdn:8.419 lr:3.0e-04 updt_s:0.029 data_s:0.056
# INFO 2026-01-11 14:08:37 ot_train.py:354 step:2K smpl:154K ep:1K epch:5.99 loss:0.173 grdn:5.895 lr:3.0e-04 updt_s:0.028 data_s:0.054
# INFO 2026-01-11 14:08:54 ot_train.py:354 step:3K smpl:166K ep:1K epch:6.49 loss:0.168 grdn:5.282 lr:3.0e-04 updt_s:0.032 data_s:0.053
# INFO 2026-01-11 14:09:10 ot_train.py:354 step:3K smpl:179K ep:1K epch:6.99 loss:0.193 grdn:7.393 lr:3.0e-04 updt_s:0.028 data_s:0.052
# INFO 2026-01-11 14:09:26 ot_train.py:354 step:3K smpl:192K ep:2K epch:7.49 loss:0.207 grdn:7.691 lr:3.0e-04 updt_s:0.031 data_s:0.053
# INFO 2026-01-11 14:09:42 ot_train.py:354 step:3K smpl:205K ep:2K epch:7.98 loss:0.198 grdn:6.202 lr:3.0e-04 updt_s:0.029 data_s:0.049
# INFO 2026-01-11 14:09:59 ot_train.py:354 step:3K smpl:218K ep:2K epch:8.48 loss:0.784 grdn:29.217 lr:3.0e-04 updt_s:0.030 data_s:0.055
# INFO 2026-01-11 14:10:15 ot_train.py:354 step:4K smpl:230K ep:2K epch:8.98 loss:0.987 grdn:19.196 lr:3.0e-04 updt_s:0.029 data_s:0.052
# INFO 2026-01-11 14:10:33 ot_train.py:354 step:4K smpl:243K ep:2K epch:9.48 loss:0.799 grdn:22.994 lr:3.0e-04 updt_s:0.030 data_s:0.057
# INFO 2026-01-11 14:10:50 ot_train.py:354 step:4K smpl:256K ep:2K epch:9.98 loss:0.684 grdn:16.506 lr:3.0e-04 updt_s:0.029 data_s:0.055
# INFO 2026-01-11 14:11:08 ot_train.py:354 step:4K smpl:269K ep:2K epch:10.48 loss:0.304 grdn:11.811 lr:3.0e-04 updt_s:0.029 data_s:0.060
# INFO 2026-01-11 14:11:24 ot_train.py:354 step:4K smpl:282K ep:2K epch:10.98 loss:0.384 grdn:15.826 lr:3.0e-04 updt_s:0.029 data_s:0.054
# INFO 2026-01-11 14:30:18 ot_train.py:354 step:18K smpl:1M ep:9K epch:44.91 loss:0.173 grdn:3.376 lr:3.0e-04 updt_s:0.028 data_s:0.053
# INFO 2026-01-11 14:30:36 ot_train.py:354 step:18K smpl:1M ep:9K epch:45.41 loss:0.169 grdn:3.285 lr:3.0e-04 updt_s:0.030 data_s:0.058
# INFO 2026-01-11 14:30:52 ot_train.py:354 step:18K smpl:1M ep:9K epch:45.91 loss:0.162 grdn:2.928 lr:3.0e-04 updt_s:0.029 data_s:0.052
# INFO 2026-01-11 14:31:09 ot_train.py:354 step:19K smpl:1M ep:10K epch:46.41 loss:0.172 grdn:3.433 lr:3.0e-04 updt_s:0.030 data_s:0.055
# INFO 2026-01-11 14:31:25 ot_train.py:354 step:19K smpl:1M ep:10K epch:46.91 loss:0.169 grdn:3.344 lr:3.0e-04 updt_s:0.028 data_s:0.051
# INFO 2026-01-11 14:31:42 ot_train.py:354 step:19K smpl:1M ep:10K epch:47.41 loss:0.165 grdn:2.916 lr:3.0e-04 updt_s:0.029 data_s:0.056
# INFO 2026-01-11 14:31:58 ot_train.py:354 step:19K smpl:1M ep:10K epch:47.91 loss:0.171 grdn:3.410 lr:3.0e-04 updt_s:0.029 data_s:0.051
# INFO 2026-01-11 14:32:16 ot_train.py:354 step:19K smpl:1M ep:10K epch:48.41 loss:0.162 grdn:3.062 lr:3.0e-04 updt_s:0.029 data_s:0.059
# INFO 2026-01-11 14:32:32 ot_train.py:354 step:20K smpl:1M ep:10K epch:48.90 loss:0.165 grdn:2.995 lr:3.0e-04 updt_s:0.029 data_s:0.054
# INFO 2026-01-11 14:32:49 ot_train.py:354 step:20K smpl:1M ep:10K epch:49.40 loss:0.165 grdn:3.124 lr:3.0e-04 updt_s:0.028 data_s:0.055
# INFO 2026-01-11 14:33:05 ot_train.py:354 step:20K smpl:1M ep:10K epch:49.90 loss:0.166 grdn:3.297 lr:3.0e-04 updt_s:0.028 data_s:0.049
# INFO 2026-01-11 14:33:21 ot_train.py:354 step:20K smpl:1M ep:10K epch:50.40 loss:0.166 grdn:3.135 lr:3.0e-04 updt_s:0.031 data_s:0.053
# INFO 2026-01-11 14:33:37 ot_train.py:354 step:20K smpl:1M ep:10K epch:50.90 loss:0.167 grdn:3.135 lr:3.0e-04 updt_s:0.029 data_s:0.050
# INFO 2026-01-11 14:33:54 ot_train.py:354 step:21K smpl:1M ep:11K epch:51.40 loss:0.170 grdn:3.311 lr:3.0e-04 updt_s:0.028 data_s:0.055
# INFO 2026-01-11 14:34:09 ot_train.py:354 step:21K smpl:1M ep:11K epch:51.90 loss:0.171 grdn:3.065 lr:3.0e-04 updt_s:0.030 data_s:0.047
# INFO 2026-01-11 14:34:26 ot_train.py:354 step:21K smpl:1M ep:11K epch:52.40 loss:0.171 grdn:3.422 lr:3.0e-04 updt_s:0.030 data_s:0.054
# INFO 2026-01-11 14:39:28 ot_train.py:354 step:25K smpl:2M ep:13K epch:61.38 loss:0.163 grdn:2.857 lr:3.0e-04 updt_s:0.030 data_s:0.055
# INFO 2026-01-11 14:39:44 ot_train.py:354 step:25K smpl:2M ep:13K epch:61.88 loss:0.159 grdn:2.563 lr:3.0e-04 updt_s:0.028 data_s:0.049
# INFO 2026-01-11 14:40:01 ot_train.py:354 step:25K smpl:2M ep:13K epch:62.38 loss:0.165 grdn:2.943 lr:3.0e-04 updt_s:0.030 data_s:0.056
# INFO 2026-01-11 14:40:01 ot_train.py:364 Checkpoint policy after step 25000
# INFO 2026-01-11 14:40:01 ot_train.py:385 Eval policy at step 25000
# Stepping through eval batches:   0%|                      | 0/1 [00:00<?, ?it/s]
# Running rollout with at most 300 steps:   0%|           | 0/300 [00:00<?, ?it/s]/home/hyunjae/anaconda3/envs/lerobot/lib/python3.10/site-packages/lerobot/scripts/lerobot_eval.py:160: UserWarning: The environment does not have 'task_description' and 'task'. Some policies require these features.
#   check_env_attributes_and_types(env)
#
# Running rollout with at most 300 steps:   0%| | 0/300 [00:00<?, ?it/s, running_s
# Running rollout with at most 300 steps:   0%| | 1/300 [00:00<04:24,  1.13it/s, r
# Running rollout with at most 300 steps:   0%| | 1/300 [00:01<04:24,  1.13it/s, r
# Running rollout with at most 300 steps:   1%| | 2/300 [00:01<02:09,  2.30it/s, r
# Running rollout with at most 300 steps:   1%| | 2/300 [00:01<02:09,  2.30it/s, r
# Running rollout with at most 300 steps:   1%| | 3/300 [00:01<03:03,  1.62it/s, r
# Running rollout with at most 300 steps:   1%| | 3/300 [00:01<03:03,  1.62it/s, r
# Running rollout with at most 300 steps:   1%| | 4/300 [00:01<02:03,  2.40it/s, r
# Running rollout with at most 300 steps:   1%| | 4/300 [00:02<02:03,  2.40it/s, r
# Running rollout with at most 300 steps:   2%| | 5/300 [00:02<02:46,  1.77it/s, r
# Running rollout with at most 300 steps:   2%| | 5/300 [00:02<02:46,  1.77it/s, r
# Running rollout with at most 300 steps:   2%| | 6/300 [00:02<02:01,  2.43it/s, r
# Running rollout with at most 300 steps:   2%| | 6/300 [00:03<02:01,  2.43it/s, r
# Running rollout with at most 300 steps:   2%| | 7/300 [00:03<02:38,  1.85it/s, r
# Running rollout with at most 300 steps:   2%| | 7/300 [00:03<02:38,  1.85it/s, r
# Running rollout with at most 300 steps:   3%| | 8/300 [00:03<01:58,  2.47it/s, r
# Running rollout with at most 300 steps:   3%| | 8/300 [00:04<01:58,  2.47it/s, r
# Running rollout with at most 300 steps:   3%| | 9/300 [00:04<02:34,  1.88it/s, r
# Running rollout with at most 300 steps:   3%| | 9/300 [00:04<02:34,  1.88it/s, r
# Running rollout with at most 300 steps:   3%| | 10/300 [00:04<01:56,  2.49it/s,
# Running rollout with at most 300 steps:   3%| | 10/300 [00:05<01:56,  2.49it/s,
# Running rollout with at most 300 steps:   4%| | 11/300 [00:05<02:31,  1.90it/s,
# Running rollout with at most 300 steps:   4%| | 11/300 [00:05<02:31,  1.90it/s,
# Running rollout with at most 300 steps:   4%| | 12/300 [00:05<01:54,  2.51it/s,
# Running rollout with at most 300 steps:   4%| | 12/300 [00:06<01:54,  2.51it/s,
# Running rollout with at most 300 steps:   4%| | 13/300 [00:06<02:30,  1.91it/s,
# Running rollout with at most 300 steps:   4%| | 13/300 [00:06<02:30,  1.91it/s,
# Running rollout with at most 300 steps:   5%| | 14/300 [00:06<01:53,  2.51it/s,
# Running rollout with at most 300 steps:   5%| | 14/300 [00:07<01:53,  2.51it/s,
# Running rollout with at most 300 steps:   5%| | 15/300 [00:07<02:28,  1.92it/s,
# Running rollout with at most 300 steps:   5%| | 15/300 [00:07<02:28,  1.92it/s,
# Running rollout with at most 300 steps:   5%| | 16/300 [00:07<01:52,  2.52it/s,
# Running rollout with at most 300 steps:   5%| | 16/300 [00:08<01:52,  2.52it/s,
# Running rollout with at most 300 steps:   6%| | 17/300 [00:08<02:27,  1.92it/s,
# Running rollout with at most 300 steps:   6%| | 17/300 [00:08<02:27,  1.92it/s,
# Running rollout with at most 300 steps:   6%| | 18/300 [00:08<01:51,  2.52it/s,
# Running rollout with at most 300 steps:   6%| | 18/300 [00:09<01:51,  2.52it/s,
# Running rollout with at most 300 steps:   6%| | 19/300 [00:09<02:26,  1.92it/s,
# Running rollout with at most 300 steps:   6%| | 19/300 [00:09<02:26,  1.92it/s,
# Running rollout with at most 300 steps:   7%| | 20/300 [00:09<01:51,  2.52it/s,
# Running rollout with at most 300 steps:   7%| | 20/300 [00:10<01:51,  2.52it/s,
# Running rollout with at most 300 steps:   7%| | 21/300 [00:10<02:25,  1.92it/s,
# Running rollout with at most 300 steps:   7%| | 21/300 [00:10<02:25,  1.92it/s,
# Running rollout with at most 300 steps:   7%| | 22/300 [00:10<01:50,  2.52it/s,
# Running rollout with at most 300 steps:   7%| | 22/300 [00:11<01:50,  2.52it/s,
# Running rollout with at most 300 steps:   8%| | 23/300 [00:11<02:24,  1.92it/s,
# Running rollout with at most 300 steps:   8%| | 23/300 [00:11<02:24,  1.92it/s,
# Running rollout with at most 300 steps:   8%| | 24/300 [00:11<01:49,  2.52it/s,
# Running rollout with at most 300 steps:   8%| | 24/300 [00:11<01:49,  2.52it/s,
# Running rollout with at most 300 steps:   8%| | 25/300 [00:11<02:23,  1.91it/s,
# Running rollout with at most 300 steps:   8%| | 25/300 [00:12<02:23,  1.91it/s,
# Running rollout with at most 300 steps:   9%| | 26/300 [00:12<01:48,  2.51it/s,
# Running rollout with at most 300 steps:   9%| | 26/300 [00:12<01:48,  2.51it/s,
# Running rollout with at most 300 steps:   9%| | 27/300 [00:12<02:22,  1.92it/s,
# Running rollout with at most 300 steps:   9%| | 27/300 [00:12<02:22,  1.92it/s,
# Running rollout with at most 300 steps:   9%| | 28/300 [00:12<01:47,  2.52it/s,
# Running rollout with at most 300 steps:   9%| | 28/300 [00:13<01:47,  2.52it/s,
# Running rollout with at most 300 steps:  10%| | 29/300 [00:13<02:20,  1.92it/s,
# Running rollout with at most 300 steps:  10%| | 29/300 [00:13<02:20,  1.92it/s,
# Running rollout with at most 300 steps:  10%| | 30/300 [00:13<01:46,  2.53it/s,
# Running rollout with at most 300 steps:  10%| | 30/300 [00:14<01:46,  2.53it/s,
# Running rollout with at most 300 steps:  10%| | 31/300 [00:14<02:19,  1.93it/s,
# Running rollout with at most 300 steps:  10%| | 31/300 [00:14<02:19,  1.93it/s,
# Running rollout with at most 300 steps:  11%| | 32/300 [00:14<01:46,  2.53it/s,
# Running rollout with at most 300 steps:  11%| | 32/300 [00:15<01:46,  2.53it/s,
# Running rollout with at most 300 steps:  11%| | 33/300 [00:15<02:18,  1.93it/s,
# Running rollout with at most 300 steps:  11%| | 33/300 [00:15<02:18,  1.93it/s,
# Running rollout with at most 300 steps:  11%| | 34/300 [00:15<01:44,  2.54it/s,
# Running rollout with at most 300 steps:  11%| | 34/300 [00:16<01:44,  2.54it/s,
# Running rollout with at most 300 steps:  12%| | 35/300 [00:16<02:17,  1.93it/s,
# Running rollout with at most 300 steps:  12%| | 35/300 [00:16<02:17,  1.93it/s,
# Running rollout with at most 300 steps:  12%| | 36/300 [00:16<01:43,  2.54it/s,
# Running rollout with at most 300 steps:  12%| | 36/300 [00:17<01:43,  2.54it/s,
# Running rollout with at most 300 steps:  12%| | 37/300 [00:17<02:16,  1.93it/s,
# Running rollout with at most 300 steps:  12%| | 37/300 [00:17<02:16,  1.93it/s,
# Running rollout with at most 300 steps:  13%|▏| 38/300 [00:17<01:43,  2.54it/s,
# Running rollout with at most 300 steps:  13%|▏| 38/300 [00:18<01:43,  2.54it/s,
# Running rollout with at most 300 steps:  13%|▏| 39/300 [00:18<02:15,  1.92it/s,
# Running rollout with at most 300 steps:  13%|▏| 39/300 [00:18<02:15,  1.92it/s,
# Running rollout with at most 300 steps:  13%|▏| 40/300 [00:18<01:43,  2.52it/s,
# Running rollout with at most 300 steps:  13%|▏| 40/300 [00:19<01:43,  2.52it/s,
# Running rollout with at most 300 steps:  14%|▏| 41/300 [00:19<02:15,  1.92it/s,
# Running rollout with at most 300 steps:  14%|▏| 41/300 [00:19<02:15,  1.92it/s,
# Running rollout with at most 300 steps:  14%|▏| 42/300 [00:19<01:42,  2.52it/s,
# Running rollout with at most 300 steps:  14%|▏| 42/300 [00:20<01:42,  2.52it/s,
# Running rollout with at most 300 steps:  14%|▏| 43/300 [00:20<02:14,  1.91it/s,
# Running rollout with at most 300 steps:  14%|▏| 43/300 [00:20<02:14,  1.91it/s,
# Running rollout with at most 300 steps:  15%|▏| 44/300 [00:20<01:42,  2.50it/s,
# Running rollout with at most 300 steps:  15%|▏| 44/300 [00:21<01:42,  2.50it/s,
# Running rollout with at most 300 steps:  15%|▏| 45/300 [00:21<02:14,  1.90it/s,
# Running rollout with at most 300 steps:  15%|▏| 45/300 [00:21<02:14,  1.90it/s,
# Running rollout with at most 300 steps:  15%|▏| 46/300 [00:21<01:41,  2.49it/s,
# Running rollout with at most 300 steps:  15%|▏| 46/300 [00:22<01:41,  2.49it/s,
# Running rollout with at most 300 steps:  16%|▏| 47/300 [00:22<02:13,  1.90it/s,
# Running rollout with at most 300 steps:  16%|▏| 47/300 [00:22<02:13,  1.90it/s,
# Running rollout with at most 300 steps:  16%|▏| 48/300 [00:22<01:41,  2.49it/s,
# Running rollout with at most 300 steps:  16%|▏| 48/300 [00:23<01:41,  2.49it/s,
# Running rollout with at most 300 steps:  16%|▏| 49/300 [00:23<02:12,  1.90it/s,
# Running rollout with at most 300 steps:  16%|▏| 49/300 [00:23<02:12,  1.90it/s,
# Running rollout with at most 300 steps:  17%|▏| 50/300 [00:23<01:40,  2.49it/s,
# Running rollout with at most 300 steps:  17%|▏| 50/300 [00:23<01:40,  2.49it/s,
# Running rollout with at most 300 steps:  17%|▏| 51/300 [00:23<02:11,  1.89it/s,
# Running rollout with at most 300 steps:  17%|▏| 51/300 [00:24<02:11,  1.89it/s,
# Running rollout with at most 300 steps:  17%|▏| 52/300 [00:24<01:39,  2.49it/s,
# Running rollout with at most 300 steps:  17%|▏| 52/300 [00:24<01:39,  2.49it/s,
# Running rollout with at most 300 steps:  18%|▏| 53/300 [00:24<02:09,  1.90it/s,
# Running rollout with at most 300 steps:  18%|▏| 53/300 [00:24<02:09,  1.90it/s,
# Running rollout with at most 300 steps:  18%|▏| 54/300 [00:24<01:38,  2.50it/s,
# Running rollout with at most 300 steps:  18%|▏| 54/300 [00:25<01:38,  2.50it/s,
# Running rollout with at most 300 steps:  18%|▏| 55/300 [00:25<02:08,  1.90it/s,
# Running rollout with at most 300 steps:  18%|▏| 55/300 [00:25<02:08,  1.90it/s,
# Running rollout with at most 300 steps:  19%|▏| 56/300 [00:25<01:37,  2.50it/s,
# Running rollout with at most 300 steps:  19%|▏| 56/300 [00:26<01:37,  2.50it/s,
# Running rollout with at most 300 steps:  19%|▏| 57/300 [00:26<02:07,  1.90it/s,
# Running rollout with at most 300 steps:  19%|▏| 57/300 [00:26<02:07,  1.90it/s,
# Running rollout with at most 300 steps:  19%|▏| 58/300 [00:26<01:36,  2.50it/s,
# Running rollout with at most 300 steps:  19%|▏| 58/300 [00:27<01:36,  2.50it/s,
# Running rollout with at most 300 steps:  20%|▏| 59/300 [00:27<02:06,  1.90it/s,
# Running rollout with at most 300 steps:  20%|▏| 59/300 [00:27<02:06,  1.90it/s,
# Running rollout with at most 300 steps:  20%|▏| 60/300 [00:27<01:35,  2.50it/s,
# Running rollout with at most 300 steps:  20%|▏| 60/300 [00:28<01:35,  2.50it/s,
# Running rollout with at most 300 steps:  20%|▏| 61/300 [00:28<02:05,  1.90it/s,
# Running rollout with at most 300 steps:  20%|▏| 61/300 [00:28<02:05,  1.90it/s,
# Running rollout with at most 300 steps:  21%|▏| 62/300 [00:28<01:35,  2.50it/s,
# Running rollout with at most 300 steps:  21%|▏| 62/300 [00:29<01:35,  2.50it/s,
# Running rollout with at most 300 steps:  21%|▏| 63/300 [00:29<02:04,  1.90it/s,
# Running rollout with at most 300 steps:  21%|▏| 63/300 [00:29<02:04,  1.90it/s,
# Running rollout with at most 300 steps:  21%|▏| 64/300 [00:29<01:34,  2.49it/s,
# Running rollout with at most 300 steps:  21%|▏| 64/300 [00:30<01:34,  2.49it/s,
# Running rollout with at most 300 steps:  22%|▏| 65/300 [00:30<02:03,  1.90it/s,
# Running rollout with at most 300 steps:  22%|▏| 65/300 [00:30<02:03,  1.90it/s,
# Running rollout with at most 300 steps:  22%|▏| 66/300 [00:30<01:33,  2.50it/s,
# Running rollout with at most 300 steps:  22%|▏| 66/300 [00:31<01:33,  2.50it/s,
# Running rollout with at most 300 steps:  22%|▏| 67/300 [00:31<02:02,  1.91it/s,
# Running rollout with at most 300 steps:  22%|▏| 67/300 [00:31<02:02,  1.91it/s,
# Running rollout with at most 300 steps:  23%|▏| 68/300 [00:31<01:32,  2.50it/s,
# Running rollout with at most 300 steps:  23%|▏| 68/300 [00:32<01:32,  2.50it/s,
# Running rollout with at most 300 steps:  23%|▏| 69/300 [00:32<02:00,  1.91it/s,
# Running rollout with at most 300 steps:  23%|▏| 69/300 [00:32<02:00,  1.91it/s,
# Running rollout with at most 300 steps:  23%|▏| 70/300 [00:32<01:31,  2.51it/s,
# Running rollout with at most 300 steps:  23%|▏| 70/300 [00:33<01:31,  2.51it/s,
# Running rollout with at most 300 steps:  24%|▏| 71/300 [00:33<01:59,  1.92it/s,
# Running rollout with at most 300 steps:  24%|▏| 71/300 [00:33<01:59,  1.92it/s,
# Running rollout with at most 300 steps:  24%|▏| 72/300 [00:33<01:30,  2.51it/s,
# Running rollout with at most 300 steps:  24%|▏| 72/300 [00:34<01:30,  2.51it/s,
# Running rollout with at most 300 steps:  24%|▏| 73/300 [00:34<01:58,  1.92it/s,
# Running rollout with at most 300 steps:  24%|▏| 73/300 [00:34<01:58,  1.92it/s,
# Running rollout with at most 300 steps:  25%|▏| 74/300 [00:34<01:29,  2.51it/s,
# Running rollout with at most 300 steps:  25%|▏| 74/300 [00:35<01:29,  2.51it/s,
# Running rollout with at most 300 steps:  25%|▎| 75/300 [00:35<01:57,  1.91it/s,
# Running rollout with at most 300 steps:  25%|▎| 75/300 [00:35<01:57,  1.91it/s,
# Running rollout with at most 300 steps:  25%|▎| 76/300 [00:35<01:29,  2.51it/s,
# Running rollout with at most 300 steps:  25%|▎| 76/300 [00:35<01:29,  2.51it/s,
# Running rollout with at most 300 steps:  26%|▎| 77/300 [00:35<01:57,  1.90it/s,
# Running rollout with at most 300 steps:  26%|▎| 77/300 [00:36<01:57,  1.90it/s,
# Running rollout with at most 300 steps:  26%|▎| 78/300 [00:36<01:28,  2.50it/s,
# Running rollout with at most 300 steps:  26%|▎| 78/300 [00:36<01:28,  2.50it/s,
# Running rollout with at most 300 steps:  26%|▎| 79/300 [00:36<01:56,  1.90it/s,
# Running rollout with at most 300 steps:  26%|▎| 79/300 [00:36<01:56,  1.90it/s,
# Running rollout with at most 300 steps:  27%|▎| 80/300 [00:36<01:28,  2.50it/s,
# Running rollout with at most 300 steps:  27%|▎| 80/300 [00:37<01:28,  2.50it/s,
# Running rollout with at most 300 steps:  27%|▎| 81/300 [00:37<01:55,  1.89it/s,
# Running rollout with at most 300 steps:  27%|▎| 81/300 [00:37<01:55,  1.89it/s,
# Running rollout with at most 300 steps:  27%|▎| 82/300 [00:37<01:27,  2.48it/s,
# Running rollout with at most 300 steps:  27%|▎| 82/300 [00:38<01:27,  2.48it/s,
# Running rollout with at most 300 steps:  28%|▎| 83/300 [00:38<01:54,  1.89it/s,
# Running rollout with at most 300 steps:  28%|▎| 83/300 [00:38<01:54,  1.89it/s,
# Running rollout with at most 300 steps:  28%|▎| 84/300 [00:38<01:26,  2.48it/s,
# Running rollout with at most 300 steps:  28%|▎| 84/300 [00:39<01:26,  2.48it/s,
# Running rollout with at most 300 steps:  28%|▎| 85/300 [00:39<01:54,  1.88it/s,
# Running rollout with at most 300 steps:  28%|▎| 85/300 [00:39<01:54,  1.88it/s,
# Running rollout with at most 300 steps:  29%|▎| 86/300 [00:39<01:26,  2.48it/s,
# Running rollout with at most 300 steps:  29%|▎| 86/300 [00:40<01:26,  2.48it/s,
# Running rollout with at most 300 steps:  29%|▎| 87/300 [00:40<01:53,  1.88it/s,
# Running rollout with at most 300 steps:  29%|▎| 87/300 [00:40<01:53,  1.88it/s,
# Running rollout with at most 300 steps:  29%|▎| 88/300 [00:40<01:25,  2.47it/s,
# Running rollout with at most 300 steps:  29%|▎| 88/300 [00:41<01:25,  2.47it/s,
# Running rollout with at most 300 steps:  30%|▎| 89/300 [00:41<01:52,  1.87it/s,
# Running rollout with at most 300 steps:  30%|▎| 89/300 [00:41<01:52,  1.87it/s,
# Running rollout with at most 300 steps:  30%|▎| 90/300 [00:41<01:26,  2.43it/s,
# Running rollout with at most 300 steps:  30%|▎| 90/300 [00:42<01:26,  2.43it/s,
# Running rollout with at most 300 steps:  30%|▎| 91/300 [00:42<01:52,  1.85it/s,
# Running rollout with at most 300 steps:  30%|▎| 91/300 [00:42<01:52,  1.85it/s,
# Running rollout with at most 300 steps:  31%|▎| 92/300 [00:42<01:25,  2.44it/s,
# Running rollout with at most 300 steps:  31%|▎| 92/300 [00:43<01:25,  2.44it/s,
# Running rollout with at most 300 steps:  31%|▎| 93/300 [00:43<01:51,  1.86it/s,
# Running rollout with at most 300 steps:  31%|▎| 93/300 [00:43<01:51,  1.86it/s,
# Running rollout with at most 300 steps:  31%|▎| 94/300 [00:43<01:24,  2.45it/s,
# Running rollout with at most 300 steps:  31%|▎| 94/300 [00:44<01:24,  2.45it/s,
# Running rollout with at most 300 steps:  32%|▎| 95/300 [00:44<01:50,  1.86it/s,
# Running rollout with at most 300 steps:  32%|▎| 95/300 [00:44<01:50,  1.86it/s,
# Running rollout with at most 300 steps:  32%|▎| 96/300 [00:44<01:23,  2.44it/s,
# Running rollout with at most 300 steps:  32%|▎| 96/300 [00:45<01:23,  2.44it/s,
# Running rollout with at most 300 steps:  32%|▎| 97/300 [00:45<01:48,  1.88it/s,
# Running rollout with at most 300 steps:  32%|▎| 97/300 [00:45<01:48,  1.88it/s,
# Running rollout with at most 300 steps:  33%|▎| 98/300 [00:45<01:21,  2.47it/s,
# Running rollout with at most 300 steps:  33%|▎| 98/300 [00:46<01:21,  2.47it/s,
# Running rollout with at most 300 steps:  33%|▎| 99/300 [00:46<01:45,  1.90it/s,
# Running rollout with at most 300 steps:  33%|▎| 99/300 [00:46<01:45,  1.90it/s,
# Running rollout with at most 300 steps:  33%|▎| 100/300 [00:46<01:20,  2.49it/s,
# Running rollout with at most 300 steps:  33%|▎| 100/300 [00:47<01:20,  2.49it/s,
# Running rollout with at most 300 steps:  34%|▎| 101/300 [00:47<01:44,  1.91it/s,
# Running rollout with at most 300 steps:  34%|▎| 101/300 [00:47<01:44,  1.91it/s,
# Running rollout with at most 300 steps:  34%|▎| 102/300 [00:47<01:18,  2.51it/s,
# Running rollout with at most 300 steps:  34%|▎| 102/300 [00:48<01:18,  2.51it/s,
# Running rollout with at most 300 steps:  34%|▎| 103/300 [00:48<01:42,  1.91it/s,
# Running rollout with at most 300 steps:  34%|▎| 103/300 [00:48<01:42,  1.91it/s,
# Running rollout with at most 300 steps:  35%|▎| 104/300 [00:48<01:17,  2.51it/s,
# Running rollout with at most 300 steps:  35%|▎| 104/300 [00:49<01:17,  2.51it/s,
# Running rollout with at most 300 steps:  35%|▎| 105/300 [00:49<01:41,  1.92it/s,
# Running rollout with at most 300 steps:  35%|▎| 105/300 [00:49<01:41,  1.92it/s,
# Running rollout with at most 300 steps:  35%|▎| 106/300 [00:49<01:16,  2.52it/s,
# Running rollout with at most 300 steps:  35%|▎| 106/300 [00:49<01:16,  2.52it/s,
# Running rollout with at most 300 steps:  36%|▎| 107/300 [00:49<01:40,  1.92it/s,
# Running rollout with at most 300 steps:  36%|▎| 107/300 [00:50<01:40,  1.92it/s,
# Running rollout with at most 300 steps:  36%|▎| 108/300 [00:50<01:16,  2.52it/s,
# Running rollout with at most 300 steps:  36%|▎| 108/300 [00:50<01:16,  2.52it/s,
# Running rollout with at most 300 steps:  36%|▎| 109/300 [00:50<01:39,  1.92it/s,
# Running rollout with at most 300 steps:  36%|▎| 109/300 [00:50<01:39,  1.92it/s,
# Running rollout with at most 300 steps:  37%|▎| 110/300 [00:50<01:15,  2.52it/s,
# Running rollout with at most 300 steps:  37%|▎| 110/300 [00:51<01:15,  2.52it/s,
# Running rollout with at most 300 steps:  37%|▎| 111/300 [00:51<01:39,  1.91it/s,
# Running rollout with at most 300 steps:  37%|▎| 111/300 [00:51<01:39,  1.91it/s,
# Running rollout with at most 300 steps:  37%|▎| 112/300 [00:51<01:15,  2.51it/s,
# Running rollout with at most 300 steps:  37%|▎| 112/300 [00:52<01:15,  2.51it/s,
# Running rollout with at most 300 steps:  38%|▍| 113/300 [00:52<01:38,  1.89it/s,
# Running rollout with at most 300 steps:  38%|▍| 113/300 [00:52<01:38,  1.89it/s,
# Running rollout with at most 300 steps:  38%|▍| 114/300 [00:52<01:14,  2.49it/s,
# Running rollout with at most 300 steps:  38%|▍| 114/300 [00:53<01:14,  2.49it/s,
# Running rollout with at most 300 steps:  38%|▍| 115/300 [00:53<01:38,  1.88it/s,
# Running rollout with at most 300 steps:  38%|▍| 115/300 [00:53<01:38,  1.88it/s,
# Running rollout with at most 300 steps:  39%|▍| 116/300 [00:53<01:14,  2.48it/s,
# Running rollout with at most 300 steps:  39%|▍| 116/300 [00:54<01:14,  2.48it/s,
# Running rollout with at most 300 steps:  39%|▍| 117/300 [00:54<01:37,  1.88it/s,
# Running rollout with at most 300 steps:  39%|▍| 117/300 [00:54<01:37,  1.88it/s,
# Running rollout with at most 300 steps:  39%|▍| 118/300 [00:54<01:14,  2.45it/s,
# Running rollout with at most 300 steps:  39%|▍| 118/300 [00:55<01:14,  2.45it/s,
# Running rollout with at most 300 steps:  40%|▍| 119/300 [00:55<01:36,  1.88it/s,
# Running rollout with at most 300 steps:  40%|▍| 119/300 [00:55<01:36,  1.88it/s,
# Running rollout with at most 300 steps:  40%|▍| 120/300 [00:55<01:12,  2.47it/s,
# Running rollout with at most 300 steps:  40%|▍| 120/300 [00:56<01:12,  2.47it/s,
# Running rollout with at most 300 steps:  40%|▍| 121/300 [00:56<01:34,  1.89it/s,
# Running rollout with at most 300 steps:  40%|▍| 121/300 [00:56<01:34,  1.89it/s,
# Running rollout with at most 300 steps:  41%|▍| 122/300 [00:56<01:11,  2.49it/s,
# Running rollout with at most 300 steps:  41%|▍| 122/300 [00:57<01:11,  2.49it/s,
# Running rollout with at most 300 steps:  41%|▍| 123/300 [00:57<01:33,  1.89it/s,
# Running rollout with at most 300 steps:  41%|▍| 123/300 [00:57<01:33,  1.89it/s,
# Running rollout with at most 300 steps:  41%|▍| 124/300 [00:57<01:10,  2.48it/s,
# Running rollout with at most 300 steps:  41%|▍| 124/300 [00:58<01:10,  2.48it/s,
# Running rollout with at most 300 steps:  42%|▍| 125/300 [00:58<01:32,  1.89it/s,
# Running rollout with at most 300 steps:  42%|▍| 125/300 [00:58<01:32,  1.89it/s,
# Running rollout with at most 300 steps:  42%|▍| 126/300 [00:58<01:10,  2.48it/s,
# Running rollout with at most 300 steps:  42%|▍| 126/300 [00:59<01:10,  2.48it/s,
# Running rollout with at most 300 steps:  42%|▍| 127/300 [00:59<01:31,  1.88it/s,
# Running rollout with at most 300 steps:  42%|▍| 127/300 [00:59<01:31,  1.88it/s,
# Running rollout with at most 300 steps:  43%|▍| 128/300 [00:59<01:09,  2.48it/s,
# Running rollout with at most 300 steps:  43%|▍| 128/300 [01:00<01:09,  2.48it/s,
# Running rollout with at most 300 steps:  43%|▍| 129/300 [01:00<01:30,  1.88it/s,
# Running rollout with at most 300 steps:  43%|▍| 129/300 [01:00<01:30,  1.88it/s,
# Running rollout with at most 300 steps:  43%|▍| 130/300 [01:00<01:08,  2.48it/s,
# Running rollout with at most 300 steps:  43%|▍| 130/300 [01:01<01:08,  2.48it/s,
# Running rollout with at most 300 steps:  44%|▍| 131/300 [01:01<01:29,  1.89it/s,
# Running rollout with at most 300 steps:  44%|▍| 131/300 [01:01<01:29,  1.89it/s,
# Running rollout with at most 300 steps:  44%|▍| 132/300 [01:01<01:07,  2.48it/s,
# Running rollout with at most 300 steps:  44%|▍| 132/300 [01:02<01:07,  2.48it/s,
# Running rollout with at most 300 steps:  44%|▍| 133/300 [01:02<01:28,  1.89it/s,
# Running rollout with at most 300 steps:  44%|▍| 133/300 [01:02<01:28,  1.89it/s,
# Running rollout with at most 300 steps:  45%|▍| 134/300 [01:02<01:06,  2.48it/s,
# Running rollout with at most 300 steps:  45%|▍| 134/300 [01:02<01:06,  2.48it/s,
# Running rollout with at most 300 steps:  45%|▍| 135/300 [01:02<01:27,  1.90it/s,
# Running rollout with at most 300 steps:  45%|▍| 135/300 [01:03<01:27,  1.90it/s,
# Running rollout with at most 300 steps:  45%|▍| 136/300 [01:03<01:05,  2.49it/s,
# Running rollout with at most 300 steps:  45%|▍| 136/300 [01:03<01:05,  2.49it/s,
# Running rollout with at most 300 steps:  46%|▍| 137/300 [01:03<01:25,  1.90it/s,
# Running rollout with at most 300 steps:  46%|▍| 137/300 [01:04<01:25,  1.90it/s,
# Running rollout with at most 300 steps:  46%|▍| 138/300 [01:04<01:04,  2.49it/s,
# Running rollout with at most 300 steps:  46%|▍| 138/300 [01:04<01:04,  2.49it/s,
# Running rollout with at most 300 steps:  46%|▍| 139/300 [01:04<01:24,  1.90it/s,
# Running rollout with at most 300 steps:  46%|▍| 139/300 [01:04<01:24,  1.90it/s,
# Running rollout with at most 300 steps:  47%|▍| 140/300 [01:04<01:03,  2.50it/s,
# Running rollout with at most 300 steps:  47%|▍| 140/300 [01:05<01:03,  2.50it/s,
# Running rollout with at most 300 steps:  47%|▍| 141/300 [01:05<01:23,  1.91it/s,
# ...
# Running rollout with at most 300 steps:  75%|▊| 226/300 [01:46<00:31,  2.36it/s,
# Running rollout with at most 300 steps:  75%|▊| 226/300 [01:47<00:31,  2.36it/s,
# Running rollout with at most 300 steps:  76%|▊| 227/300 [01:47<00:40,  1.81it/s,
# Running rollout with at most 300 steps:  76%|▊| 227/300 [01:47<00:40,  1.81it/s,
# Running rollout with at most 300 steps:  76%|▊| 228/300 [01:47<00:30,  2.37it/s,
# Running rollout with at most 300 steps:  76%|▊| 228/300 [01:48<00:30,  2.37it/s,
# Running rollout with at most 300 steps:  76%|▊| 229/300 [01:48<00:38,  1.83it/s,
# Running rollout with at most 300 steps:  76%|▊| 229/300 [01:48<00:38,  1.83it/s,
# Running rollout with at most 300 steps:  77%|▊| 230/300 [01:48<00:29,  2.39it/s,
# Running rollout with at most 300 steps:  77%|▊| 230/300 [01:49<00:29,  2.39it/s,
# Running rollout with at most 300 steps:  77%|▊| 231/300 [01:49<00:37,  1.83it/s,
# Running rollout with at most 300 steps:  77%|▊| 231/300 [01:49<00:37,  1.83it/s,
# Running rollout with at most 300 steps:  77%|▊| 232/300 [01:49<00:28,  2.39it/s,
# Running rollout with at most 300 steps:  77%|▊| 232/300 [01:50<00:28,  2.39it/s,
# Running rollout with at most 300 steps:  78%|▊| 233/300 [01:50<00:36,  1.84it/s,
# Running rollout with at most 300 steps:  78%|▊| 233/300 [01:50<00:36,  1.84it/s,
# Running rollout with at most 300 steps:  78%|▊| 234/300 [01:50<00:27,  2.41it/s,
# Running rollout with at most 300 steps:  78%|▊| 234/300 [01:51<00:27,  2.41it/s,
# Running rollout with at most 300 steps:  78%|▊| 235/300 [01:51<00:35,  1.85it/s,
# Running rollout with at most 300 steps:  78%|▊| 235/300 [01:51<00:35,  1.85it/s,
# Running rollout with at most 300 steps:  79%|▊| 236/300 [01:51<00:26,  2.41it/s,
# Running rollout with at most 300 steps:  79%|▊| 236/300 [01:52<00:26,  2.41it/s,
# Running rollout with at most 300 steps:  79%|▊| 237/300 [01:52<00:33,  1.86it/s,
# Running rollout with at most 300 steps:  79%|▊| 237/300 [01:52<00:33,  1.86it/s,
# Running rollout with at most 300 steps:  79%|▊| 238/300 [01:52<00:25,  2.42it/s,
# Running rollout with at most 300 steps:  79%|▊| 238/300 [01:53<00:25,  2.42it/s,
# Running rollout with at most 300 steps:  80%|▊| 239/300 [01:53<00:32,  1.87it/s,
# Running rollout with at most 300 steps:  80%|▊| 239/300 [01:53<00:32,  1.87it/s,
# Running rollout with at most 300 steps:  80%|▊| 240/300 [01:53<00:24,  2.44it/s,
# Running rollout with at most 300 steps:  80%|▊| 240/300 [01:54<00:24,  2.44it/s,
# Running rollout with at most 300 steps:  80%|▊| 241/300 [01:54<00:31,  1.87it/s,
# Running rollout with at most 300 steps:  80%|▊| 241/300 [01:54<00:31,  1.87it/s,
# Running rollout with at most 300 steps:  81%|▊| 242/300 [01:54<00:23,  2.44it/s,
# Running rollout with at most 300 steps:  81%|▊| 242/300 [01:55<00:23,  2.44it/s,
# Running rollout with at most 300 steps:  81%|▊| 243/300 [01:55<00:30,  1.88it/s,
# Running rollout with at most 300 steps:  81%|▊| 243/300 [01:55<00:30,  1.88it/s,
# Running rollout with at most 300 steps:  81%|▊| 244/300 [01:55<00:22,  2.47it/s,
# Running rollout with at most 300 steps:  81%|▊| 244/300 [01:56<00:22,  2.47it/s,
# Running rollout with at most 300 steps:  82%|▊| 245/300 [01:56<00:29,  1.88it/s,
# Running rollout with at most 300 steps:  82%|▊| 245/300 [01:56<00:29,  1.88it/s,
# Running rollout with at most 300 steps:  82%|▊| 246/300 [01:56<00:21,  2.48it/s,
# Running rollout with at most 300 steps:  82%|▊| 246/300 [01:57<00:21,  2.48it/s,
# Running rollout with at most 300 steps:  82%|▊| 247/300 [01:57<00:28,  1.88it/s,
# Running rollout with at most 300 steps:  82%|▊| 247/300 [01:57<00:28,  1.88it/s,
# Running rollout with at most 300 steps:  83%|▊| 248/300 [01:57<00:21,  2.47it/s,
# Running rollout with at most 300 steps:  83%|▊| 248/300 [01:58<00:21,  2.47it/s,
# Running rollout with at most 300 steps:  83%|▊| 249/300 [01:58<00:27,  1.88it/s,
# Running rollout with at most 300 steps:  83%|▊| 249/300 [01:58<00:27,  1.88it/s,
# Running rollout with at most 300 steps:  83%|▊| 250/300 [01:58<00:20,  2.44it/s,
# Running rollout with at most 300 steps:  83%|▊| 250/300 [01:59<00:20,  2.44it/s,
# Running rollout with at most 300 steps:  84%|▊| 251/300 [01:59<00:26,  1.87it/s,
# Running rollout with at most 300 steps:  84%|▊| 251/300 [01:59<00:26,  1.87it/s,
# Running rollout with at most 300 steps:  84%|▊| 252/300 [01:59<00:19,  2.44it/s,
# Running rollout with at most 300 steps:  84%|▊| 252/300 [02:00<00:19,  2.44it/s,
# Running rollout with at most 300 steps:  84%|▊| 253/300 [02:00<00:25,  1.87it/s,
# Running rollout with at most 300 steps:  84%|▊| 253/300 [02:00<00:25,  1.87it/s,
# Running rollout with at most 300 steps:  85%|▊| 254/300 [02:00<00:18,  2.42it/s,
# Running rollout with at most 300 steps:  85%|▊| 254/300 [02:01<00:18,  2.42it/s,
# Running rollout with at most 300 steps:  85%|▊| 255/300 [02:01<00:24,  1.84it/s,
# Running rollout with at most 300 steps:  85%|▊| 255/300 [02:01<00:24,  1.84it/s,
# Running rollout with at most 300 steps:  85%|▊| 256/300 [02:01<00:18,  2.39it/s,
# Running rollout with at most 300 steps:  85%|▊| 256/300 [02:01<00:18,  2.39it/s,
# Running rollout with at most 300 steps:  86%|▊| 257/300 [02:01<00:23,  1.87it/s,
# Running rollout with at most 300 steps:  86%|▊| 257/300 [02:02<00:23,  1.87it/s,
# Running rollout with at most 300 steps:  86%|▊| 258/300 [02:02<00:17,  2.43it/s,
# Running rollout with at most 300 steps:  86%|▊| 258/300 [02:02<00:17,  2.43it/s,
# Running rollout with at most 300 steps:  86%|▊| 259/300 [02:02<00:21,  1.88it/s,
# Running rollout with at most 300 steps:  86%|▊| 259/300 [02:02<00:21,  1.88it/s,
# Running rollout with at most 300 steps:  87%|▊| 260/300 [02:02<00:16,  2.47it/s,
# Running rollout with at most 300 steps:  87%|▊| 260/300 [02:03<00:16,  2.47it/s,
# Running rollout with at most 300 steps:  87%|▊| 261/300 [02:03<00:20,  1.89it/s,
# Running rollout with at most 300 steps:  87%|▊| 261/300 [02:03<00:20,  1.89it/s,
# Running rollout with at most 300 steps:  87%|▊| 262/300 [02:03<00:15,  2.49it/s,
# Running rollout with at most 300 steps:  87%|▊| 262/300 [02:04<00:15,  2.49it/s,
# Running rollout with at most 300 steps:  88%|▉| 263/300 [02:04<00:19,  1.89it/s,
# Running rollout with at most 300 steps:  88%|▉| 263/300 [02:04<00:19,  1.89it/s,
# Running rollout with at most 300 steps:  88%|▉| 264/300 [02:04<00:14,  2.49it/s,
# Running rollout with at most 300 steps:  88%|▉| 264/300 [02:05<00:14,  2.49it/s,
# Running rollout with at most 300 steps:  88%|▉| 265/300 [02:05<00:18,  1.87it/s,
# Running rollout with at most 300 steps:  88%|▉| 265/300 [02:05<00:18,  1.87it/s,
# Running rollout with at most 300 steps:  89%|▉| 266/300 [02:05<00:13,  2.43it/s,
# Running rollout with at most 300 steps:  89%|▉| 266/300 [02:06<00:13,  2.43it/s,
# Running rollout with at most 300 steps:  89%|▉| 267/300 [02:06<00:17,  1.84it/s,
# Running rollout with at most 300 steps:  89%|▉| 267/300 [02:06<00:17,  1.84it/s,
# Running rollout with at most 300 steps:  89%|▉| 268/300 [02:06<00:13,  2.43it/s,
# Running rollout with at most 300 steps:  89%|▉| 268/300 [02:07<00:13,  2.43it/s,
# Running rollout with at most 300 steps:  90%|▉| 269/300 [02:07<00:16,  1.85it/s,
# Running rollout with at most 300 steps:  90%|▉| 269/300 [02:07<00:16,  1.85it/s,
# Running rollout with at most 300 steps:  90%|▉| 270/300 [02:07<00:12,  2.40it/s,
# Running rollout with at most 300 steps:  90%|▉| 270/300 [02:08<00:12,  2.40it/s,
# Running rollout with at most 300 steps:  90%|▉| 271/300 [02:08<00:15,  1.83it/s,
# Running rollout with at most 300 steps:  90%|▉| 271/300 [02:08<00:15,  1.83it/s,
# Running rollout with at most 300 steps:  91%|▉| 272/300 [02:08<00:11,  2.38it/s,
# Running rollout with at most 300 steps:  91%|▉| 272/300 [02:09<00:11,  2.38it/s,
# Running rollout with at most 300 steps:  91%|▉| 273/300 [02:09<00:14,  1.82it/s,
# Running rollout with at most 300 steps:  91%|▉| 273/300 [02:09<00:14,  1.82it/s,
# Running rollout with at most 300 steps:  91%|▉| 274/300 [02:09<00:10,  2.38it/s,
# Running rollout with at most 300 steps:  91%|▉| 274/300 [02:10<00:10,  2.38it/s,
# Running rollout with at most 300 steps:  92%|▉| 275/300 [02:10<00:13,  1.82it/s,
# Running rollout with at most 300 steps:  92%|▉| 275/300 [02:10<00:13,  1.82it/s,
# Running rollout with at most 300 steps:  92%|▉| 276/300 [02:10<00:10,  2.40it/s,
# Running rollout with at most 300 steps:  92%|▉| 276/300 [02:11<00:10,  2.40it/s,
# Running rollout with at most 300 steps:  92%|▉| 277/300 [02:11<00:12,  1.83it/s,
# Running rollout with at most 300 steps:  92%|▉| 277/300 [02:11<00:12,  1.83it/s,
# Running rollout with at most 300 steps:  93%|▉| 278/300 [02:11<00:09,  2.40it/s,
# Running rollout with at most 300 steps:  93%|▉| 278/300 [02:12<00:09,  2.40it/s,
# Running rollout with at most 300 steps:  93%|▉| 279/300 [02:12<00:11,  1.85it/s,
# Running rollout with at most 300 steps:  93%|▉| 279/300 [02:12<00:11,  1.85it/s,
# Running rollout with at most 300 steps:  93%|▉| 280/300 [02:12<00:08,  2.44it/s,
# Running rollout with at most 300 steps:  93%|▉| 280/300 [02:13<00:08,  2.44it/s,
# Running rollout with at most 300 steps:  94%|▉| 281/300 [02:13<00:10,  1.87it/s,
# Running rollout with at most 300 steps:  94%|▉| 281/300 [02:13<00:10,  1.87it/s,
# Running rollout with at most 300 steps:  94%|▉| 282/300 [02:13<00:07,  2.45it/s,
# Running rollout with at most 300 steps:  94%|▉| 282/300 [02:14<00:07,  2.45it/s,
# Running rollout with at most 300 steps:  94%|▉| 283/300 [02:14<00:09,  1.88it/s,
# Running rollout with at most 300 steps:  94%|▉| 283/300 [02:14<00:09,  1.88it/s,
# Running rollout with at most 300 steps:  95%|▉| 284/300 [02:14<00:06,  2.47it/s,
# Running rollout with at most 300 steps:  95%|▉| 284/300 [02:15<00:06,  2.47it/s,
# Running rollout with at most 300 steps:  95%|▉| 285/300 [02:15<00:07,  1.89it/s,
# Running rollout with at most 300 steps:  95%|▉| 285/300 [02:15<00:07,  1.89it/s,
# Running rollout with at most 300 steps:  95%|▉| 286/300 [02:15<00:05,  2.47it/s,
# Running rollout with at most 300 steps:  95%|▉| 286/300 [02:16<00:05,  2.47it/s,
# Running rollout with at most 300 steps:  96%|▉| 287/300 [02:16<00:06,  1.90it/s,
# Running rollout with at most 300 steps:  96%|▉| 287/300 [02:16<00:06,  1.90it/s,
# Running rollout with at most 300 steps:  96%|▉| 288/300 [02:16<00:04,  2.49it/s,
# Running rollout with at most 300 steps:  96%|▉| 288/300 [02:17<00:04,  2.49it/s,
# Running rollout with at most 300 steps:  96%|▉| 289/300 [02:17<00:05,  1.91it/s,
# Running rollout with at most 300 steps:  96%|▉| 289/300 [02:17<00:05,  1.91it/s,
# Running rollout with at most 300 steps:  97%|▉| 290/300 [02:17<00:04,  2.50it/s,
# Running rollout with at most 300 steps:  97%|▉| 290/300 [02:18<00:04,  2.50it/s,
# Running rollout with at most 300 steps:  97%|▉| 291/300 [02:18<00:04,  1.90it/s,
# Running rollout with at most 300 steps:  97%|▉| 291/300 [02:18<00:04,  1.90it/s,
# Running rollout with at most 300 steps:  97%|▉| 292/300 [02:18<00:03,  2.50it/s,
# Running rollout with at most 300 steps:  97%|▉| 292/300 [02:18<00:03,  2.50it/s,
# Running rollout with at most 300 steps:  98%|▉| 293/300 [02:18<00:03,  1.90it/s,
# Running rollout with at most 300 steps:  98%|▉| 293/300 [02:19<00:03,  1.90it/s,
# Running rollout with at most 300 steps:  98%|▉| 294/300 [02:19<00:02,  2.48it/s,
# Running rollout with at most 300 steps:  98%|▉| 294/300 [02:19<00:02,  2.48it/s,
# Running rollout with at most 300 steps:  98%|▉| 295/300 [02:19<00:02,  1.89it/s,
# Running rollout with at most 300 steps:  98%|▉| 295/300 [02:19<00:02,  1.89it/s,
# Running rollout with at most 300 steps:  99%|▉| 296/300 [02:19<00:01,  2.48it/s,
# Running rollout with at most 300 steps:  99%|▉| 296/300 [02:20<00:01,  2.48it/s,
# Running rollout with at most 300 steps:  99%|▉| 297/300 [02:20<00:01,  1.88it/s,
# Running rollout with at most 300 steps:  99%|▉| 297/300 [02:20<00:01,  1.88it/s,
# Running rollout with at most 300 steps:  99%|▉| 298/300 [02:20<00:00,  2.45it/s,
# Running rollout with at most 300 steps:  99%|▉| 298/300 [02:21<00:00,  2.45it/s,
# Running rollout with at most 300 steps: 100%|▉| 299/300 [02:21<00:00,  1.87it/s,
# Running rollout with at most 300 steps: 100%|▉| 299/300 [02:21<00:00,  1.87it/s,
# Running rollout with at most 300 steps: 100%|█| 300/300 [02:21<00:00,  2.30it/s,
# INFO 2026-01-11 18:54:32 ot_train.py:405 Suite overall aggregated: {'avg_sum_reward': 30.0458977779501, 'avg_max_reward': 0.22567538453405914, 'pc_success': 0.0, 'n_episodes': 50, 'eval_s': 143.02978539466858, 'eval_ep_s': 2.860595712661743, 'video_paths': ['temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_0.mp4', 'temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_1.mp4', 'temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_2.mp4', 'temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_3.mp4']}
# INFO 2026-01-11 18:54:32 ot_train.py:435 End of training

# %% [markdown]
# ## Video evaluation of the training sequence

# %%
from IPython.display import HTML, display

def display_video_grid(videos, cols=2, ratio = 100):
    """
    Display videos in a grid with titles.

    Args:
        videos (list of tuples): [(filepath, title), ...]
        cols (int): number of videos per row
    """
    # CSS for grid
    style = f"""
    <style>
    .video-grid {{
      display: grid;
      grid-template-columns: repeat({cols}, 1fr);
      gap: 20px;
      margin-top: 20px;
    }}
    .video-item {{
      text-align: center;
    }}
    .video-item video {{
      width: {ratio}%;
      border-radius: 10px;
      box-shadow: 0 4px 10px rgba(0,0,0,0.2);
    }}
    .video-title {{
      margin-top: 8px;
      font-weight: bold;
      font-family: sans-serif;
    }}
    </style>
    """

    # Build video HTML
    items = ""
    for path, title in videos:
        items += f"""
        <div class="video-item">
            <video controls>
                <source src="{path}" type="video/mp4">
            </video>
            <div class="video-title">{title}</div>
        </div>
        """

    html = style + f'<div class="video-grid">{items}</div>'
    display(HTML(html))

# %%
import os
steps = ["step_025000", "step_050000", "step_100000", "step_200000"]
episodes = ["episode_0", "episode_1", "episode_2", "episode_3"]

video_list = []
for episode in episodes:
    for step in steps:
        v_fp = f"./temp/outputs/train/tdmpc_pusht/eval/videos_{step}/pusht_0/eval_{episode}.mp4"
        v_title = f"{step}_{episode}"
        video_list.append((v_fp, v_title))

print(video_list)

display_video_grid(video_list, cols=len(steps))
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# [('./temp/outputs/train/tdmpc_pusht/eval/videos_step_025000/pusht_0/eval_episode_0.mp4', 'step_025000_episode_0'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_050000/pusht_0/eval_episode_0.mp4', 'step_050000_episode_0'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_100000/pusht_0/eval_episode_0.mp4', 'step_100000_episode_0'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_0.mp4', 'step_200000_episode_0'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_025000/pusht_0/eval_episode_1.mp4', 'step_025000_episode_1'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_050000/pusht_0/eval_episode_1.mp4', 'step_050000_episode_1'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_100000/pusht_0/eval_episode_1.mp4', 'step_100000_episode_1'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_1.mp4', 'step_200000_episode_1'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_025000/pusht_0/eval_episode_2.mp4', 'step_025000_episode_2'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_050000/pusht_0/eval_episode_2.mp4', 'step_050000_episode_2'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_100000/pusht_0/eval_episode_2.mp4', 'step_100000_episode_2'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_2.mp4', 'step_200000_episode_2'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_025000/pusht_0/eval_episode_3.mp4', 'step_025000_episode_3'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_050000/pusht_0/eval_episode_3.mp4', 'step_050000_episode_3'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_100000/pusht_0/eval_episode_3.mp4', 'step_100000_episode_3'), ('./temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_3.mp4', 'step_200000_episode_3')]
#     <style>
#     .video-grid {
#       display: grid;
#       grid-template-columns: repeat(4, 1fr);
#       gap: 20px;
#       margin-top: 20px;
#     }
#     .video-item {
#       text-align: center;
#     }
#     .video-item video {
#       width: 100%;
#       border-radius: 10px;
#       box-shadow: 0 4px 10px rgba(0,0,0,0.2);
#     }
#     .video-title {
#       margin-top: 8px;
#       font-weight: bold;
#       font-family: sans-serif;
#     }
#     </style>
#     <div class="video-grid">
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_025000/pusht_0/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_025000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_050000/pusht_0/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_050000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_100000/pusht_0/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_100000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_200000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_025000/pusht_0/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_025000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_050000/pusht_0/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_050000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_100000/pusht_0/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_100000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_200000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_025000/pusht_0/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_025000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_050000/pusht_0/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_050000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_100000/pusht_0/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_100000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_200000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_025000/pusht_0/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_025000_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_050000/pusht_0/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_050000_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_100000/pusht_0/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_100000_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./temp/outputs/train/tdmpc_pusht/eval/videos_step_200000/pusht_0/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_200000_episode_3</div>
#         </div>
#         </div>
