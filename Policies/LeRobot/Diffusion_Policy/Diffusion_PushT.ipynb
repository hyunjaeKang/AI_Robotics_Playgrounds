# %% [markdown]
# # Diffusion Policy with Lerobot

# %% [markdown]
# ## Device Setup

# %%
import torch

if torch.backends.mps.is_available():
    device = "mps"
elif torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

print(f"Available device : {device}")
# Out:
# Available device : mps

# %% [markdown]
# ##  Train the diffusion policy for pushT environment

# %%
# !python -m lerobot.scripts.train --output_dir=./temp/outputs/train/diffusion_pusht \
    --policy.type=diffusion \
    --dataset.repo_id=lerobot/pusht \
    --seed=100000 \
    --env.type=pusht \
    --batch_size=64 \
    --steps=200000 \
    --eval_freq=25 \
    --save_freq=25000 \
    --policy.device=$device \
    --policy.push_to_hub=false \
    --wandb.enable=false
# Out:
# INFO 2025-09-08 18:20:55 ils/utils.py:51 Metal backend detected, using mps.
# WARNING 2025-09-08 18:20:55 /policies.py:80 Device '' is not available. Switching to 'mps'.
# INFO 2025-09-08 18:20:55 ts/train.py:111 {'batch_size': 64,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'lerobot/pusht',
#              'revision': None,
#              'root': None,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': {'episode_length': 300,
#          'features': {'action': {'shape': [2],
#                                  'type': <FeatureType.ACTION: 'ACTION'>},
#                       'agent_pos': {'shape': [2],
#                                     'type': <FeatureType.STATE: 'STATE'>},
#                       'pixels': {'shape': [384, 384, 3],
#                                  'type': <FeatureType.VISUAL: 'VISUAL'>}},
#          'features_map': {'action': 'action',
#                           'agent_pos': 'observation.state',
#                           'environment_state': 'observation.environment_state',
#                           'pixels': 'observation.image'},
#          'fps': 10,
#          'obs_type': 'pixels_agent_pos',
#          'render_mode': 'rgb_array',
#          'task': 'PushT-v0',
#          'type': 'pusht',
#          'visualization_height': 384,
#          'visualization_width': 384},
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 25000,
#  'job_name': 'pusht_diffusion',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.95, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 0.0001,
#                'type': 'adam',
#                'weight_decay': 1e-06},
#  'output_dir': 'outputs/train/diffusion_pusht',
#  'policy': {'beta_end': 0.02,
#             'beta_schedule': 'squaredcos_cap_v2',
#             'beta_start': 0.0001,
#             'clip_sample': True,
#             'clip_sample_range': 1.0,
#             'crop_is_random': True,
#             'crop_shape': [84, 84],
#             'device': 'mps',
#             'diffusion_step_embed_dim': 128,
#             'do_mask_loss_for_padding': False,
#             'down_dims': [512, 1024, 2048],
#             'drop_n_last_frames': 7,
#             'horizon': 16,
#             'input_features': {},
#             'kernel_size': 5,
#             'license': None,
#             'n_action_steps': 8,
#             'n_groups': 8,
#             'n_obs_steps': 2,
#             'noise_scheduler_type': 'DDPM',
#             'normalization_mapping': {'ACTION': <NormalizationMode.MIN_MAX: 'MIN_MAX'>,
#                                       'STATE': <NormalizationMode.MIN_MAX: 'MIN_MAX'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'num_inference_steps': None,
#             'num_train_timesteps': 100,
#             'optimizer_betas': [0.95, 0.999],
#             'optimizer_eps': 1e-08,
#             'optimizer_lr': 0.0001,
#             'optimizer_weight_decay': 1e-06,
#             'output_features': {},
#             'prediction_type': 'epsilon',
#             'pretrained_backbone_weights': None,
#             'private': None,
#             'push_to_hub': False,
#             'repo_id': None,
#             'scheduler_name': 'cosine',
#             'scheduler_warmup_steps': 500,
#             'spatial_softmax_num_keypoints': 32,
#             'tags': None,
#             'type': 'diffusion',
#             'use_amp': False,
#             'use_film_scale_modulation': True,
#             'use_group_norm': True,
#             'use_separate_rgb_encoder_per_camera': False,
#             'vision_backbone': 'resnet18'},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 25000,
#  'scheduler': {'name': 'cosine', 'num_warmup_steps': 500, 'type': 'diffuser'},
#  'seed': 100000,
#  'steps': 200000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': False,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2025-09-08 18:20:55 ts/train.py:117 Logs will be saved locally.
# INFO 2025-09-08 18:20:55 ts/train.py:127 Creating dataset
# Resolving data files: 100%|███████████████| 206/206 [00:00<00:00, 710548.21it/s]
# INFO 2025-09-08 18:20:58 ts/train.py:135 Creating env
# INFO 2025-09-08 18:20:58 ts/train.py:138 Creating policy
# INFO 2025-09-08 18:20:59 ts/train.py:144 Creating optimizer and scheduler
# INFO 2025-09-08 18:20:59 ts/train.py:156 Output dir: outputs/train/diffusion_pusht
# INFO 2025-09-08 18:20:59 ts/train.py:158 cfg.env.task='PushT-v0'
# INFO 2025-09-08 18:20:59 ts/train.py:159 cfg.steps=200000 (200K)
# INFO 2025-09-08 18:20:59 ts/train.py:160 dataset.num_frames=25650 (26K)
# INFO 2025-09-08 18:20:59 ts/train.py:161 dataset.num_episodes=206
# INFO 2025-09-08 18:20:59 ts/train.py:162 num_learnable_params=262709026 (263M)
# INFO 2025-09-08 18:20:59 ts/train.py:163 num_total_params=262709044 (263M)
# INFO 2025-09-08 18:20:59 ts/train.py:202 Start offline training on a fixed dataset
# objc[28470]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x10fc703a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12d688800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28470]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x10fc703f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12d688850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28466]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11ce003a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13fa30800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28464]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1490183a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x157744800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28468]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1228603a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1338bc800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28466]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11ce003f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13fa30850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28464]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1490183f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x157744850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28468]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1228603f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1338bc850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 18:22:38 ts/train.py:232 step:200 smpl:13K ep:103 epch:0.50 loss:0.331 grdn:5.552 lr:2.0e-05 updt_s:0.447 data_s:0.042
# objc[28572]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x126db03a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x143c6c800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28576]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12c7f03a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x14c51c800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28579]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12583c3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x136914800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28574]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x122e443a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x15e09c800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28572]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x126db03f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x143c6c850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28576]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12c7f03f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x14c51c850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28579]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12583c3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x136914850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28574]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x122e443f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x15e09c850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 18:24:21 ts/train.py:232 step:400 smpl:26K ep:206 epch:1.00 loss:0.079 grdn:2.422 lr:6.0e-05 updt_s:0.468 data_s:0.046
# INFO 2025-09-08 18:26:23 ts/train.py:232 step:600 smpl:38K ep:308 epch:1.50 loss:0.072 grdn:1.908 lr:9.5e-05 updt_s:0.606 data_s:0.001
# objc[28876]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x10c5bc3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x146934800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28874]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12bf3c3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x148278800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28876]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x10c5bc3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x146934850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28874]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12bf3c3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x148278850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28870]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1223d83a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x147ea8800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28872]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1401d83a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x169bc4800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28872]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1401d83f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x169bc4850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[28870]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1223d83f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x147ea8850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 18:29:11 ts/train.py:232 step:800 smpl:51K ep:411 epch:2.00 loss:0.061 grdn:1.347 lr:1.0e-04 updt_s:0.788 data_s:0.045
# INFO 2025-09-08 18:31:44 ts/train.py:232 step:1K smpl:64K ep:514 epch:2.50 loss:0.057 grdn:1.090 lr:1.0e-04 updt_s:0.763 data_s:0.001
# objc[29082]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x125cd83a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x136280800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29080]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11f63c3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13cda0800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29082]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x125cd83f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x136280850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29080]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11f63c3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13cda0850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29078]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x134dec3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x144990800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29084]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x119f243a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12b22c800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29078]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x134dec3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x144990850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29084]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x119f243f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12b22c850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 18:34:10 ts/train.py:232 step:1K smpl:77K ep:617 epch:2.99 loss:0.055 grdn:0.968 lr:1.0e-04 updt_s:0.678 data_s:0.045
# INFO 2025-09-08 18:36:28 ts/train.py:232 step:1K smpl:90K ep:720 epch:3.49 loss:0.053 grdn:0.934 lr:1.0e-04 updt_s:0.688 data_s:0.001
# objc[29279]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11b0e03a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x14ae74800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29279]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11b0e03f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x14ae74850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29283]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1238803a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1567d8800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29286]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11bd1c3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12ad2c800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29281]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1248203a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x144128800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29283]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1238803f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1567d8850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29286]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11bd1c3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12ad2c850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29281]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1248203f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x144128850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 18:38:51 ts/train.py:232 step:2K smpl:102K ep:822 epch:3.99 loss:0.051 grdn:0.904 lr:1.0e-04 updt_s:0.665 data_s:0.045
# INFO 2025-09-08 18:41:09 ts/train.py:232 step:2K smpl:115K ep:925 epch:4.49 loss:0.051 grdn:0.946 lr:1.0e-04 updt_s:0.687 data_s:0.001
# objc[29567]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x10ed683a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13b298800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29565]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11fbe43a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1407bc800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29572]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12ddcc3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13ee6c800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29567]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x10ed683f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13b298850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29565]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11fbe43f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1407bc850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29572]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12ddcc3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13ee6c850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29599]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11deac3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13c42c800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29599]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11deac3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13c42c850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 18:43:42 ts/train.py:232 step:2K smpl:128K ep:1K epch:4.99 loss:0.048 grdn:0.794 lr:1.0e-04 updt_s:0.713 data_s:0.048
# INFO 2025-09-08 18:46:01 ts/train.py:232 step:2K smpl:141K ep:1K epch:5.49 loss:0.049 grdn:0.799 lr:1.0e-04 updt_s:0.691 data_s:0.001
# objc[29828]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11fd003a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13d7e8800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29834]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x139a703a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x159670800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29832]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1248b83a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x135a9c800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29830]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12417c3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13738c800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29834]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x139a703f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x159670850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29828]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11fd003f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13d7e8850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29830]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12417c3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13738c850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[29832]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1248b83f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x135a9c850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 18:48:24 ts/train.py:232 step:2K smpl:154K ep:1K epch:5.99 loss:0.048 grdn:0.815 lr:1.0e-04 updt_s:0.664 data_s:0.045
# INFO 2025-09-08 18:50:42 ts/train.py:232 step:3K smpl:166K ep:1K epch:6.49 loss:0.047 grdn:0.764 lr:1.0e-04 updt_s:0.684 data_s:0.001
# objc[30069]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11d4283a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x139814800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30073]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1272a03a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x156884800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30064]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x139a083a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x16b4f0800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30069]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11d4283f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x139814850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30067]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x120ed83a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12fe68800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30073]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1272a03f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x156884850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30064]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x139a083f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x16b4f0850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30067]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x120ed83f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12fe68850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 18:53:04 ts/train.py:232 step:3K smpl:179K ep:1K epch:6.99 loss:0.044 grdn:0.727 lr:1.0e-04 updt_s:0.662 data_s:0.045
# INFO 2025-09-08 18:55:21 ts/train.py:232 step:3K smpl:192K ep:2K epch:7.49 loss:0.046 grdn:0.733 lr:1.0e-04 updt_s:0.681 data_s:0.001
# objc[30292]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x10d5ec3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12957c800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30292]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x10d5ec3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12957c850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30298]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1377a03a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13fbec800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30289]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x15826c3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x16672c800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30294]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1242c03a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x144c04800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30298]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1377a03f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13fbec850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30289]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x15826c3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x16672c850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30294]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1242c03f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x144c04850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 18:57:46 ts/train.py:232 step:3K smpl:205K ep:2K epch:7.98 loss:0.043 grdn:0.672 lr:1.0e-04 updt_s:0.673 data_s:0.045
# INFO 2025-09-08 19:00:06 ts/train.py:232 step:3K smpl:218K ep:2K epch:8.48 loss:0.043 grdn:0.673 lr:1.0e-04 updt_s:0.699 data_s:0.001
# objc[30504]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x148e6c3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1574cc800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30508]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x125d803a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1367bc800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30502]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x127e703a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x146008800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30506]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1445143a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1667c0800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30504]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x148e6c3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1574cc850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30508]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x125d803f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1367bc850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30502]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x127e703f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x146008850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30506]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1445143f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1667c0850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 19:02:30 ts/train.py:232 step:4K smpl:230K ep:2K epch:8.98 loss:0.044 grdn:0.646 lr:1.0e-04 updt_s:0.671 data_s:0.045
# objc[30813]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11af943a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x15bb58800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30809]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12faac3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x148970800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30813]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11af943f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x15bb58850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30809]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12faac3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x148970850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30807]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1187ec3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x138a68800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30811]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1221503a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x149ae0800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30807]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1187ec3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x138a68850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[30811]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1221503f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x149ae0850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 19:04:56 ts/train.py:232 step:4K smpl:243K ep:2K epch:9.48 loss:0.043 grdn:0.681 lr:1.0e-04 updt_s:0.681 data_s:0.045
# INFO 2025-09-08 19:07:14 ts/train.py:232 step:4K smpl:256K ep:2K epch:9.98 loss:0.042 grdn:0.666 lr:1.0e-04 updt_s:0.682 data_s:0.001
# objc[31023]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x126c503a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x160cc8800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[31023]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x126c503f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x160cc8850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[31021]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11caa43a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13aaf4800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[31027]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1252cc3a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x15f4d4800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[31025]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12c7383a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13e300800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[31021]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11caa43f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13aaf4850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[31025]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12c7383f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x13e300850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[31027]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1252cc3f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x15f4d4850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-08 19:09:36 ts/train.py:232 step:4K smpl:269K ep:2K epch:10.48 loss:0.041 grdn:0.595 lr:1.0e-04 updt_s:0.660 data_s:0.047
# INFO 2025-09-08 19:11:52 ts/train.py:232 step:4K smpl:282K ep:2K epch:10.98 loss:0.042 grdn:0.603 lr:1.0e-04 updt_s:0.673 data_s:0.001
# objc[31235]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x12f6003a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x14f514800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[31239]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x113b443a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x131e40800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# ...
# Running rollout with at most 300 steps:  67%|▋| 201/300 [05:08<05:19,  3.23s/it,
# Running rollout with at most 300 steps:  67%|▋| 201/300 [05:08<05:19,  3.23s/it,
# Running rollout with at most 300 steps:  67%|▋| 202/300 [05:08<03:53,  2.38s/it,
# Running rollout with at most 300 steps:  67%|▋| 202/300 [05:08<03:53,  2.38s/it,
# Running rollout with at most 300 steps:  68%|▋| 203/300 [05:08<03:51,  2.38s/it,
# Running rollout with at most 300 steps:  68%|▋| 204/300 [05:08<02:13,  1.39s/it,
# Running rollout with at most 300 steps:  68%|▋| 204/300 [05:08<02:13,  1.39s/it,
# Running rollout with at most 300 steps:  68%|▋| 205/300 [05:08<01:43,  1.08s/it,
# Running rollout with at most 300 steps:  68%|▋| 205/300 [05:08<01:43,  1.08s/it,
# Running rollout with at most 300 steps:  69%|▋| 206/300 [05:08<01:18,  1.19it/s,
# Running rollout with at most 300 steps:  69%|▋| 206/300 [05:08<01:18,  1.19it/s,
# Running rollout with at most 300 steps:  69%|▋| 207/300 [05:08<01:00,  1.54it/s,
# Running rollout with at most 300 steps:  69%|▋| 207/300 [05:09<01:00,  1.54it/s,
# Running rollout with at most 300 steps:  69%|▋| 208/300 [05:09<00:47,  1.96it/s,
# Running rollout with at most 300 steps:  69%|▋| 208/300 [05:20<00:47,  1.96it/s,
# Running rollout with at most 300 steps:  70%|▋| 209/300 [05:20<05:17,  3.49s/it,
# Running rollout with at most 300 steps:  70%|▋| 209/300 [05:20<05:17,  3.49s/it,
# Running rollout with at most 300 steps:  70%|▋| 210/300 [05:20<03:46,  2.52s/it,
# Running rollout with at most 300 steps:  70%|▋| 210/300 [05:20<03:46,  2.52s/it,
# Running rollout with at most 300 steps:  70%|▋| 211/300 [05:20<03:44,  2.52s/it,
# Running rollout with at most 300 steps:  71%|▋| 212/300 [05:20<02:06,  1.44s/it,
# Running rollout with at most 300 steps:  71%|▋| 212/300 [05:20<02:06,  1.44s/it,
# Running rollout with at most 300 steps:  71%|▋| 213/300 [05:20<01:37,  1.12s/it,
# Running rollout with at most 300 steps:  71%|▋| 213/300 [05:20<01:37,  1.12s/it,
# Running rollout with at most 300 steps:  71%|▋| 214/300 [05:20<01:35,  1.12s/it,
# Running rollout with at most 300 steps:  72%|▋| 215/300 [05:20<00:59,  1.43it/s,
# Running rollout with at most 300 steps:  72%|▋| 215/300 [05:20<00:59,  1.43it/s,
# Running rollout with at most 300 steps:  72%|▋| 216/300 [05:20<00:47,  1.76it/s,
# Running rollout with at most 300 steps:  72%|▋| 216/300 [05:31<00:47,  1.76it/s,
# Running rollout with at most 300 steps:  72%|▋| 217/300 [05:31<04:19,  3.13s/it,
# Running rollout with at most 300 steps:  72%|▋| 217/300 [05:31<04:19,  3.13s/it,
# Running rollout with at most 300 steps:  73%|▋| 218/300 [05:31<03:12,  2.35s/it,
# Running rollout with at most 300 steps:  73%|▋| 218/300 [05:32<03:12,  2.35s/it,
# Running rollout with at most 300 steps:  73%|▋| 219/300 [05:32<02:21,  1.74s/it,
# Running rollout with at most 300 steps:  73%|▋| 219/300 [05:32<02:21,  1.74s/it,
# Running rollout with at most 300 steps:  73%|▋| 220/300 [05:32<01:42,  1.29s/it,
# Running rollout with at most 300 steps:  73%|▋| 220/300 [05:32<01:42,  1.29s/it,
# Running rollout with at most 300 steps:  74%|▋| 221/300 [05:32<01:15,  1.05it/s,
# Running rollout with at most 300 steps:  74%|▋| 221/300 [05:32<01:15,  1.05it/s,
# Running rollout with at most 300 steps:  74%|▋| 222/300 [05:32<00:55,  1.39it/s,
# Running rollout with at most 300 steps:  74%|▋| 222/300 [05:32<00:55,  1.39it/s,
# Running rollout with at most 300 steps:  74%|▋| 223/300 [05:32<00:55,  1.39it/s,
# Running rollout with at most 300 steps:  75%|▋| 224/300 [05:32<00:33,  2.27it/s,
# Running rollout with at most 300 steps:  75%|▋| 224/300 [05:43<00:33,  2.27it/s,
# Running rollout with at most 300 steps:  75%|▊| 225/300 [05:43<03:47,  3.03s/it,
# Running rollout with at most 300 steps:  75%|▊| 225/300 [05:43<03:47,  3.03s/it,
# Running rollout with at most 300 steps:  75%|▊| 226/300 [05:43<02:48,  2.28s/it,
# Running rollout with at most 300 steps:  75%|▊| 226/300 [05:43<02:48,  2.28s/it,
# Running rollout with at most 300 steps:  76%|▊| 227/300 [05:43<02:03,  1.69s/it,
# Running rollout with at most 300 steps:  76%|▊| 227/300 [05:44<02:03,  1.69s/it,
# Running rollout with at most 300 steps:  76%|▊| 228/300 [05:44<01:30,  1.25s/it,
# Running rollout with at most 300 steps:  76%|▊| 228/300 [05:44<01:30,  1.25s/it,
# Running rollout with at most 300 steps:  76%|▊| 229/300 [05:44<01:05,  1.08it/s,
# Running rollout with at most 300 steps:  76%|▊| 229/300 [05:44<01:05,  1.08it/s,
# Running rollout with at most 300 steps:  77%|▊| 230/300 [05:44<00:48,  1.43it/s,
# Running rollout with at most 300 steps:  77%|▊| 230/300 [05:44<00:48,  1.43it/s,
# Running rollout with at most 300 steps:  77%|▊| 231/300 [05:44<00:36,  1.91it/s,
# Running rollout with at most 300 steps:  77%|▊| 231/300 [05:44<00:36,  1.91it/s,
# Running rollout with at most 300 steps:  77%|▊| 232/300 [05:44<00:27,  2.44it/s,
# Running rollout with at most 300 steps:  77%|▊| 232/300 [05:55<00:27,  2.44it/s,
# Running rollout with at most 300 steps:  78%|▊| 233/300 [05:55<03:57,  3.55s/it,
# Running rollout with at most 300 steps:  78%|▊| 233/300 [05:55<03:57,  3.55s/it,
# Running rollout with at most 300 steps:  78%|▊| 234/300 [05:55<02:47,  2.53s/it,
# Running rollout with at most 300 steps:  78%|▊| 234/300 [05:55<02:47,  2.53s/it,
# Running rollout with at most 300 steps:  78%|▊| 235/300 [05:55<01:57,  1.81s/it,
# Running rollout with at most 300 steps:  78%|▊| 235/300 [05:55<01:57,  1.81s/it,
# Running rollout with at most 300 steps:  79%|▊| 236/300 [05:55<01:23,  1.31s/it,
# Running rollout with at most 300 steps:  79%|▊| 236/300 [05:56<01:23,  1.31s/it,
# Running rollout with at most 300 steps:  79%|▊| 237/300 [05:56<00:59,  1.05it/s,
# Running rollout with at most 300 steps:  79%|▊| 237/300 [05:56<00:59,  1.05it/s,
# Running rollout with at most 300 steps:  79%|▊| 238/300 [05:56<00:43,  1.43it/s,
# Running rollout with at most 300 steps:  79%|▊| 238/300 [05:56<00:43,  1.43it/s,
# Running rollout with at most 300 steps:  80%|▊| 239/300 [05:56<00:32,  1.90it/s,
# Running rollout with at most 300 steps:  80%|▊| 239/300 [05:56<00:32,  1.90it/s,
# Running rollout with at most 300 steps:  80%|▊| 240/300 [05:56<00:24,  2.49it/s,
# Running rollout with at most 300 steps:  80%|▊| 240/300 [06:07<00:24,  2.49it/s,
# Running rollout with at most 300 steps:  80%|▊| 241/300 [06:07<03:30,  3.57s/it,
# Running rollout with at most 300 steps:  80%|▊| 241/300 [06:07<03:30,  3.57s/it,
# Running rollout with at most 300 steps:  81%|▊| 242/300 [06:07<02:26,  2.53s/it,
# Running rollout with at most 300 steps:  81%|▊| 242/300 [06:07<02:26,  2.53s/it,
# Running rollout with at most 300 steps:  81%|▊| 243/300 [06:07<01:43,  1.81s/it,
# Running rollout with at most 300 steps:  81%|▊| 243/300 [06:07<01:43,  1.81s/it,
# Running rollout with at most 300 steps:  81%|▊| 244/300 [06:07<01:13,  1.30s/it,
# Running rollout with at most 300 steps:  81%|▊| 244/300 [06:07<01:13,  1.30s/it,
# Running rollout with at most 300 steps:  82%|▊| 245/300 [06:07<00:52,  1.06it/s,
# Running rollout with at most 300 steps:  82%|▊| 245/300 [06:07<00:52,  1.06it/s,
# Running rollout with at most 300 steps:  82%|▊| 246/300 [06:07<00:38,  1.42it/s,
# Running rollout with at most 300 steps:  82%|▊| 246/300 [06:08<00:38,  1.42it/s,
# Running rollout with at most 300 steps:  82%|▊| 247/300 [06:08<00:27,  1.90it/s,
# Running rollout with at most 300 steps:  82%|▊| 247/300 [06:08<00:27,  1.90it/s,
# Running rollout with at most 300 steps:  83%|▊| 248/300 [06:08<00:20,  2.49it/s,
# Running rollout with at most 300 steps:  83%|▊| 248/300 [06:19<00:20,  2.49it/s,
# Running rollout with at most 300 steps:  83%|▊| 249/300 [06:19<03:03,  3.59s/it,
# Running rollout with at most 300 steps:  83%|▊| 249/300 [06:19<03:03,  3.59s/it,
# Running rollout with at most 300 steps:  83%|▊| 250/300 [06:19<02:07,  2.55s/it,
# Running rollout with at most 300 steps:  83%|▊| 250/300 [06:19<02:07,  2.55s/it,
# Running rollout with at most 300 steps:  84%|▊| 251/300 [06:19<01:29,  1.82s/it,
# Running rollout with at most 300 steps:  84%|▊| 251/300 [06:19<01:29,  1.82s/it,
# Running rollout with at most 300 steps:  84%|▊| 252/300 [06:19<01:03,  1.31s/it,
# Running rollout with at most 300 steps:  84%|▊| 252/300 [06:19<01:03,  1.31s/it,
# Running rollout with at most 300 steps:  84%|▊| 253/300 [06:19<00:44,  1.05it/s,
# Running rollout with at most 300 steps:  84%|▊| 253/300 [06:19<00:44,  1.05it/s,
# Running rollout with at most 300 steps:  85%|▊| 254/300 [06:19<00:32,  1.42it/s,
# Running rollout with at most 300 steps:  85%|▊| 254/300 [06:19<00:32,  1.42it/s,
# Running rollout with at most 300 steps:  85%|▊| 255/300 [06:19<00:23,  1.89it/s,
# Running rollout with at most 300 steps:  85%|▊| 255/300 [06:20<00:23,  1.89it/s,
# Running rollout with at most 300 steps:  85%|▊| 256/300 [06:20<00:17,  2.45it/s,
# Running rollout with at most 300 steps:  85%|▊| 256/300 [06:31<00:17,  2.45it/s,
# Running rollout with at most 300 steps:  86%|▊| 257/300 [06:31<02:34,  3.59s/it,
# Running rollout with at most 300 steps:  86%|▊| 257/300 [06:31<02:34,  3.59s/it,
# Running rollout with at most 300 steps:  86%|▊| 258/300 [06:31<01:47,  2.55s/it,
# Running rollout with at most 300 steps:  86%|▊| 258/300 [06:31<01:47,  2.55s/it,
# Running rollout with at most 300 steps:  86%|▊| 259/300 [06:31<01:14,  1.82s/it,
# Running rollout with at most 300 steps:  86%|▊| 259/300 [06:31<01:14,  1.82s/it,
# Running rollout with at most 300 steps:  87%|▊| 260/300 [06:31<00:52,  1.31s/it,
# Running rollout with at most 300 steps:  87%|▊| 260/300 [06:31<00:52,  1.31s/it,
# Running rollout with at most 300 steps:  87%|▊| 261/300 [06:31<00:37,  1.05it/s,
# Running rollout with at most 300 steps:  87%|▊| 261/300 [06:31<00:37,  1.05it/s,
# Running rollout with at most 300 steps:  87%|▊| 262/300 [06:31<00:26,  1.42it/s,
# Running rollout with at most 300 steps:  87%|▊| 262/300 [06:31<00:26,  1.42it/s,
# Running rollout with at most 300 steps:  88%|▉| 263/300 [06:31<00:19,  1.90it/s,
# Running rollout with at most 300 steps:  88%|▉| 263/300 [06:31<00:19,  1.90it/s,
# Running rollout with at most 300 steps:  88%|▉| 264/300 [06:31<00:14,  2.48it/s,
# Running rollout with at most 300 steps:  88%|▉| 264/300 [06:42<00:14,  2.48it/s,
# Running rollout with at most 300 steps:  88%|▉| 265/300 [06:42<02:05,  3.58s/it,
# Running rollout with at most 300 steps:  88%|▉| 265/300 [06:42<02:05,  3.58s/it,
# Running rollout with at most 300 steps:  89%|▉| 266/300 [06:42<01:26,  2.54s/it,
# Running rollout with at most 300 steps:  89%|▉| 266/300 [06:43<01:26,  2.54s/it,
# Running rollout with at most 300 steps:  89%|▉| 267/300 [06:43<00:59,  1.81s/it,
# Running rollout with at most 300 steps:  89%|▉| 267/300 [06:43<00:59,  1.81s/it,
# Running rollout with at most 300 steps:  89%|▉| 268/300 [06:43<00:41,  1.30s/it,
# Running rollout with at most 300 steps:  89%|▉| 268/300 [06:43<00:41,  1.30s/it,
# Running rollout with at most 300 steps:  90%|▉| 269/300 [06:43<00:29,  1.06it/s,
# Running rollout with at most 300 steps:  90%|▉| 269/300 [06:43<00:29,  1.06it/s,
# Running rollout with at most 300 steps:  90%|▉| 270/300 [06:43<00:20,  1.43it/s,
# Running rollout with at most 300 steps:  90%|▉| 270/300 [06:43<00:20,  1.43it/s,
# Running rollout with at most 300 steps:  90%|▉| 271/300 [06:43<00:15,  1.92it/s,
# Running rollout with at most 300 steps:  90%|▉| 271/300 [06:43<00:15,  1.92it/s,
# Running rollout with at most 300 steps:  91%|▉| 272/300 [06:43<00:11,  2.47it/s,
# Running rollout with at most 300 steps:  91%|▉| 272/300 [06:54<00:11,  2.47it/s,
# Running rollout with at most 300 steps:  91%|▉| 273/300 [06:54<01:37,  3.59s/it,
# Running rollout with at most 300 steps:  91%|▉| 273/300 [06:54<01:37,  3.59s/it,
# Running rollout with at most 300 steps:  91%|▉| 274/300 [06:54<01:06,  2.55s/it,
# Running rollout with at most 300 steps:  91%|▉| 274/300 [06:54<01:06,  2.55s/it,
# Running rollout with at most 300 steps:  92%|▉| 275/300 [06:54<00:45,  1.82s/it,
# Running rollout with at most 300 steps:  92%|▉| 275/300 [06:55<00:45,  1.82s/it,
# Running rollout with at most 300 steps:  92%|▉| 276/300 [06:55<00:31,  1.31s/it,
# Running rollout with at most 300 steps:  92%|▉| 276/300 [06:55<00:31,  1.31s/it,
# Running rollout with at most 300 steps:  92%|▉| 277/300 [06:55<00:21,  1.06it/s,
# Running rollout with at most 300 steps:  92%|▉| 277/300 [06:55<00:21,  1.06it/s,
# Running rollout with at most 300 steps:  93%|▉| 278/300 [06:55<00:15,  1.43it/s,
# Running rollout with at most 300 steps:  93%|▉| 278/300 [06:55<00:15,  1.43it/s,
# Running rollout with at most 300 steps:  93%|▉| 279/300 [06:55<00:10,  1.91it/s,
# Running rollout with at most 300 steps:  93%|▉| 279/300 [06:55<00:10,  1.91it/s,
# Running rollout with at most 300 steps:  93%|▉| 280/300 [06:55<00:08,  2.49it/s,
# Running rollout with at most 300 steps:  93%|▉| 280/300 [07:06<00:08,  2.49it/s,
# Running rollout with at most 300 steps:  94%|▉| 281/300 [07:06<01:08,  3.60s/it,
# Running rollout with at most 300 steps:  94%|▉| 281/300 [07:06<01:08,  3.60s/it,
# Running rollout with at most 300 steps:  94%|▉| 282/300 [07:06<00:46,  2.56s/it,
# Running rollout with at most 300 steps:  94%|▉| 282/300 [07:06<00:46,  2.56s/it,
# Running rollout with at most 300 steps:  94%|▉| 283/300 [07:06<00:30,  1.82s/it,
# Running rollout with at most 300 steps:  94%|▉| 283/300 [07:06<00:30,  1.82s/it,
# Running rollout with at most 300 steps:  95%|▉| 284/300 [07:06<00:20,  1.31s/it,
# Running rollout with at most 300 steps:  95%|▉| 284/300 [07:07<00:20,  1.31s/it,
# Running rollout with at most 300 steps:  95%|▉| 285/300 [07:07<00:14,  1.05it/s,
# Running rollout with at most 300 steps:  95%|▉| 285/300 [07:07<00:14,  1.05it/s,
# Running rollout with at most 300 steps:  95%|▉| 286/300 [07:07<00:09,  1.42it/s,
# Running rollout with at most 300 steps:  95%|▉| 286/300 [07:07<00:09,  1.42it/s,
# Running rollout with at most 300 steps:  96%|▉| 287/300 [07:07<00:06,  1.86it/s,
# Running rollout with at most 300 steps:  96%|▉| 287/300 [07:07<00:06,  1.86it/s,
# Running rollout with at most 300 steps:  96%|▉| 288/300 [07:18<00:06,  1.86it/s,
# Running rollout with at most 300 steps:  96%|▉| 289/300 [07:18<00:31,  2.87s/it,
# Running rollout with at most 300 steps:  96%|▉| 289/300 [07:18<00:31,  2.87s/it,
# Running rollout with at most 300 steps:  97%|▉| 290/300 [07:18<00:21,  2.19s/it,
# Running rollout with at most 300 steps:  97%|▉| 290/300 [07:18<00:21,  2.19s/it,
# Running rollout with at most 300 steps:  97%|▉| 291/300 [07:18<00:14,  1.64s/it,
# Running rollout with at most 300 steps:  97%|▉| 291/300 [07:18<00:14,  1.64s/it,
# Running rollout with at most 300 steps:  97%|▉| 292/300 [07:18<00:09,  1.23s/it,
# Running rollout with at most 300 steps:  97%|▉| 292/300 [07:18<00:09,  1.23s/it,
# Running rollout with at most 300 steps:  98%|▉| 293/300 [07:18<00:06,  1.09it/s,
# Running rollout with at most 300 steps:  98%|▉| 293/300 [07:19<00:06,  1.09it/s,
# Running rollout with at most 300 steps:  98%|▉| 294/300 [07:19<00:04,  1.46it/s,
# Running rollout with at most 300 steps:  98%|▉| 294/300 [07:19<00:04,  1.46it/s,
# Running rollout with at most 300 steps:  98%|▉| 295/300 [07:19<00:02,  1.91it/s,
# Running rollout with at most 300 steps:  98%|▉| 295/300 [07:19<00:02,  1.91it/s,
# Running rollout with at most 300 steps:  99%|▉| 296/300 [07:19<00:01,  2.46it/s,
# Running rollout with at most 300 steps:  99%|▉| 296/300 [07:30<00:01,  2.46it/s,
# Running rollout with at most 300 steps:  99%|▉| 297/300 [07:30<00:10,  3.57s/it,
# Running rollout with at most 300 steps:  99%|▉| 297/300 [07:30<00:10,  3.57s/it,
# Running rollout with at most 300 steps:  99%|▉| 298/300 [07:30<00:05,  2.55s/it,
# Running rollout with at most 300 steps:  99%|▉| 298/300 [07:30<00:05,  2.55s/it,
# Running rollout with at most 300 steps: 100%|▉| 299/300 [07:30<00:01,  1.82s/it,
# Running rollout with at most 300 steps: 100%|▉| 299/300 [07:30<00:01,  1.82s/it,
# Running rollout with at most 300 steps: 100%|█| 300/300 [07:30<00:00,  1.33s/it,
# Stepping through eval batches: 100%|█| 1/1 [07:31<00:00, 451.17s/it, running_suc
# INFO 2025-09-10 03:50:44 ts/train.py:275 step:200K smpl:13M ep:103K epch:499.03 ∑rwrd:96.419 success:70.0 eval_s:451.531
# INFO 2025-09-10 03:50:44 ts/train.py:283 End of training

# %% [markdown]
# ### Resume the training

# %%
# !python -m lerobot.scripts.train \
    --config_path=./temp/outputs/train/diffusion_pusht_small/checkpoints/last/pretrained_model/train_config.json \
    --resume=true
# Out:
# INFO 2025-09-11 09:07:40 ts/train.py:111 {'batch_size': 64,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'lerobot/pusht',
#              'revision': None,
#              'root': None,
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': {'episode_length': 300,
#          'features': {'action': {'shape': [2],
#                                  'type': <FeatureType.ACTION: 'ACTION'>},
#                       'agent_pos': {'shape': [2],
#                                     'type': <FeatureType.STATE: 'STATE'>},
#                       'pixels': {'shape': [384, 384, 3],
#                                  'type': <FeatureType.VISUAL: 'VISUAL'>}},
#          'features_map': {'action': 'action',
#                           'agent_pos': 'observation.state',
#                           'environment_state': 'observation.environment_state',
#                           'pixels': 'observation.image'},
#          'fps': 10,
#          'obs_type': 'pixels_agent_pos',
#          'render_mode': 'rgb_array',
#          'task': 'PushT-v0',
#          'type': 'pusht',
#          'visualization_height': 384,
#          'visualization_width': 384},
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 2500,
#  'job_name': 'pusht_diffusion',
#  'log_freq': 10000,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.95, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 0.0001,
#                'type': 'adam',
#                'weight_decay': 1e-06},
#  'output_dir': 'temp/outputs/train/diffusion_pusht_small',
#  'policy': {'beta_end': 0.02,
#             'beta_schedule': 'squaredcos_cap_v2',
#             'beta_start': 0.0001,
#             'clip_sample': True,
#             'clip_sample_range': 1.0,
#             'crop_is_random': True,
#             'crop_shape': [84, 84],
#             'device': 'mps',
#             'diffusion_step_embed_dim': 128,
#             'do_mask_loss_for_padding': False,
#             'down_dims': [512, 1024, 2048],
#             'drop_n_last_frames': 7,
#             'horizon': 16,
#             'input_features': {'observation.image': {'shape': [3, 96, 96],
#                                                      'type': <FeatureType.VISUAL: 'VISUAL'>},
#                                'observation.state': {'shape': [2],
#                                                      'type': <FeatureType.STATE: 'STATE'>}},
#             'kernel_size': 5,
#             'license': None,
#             'n_action_steps': 8,
#             'n_groups': 8,
#             'n_obs_steps': 2,
#             'noise_scheduler_type': 'DDPM',
#             'normalization_mapping': {'ACTION': <NormalizationMode.MIN_MAX: 'MIN_MAX'>,
#                                       'STATE': <NormalizationMode.MIN_MAX: 'MIN_MAX'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'num_inference_steps': None,
#             'num_train_timesteps': 100,
#             'optimizer_betas': [0.95, 0.999],
#             'optimizer_eps': 1e-08,
#             'optimizer_lr': 0.0001,
#             'optimizer_weight_decay': 1e-06,
#             'output_features': {'action': {'shape': [2],
#                                            'type': <FeatureType.ACTION: 'ACTION'>}},
#             'prediction_type': 'epsilon',
#             'pretrained_backbone_weights': None,
#             'private': None,
#             'push_to_hub': False,
#             'repo_id': None,
#             'scheduler_name': 'cosine',
#             'scheduler_warmup_steps': 500,
#             'spatial_softmax_num_keypoints': 32,
#             'tags': None,
#             'type': 'diffusion',
#             'use_amp': False,
#             'use_film_scale_modulation': True,
#             'use_group_norm': True,
#             'use_separate_rgb_encoder_per_camera': False,
#             'vision_backbone': 'resnet18'},
#  'resume': True,
#  'save_checkpoint': True,
#  'save_freq': 25,
#  'scheduler': {'name': 'cosine', 'num_warmup_steps': 500, 'type': 'diffuser'},
#  'seed': 100000,
#  'steps': 50000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': False,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2025-09-11 09:07:40 ts/train.py:117 Logs will be saved locally.
# INFO 2025-09-11 09:07:40 ts/train.py:127 Creating dataset
# Resolving data files: 100%|███████████████| 206/206 [00:00<00:00, 103155.04it/s]
# INFO 2025-09-11 09:07:41 ts/train.py:135 Creating env
# INFO 2025-09-11 09:07:41 ts/train.py:138 Creating policy
# Loading weights from local directory
# INFO 2025-09-11 09:07:43 ts/train.py:144 Creating optimizer and scheduler
# INFO 2025-09-11 09:07:44 ts/train.py:156 Output dir: temp/outputs/train/diffusion_pusht_small
# INFO 2025-09-11 09:07:44 ts/train.py:158 cfg.env.task='PushT-v0'
# INFO 2025-09-11 09:07:44 ts/train.py:159 cfg.steps=50000 (50K)
# INFO 2025-09-11 09:07:44 ts/train.py:160 dataset.num_frames=25650 (26K)
# INFO 2025-09-11 09:07:44 ts/train.py:161 dataset.num_episodes=206
# INFO 2025-09-11 09:07:44 ts/train.py:162 num_learnable_params=262709026 (263M)
# INFO 2025-09-11 09:07:44 ts/train.py:163 num_total_params=262709044 (263M)
# INFO 2025-09-11 09:07:44 ts/train.py:202 Start offline training on a fixed dataset
# objc[65759]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11b8f03a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x166d48800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[65765]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x123d743a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1476b0800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[65763]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x10f4e03a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12e6ac800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[65761]: Class AVFFrameReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1123183a8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12fb00800). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[65765]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x123d743f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x1476b0850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[65759]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x11b8f03f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x166d48850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[65763]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x10f4e03f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12e6ac850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[65761]: Class AVFAudioReceiver is implemented in both /Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/av/.dylibs/libavdevice.61.3.100.dylib (0x1123183f8) and /Users/hyunjae.k/anaconda3/envs/lerobot/lib/libavdevice.60.3.100.dylib (0x12fb00850). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# INFO 2025-09-11 09:08:08 ts/train.py:241 Checkpoint policy after step 4700
# INFO 2025-09-11 09:08:21 ts/train.py:241 Checkpoint policy after step 4725
# INFO 2025-09-11 09:08:33 ts/train.py:241 Checkpoint policy after step 4750
# INFO 2025-09-11 09:08:46 ts/train.py:241 Checkpoint policy after step 4775
# INFO 2025-09-11 09:08:59 ts/train.py:241 Checkpoint policy after step 4800
# INFO 2025-09-11 09:09:12 ts/train.py:241 Checkpoint policy after step 4825
# INFO 2025-09-11 09:09:25 ts/train.py:241 Checkpoint policy after step 4850
# INFO 2025-09-11 09:09:38 ts/train.py:241 Checkpoint policy after step 4875
# ^C
#   File "/Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/torch/amp/grad_scaler.py", line 384, in step
#     return optimizer.step(*args, **kwargs)
#   File "/Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/torch/optim/lr_scheduler.py", line 124, in wrapper
#     return func.__get__(opt, opt.__class__)(*args, **kwargs)
#   File "/Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/torch/optim/optimizer.py", line 485, in wrapper
#     out = func(*args, **kwargs)
#   File "/Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/torch/optim/optimizer.py", line 79, in _use_grad
#     ret = func(self, *args, **kwargs)
#   File "/Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/torch/optim/adam.py", line 246, in step
#     adam(
#   File "/Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/torch/optim/optimizer.py", line 147, in maybe_fallback
#     return func(*args, **kwargs)
#   File "/Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/torch/optim/adam.py", line 933, in adam
#     func(
#   File "/Users/hyunjae.k/anaconda3/envs/lerobot/lib/python3.10/site-packages/torch/optim/adam.py", line 527, in _single_tensor_adam
#     param.addcdiv_(exp_avg, denom, value=-step_size)
# KeyboardInterrupt
# libc++abi: terminating due to uncaught exception of type std::__1::system_error: Broken pipe

# %% [markdown]
# ## Video evaluation of the training sequence

# %%
from IPython.display import HTML, display

def display_video_grid(videos, cols=2, ratio = 100):
    """
    Display videos in a grid with titles.

    Args:
        videos (list of tuples): [(filepath, title), ...]
        cols (int): number of videos per row
    """
    # CSS for grid
    style = f"""
    <style>
    .video-grid {{
      display: grid;
      grid-template-columns: repeat({cols}, 1fr);
      gap: 20px;
      margin-top: 20px;
    }}
    .video-item {{
      text-align: center;
    }}
    .video-item video {{
      width: {ratio}%;
      border-radius: 10px;
      box-shadow: 0 4px 10px rgba(0,0,0,0.2);
    }}
    .video-title {{
      margin-top: 8px;
      font-weight: bold;
      font-family: sans-serif;
    }}
    </style>
    """

    # Build video HTML
    items = ""
    for path, title in videos:
        items += f"""
        <div class="video-item">
            <video controls>
                <source src="{path}" type="video/mp4">
            </video>
            <div class="video-title">{title}</div>
        </div>
        """

    html = style + f'<div class="video-grid">{items}</div>'
    display(HTML(html))

# %%
steps = ["step_000025", "step_002500", "step_025000", "step_050000", "step_100000", "step_200000"]
episodes = ["episode_0", "episode_1", "episode_2", "episode_3"]

video_list = []
for episode in episodes:
    for step in steps:
        v_fp = f"./output/train_videos_pusht/videos_{step}/eval_{episode}.mp4"
        v_title = f"{step}_{episode}"
        video_list.append((v_fp, v_title))

print(video_list)

display_video_grid(video_list, cols=len(steps))
# Out:
# [('./output/train_videos_pusht/videos_step_000025/eval_episode_0.mp4', 'step_000025_episode_0'), ('./output/train_videos_pusht/videos_step_002500/eval_episode_0.mp4', 'step_002500_episode_0'), ('./output/train_videos_pusht/videos_step_025000/eval_episode_0.mp4', 'step_025000_episode_0'), ('./output/train_videos_pusht/videos_step_050000/eval_episode_0.mp4', 'step_050000_episode_0'), ('./output/train_videos_pusht/videos_step_100000/eval_episode_0.mp4', 'step_100000_episode_0'), ('./output/train_videos_pusht/videos_step_200000/eval_episode_0.mp4', 'step_200000_episode_0'), ('./output/train_videos_pusht/videos_step_000025/eval_episode_1.mp4', 'step_000025_episode_1'), ('./output/train_videos_pusht/videos_step_002500/eval_episode_1.mp4', 'step_002500_episode_1'), ('./output/train_videos_pusht/videos_step_025000/eval_episode_1.mp4', 'step_025000_episode_1'), ('./output/train_videos_pusht/videos_step_050000/eval_episode_1.mp4', 'step_050000_episode_1'), ('./output/train_videos_pusht/videos_step_100000/eval_episode_1.mp4', 'step_100000_episode_1'), ('./output/train_videos_pusht/videos_step_200000/eval_episode_1.mp4', 'step_200000_episode_1'), ('./output/train_videos_pusht/videos_step_000025/eval_episode_2.mp4', 'step_000025_episode_2'), ('./output/train_videos_pusht/videos_step_002500/eval_episode_2.mp4', 'step_002500_episode_2'), ('./output/train_videos_pusht/videos_step_025000/eval_episode_2.mp4', 'step_025000_episode_2'), ('./output/train_videos_pusht/videos_step_050000/eval_episode_2.mp4', 'step_050000_episode_2'), ('./output/train_videos_pusht/videos_step_100000/eval_episode_2.mp4', 'step_100000_episode_2'), ('./output/train_videos_pusht/videos_step_200000/eval_episode_2.mp4', 'step_200000_episode_2'), ('./output/train_videos_pusht/videos_step_000025/eval_episode_3.mp4', 'step_000025_episode_3'), ('./output/train_videos_pusht/videos_step_002500/eval_episode_3.mp4', 'step_002500_episode_3'), ('./output/train_videos_pusht/videos_step_025000/eval_episode_3.mp4', 'step_025000_episode_3'), ('./output/train_videos_pusht/videos_step_050000/eval_episode_3.mp4', 'step_050000_episode_3'), ('./output/train_videos_pusht/videos_step_100000/eval_episode_3.mp4', 'step_100000_episode_3'), ('./output/train_videos_pusht/videos_step_200000/eval_episode_3.mp4', 'step_200000_episode_3')]
#     <style>
#     .video-grid {
#       display: grid;
#       grid-template-columns: repeat(6, 1fr);
#       gap: 20px;
#       margin-top: 20px;
#     }
#     .video-item {
#       text-align: center;
#     }
#     .video-item video {
#       width: 100%;
#       border-radius: 10px;
#       box-shadow: 0 4px 10px rgba(0,0,0,0.2);
#     }
#     .video-title {
#       margin-top: 8px;
#       font-weight: bold;
#       font-family: sans-serif;
#     }
#     </style>
#     <div class="video-grid">
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_000025/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_000025_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_002500/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_002500_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_025000/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_025000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_050000/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_050000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_100000/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_100000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_200000/eval_episode_0.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_200000_episode_0</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_000025/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_000025_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_002500/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_002500_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_025000/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_025000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_050000/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_050000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_100000/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_100000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_200000/eval_episode_1.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_200000_episode_1</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_000025/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_000025_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_002500/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_002500_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_025000/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_025000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_050000/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_050000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_100000/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_100000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_200000/eval_episode_2.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_200000_episode_2</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_000025/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_000025_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_002500/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_002500_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_025000/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_025000_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_050000/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_050000_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_100000/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_100000_episode_3</div>
#         </div>
#
#         <div class="video-item">
#             <video controls>
#                 <source src="./output/train_videos_pusht/videos_step_200000/eval_episode_3.mp4" type="video/mp4">
#             </video>
#             <div class="video-title">step_200000_episode_3</div>
#         </div>
#         </div>
